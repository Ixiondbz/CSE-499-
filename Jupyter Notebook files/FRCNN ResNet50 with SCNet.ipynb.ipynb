# %% [markdown]
# #Installing libraries etc.

# %%
# !pip3 install mlnotify
from IPython.display import clear_output
# %load_ext autoreload
# %autoreload 2
# Install dependencies and 
# !pip install albumentations==0.4.6
# !pip install pycocotools --quiet

# !git clone https://github.com/Pseudo-Lab/Tutorial-Book-Utils
# !python Tutorial-Book-Utils/PL_data_loader.py --data FaceMaskDetection

# Clone TorchVision repo and copy helper files
# !git clone https://github.com/pytorch/vision.git
# %cd vision
# !git checkout v0.3.0
# %cd ..
# !cp vision/references/detection/utils.py ./
# !cp vision/references/detection/transforms.py ./
# !cp vision/references/detection/coco_eval.py ./
# !cp vision/references/detection/engine.py ./
# !cp vision/references/detection/coco_utils.py ./


# basic python and ML Libraries
import os
import random
import numpy as np
import pandas as pd

# for ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# We will be reading images using OpenCV
import cv2

# matplotlib for visualization
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# torchvision libraries
import torch
import torchvision
from torchvision import transforms as torchtrans  
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.backbone_utils import resnet_fpn_backbone

from torchvision.models.detection.rpn import AnchorGenerator

import torch.nn as nn
import torch.nn.functional as F

# helper libraries
from engine import train_one_epoch, evaluate
import utils
import transforms as T

# for image augmentations
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

# !apt-get install python3-openslide
from openslide import open_slide

import plotly.express as px
clear_output()

# %%
from torchvision.models.detection import FasterRCNN
from torch.utils.data import DataLoader, Dataset
import sys
import os
from torchvision.ops import misc as misc_nn_ops

import torch.hub
from functools import partial
from typing import Type, Any, Callable, Union, List, Optional
import torch
import warnings
from typing import Callable, Dict, List, Optional, Union
from torch import nn, Tensor
from torchvision.ops import misc as misc_nn_ops
from torchvision.ops.feature_pyramid_network import ExtraFPNBlock, FeaturePyramidNetwork, LastLevelMaxPool
from collections import OrderedDict
from torchvision.models import resnet 
from torch.hub import load_state_dict_from_url
import enum
from typing import Sequence, TypeVar, Type
from dataclasses import dataclass,fields

T = TypeVar("T", bound=enum.Enum)


class StrEnumMeta(enum.EnumMeta):
    auto = enum.auto

    def from_str(self: Type[T], member: str) -> T:  # type: ignore[misc]
        try:
            return self[member]
        except KeyError:
            # TODO: use `add_suggestion` from torchvision.prototype.utils._internal to improve the error message as
            #  soon as it is migrated.
            raise ValueError(f"Unknown value '{member}' for {self.__name__}.") from None


class StrEnum(enum.Enum, metaclass=StrEnumMeta):
    pass

@dataclass
class Weights:
    """
    This class is used to group important attributes associated with the pre-trained weights.
    Args:
        url (str): The location where we find the weights.
        transforms (Callable): A callable that constructs the preprocessing method (or validation preset transforms)
            needed to use the model. The reason we attach a constructor method rather than an already constructed
            object is because the specific object might have memory and thus we want to delay initialization until
            needed.
        meta (Dict[str, Any]): Stores meta-data related to the weights of the model and its configuration. These can be
            informative attributes (for example the number of parameters/flops, recipe link/methods used in training
            etc), configuration parameters (for example the `num_classes`) needed to construct the model or important
            meta-data (for example the `classes` of a classification model) needed to use the model.
    """

    url: str
    transforms: Callable
    meta: Dict[str, Any]

class WeightsEnum(StrEnum):
    """
    This class is the parent class of all model weights. Each model building method receives an optional `weights`
    parameter with its associated pre-trained weights. It inherits from `Enum` and its values should be of type
    `Weights`.
    Args:
        value (Weights): The data class entry with the weight information.
    """

    def __init__(self, value: Weights):
        self._value_ = value

    @classmethod
    def verify(cls, obj: Any) -> Any:
        if obj is not None:
            if type(obj) is str:
                obj = cls.from_str(obj.replace(cls.__name__ + ".", ""))
            elif not isinstance(obj, cls):
                raise TypeError(
                    f"Invalid Weight class provided; expected {cls.__name__} but received {obj.__class__.__name__}."
                )
        return obj

    def get_state_dict(self, progress: bool) -> OrderedDict:
        return load_state_dict_from_url(self.url, progress=progress)

    def __repr__(self) -> str:
        return f"{self.__class__.__name__}.{self._name_}"

    def __getattr__(self, name):
        # Be able to fetch Weights attributes directly
        for f in fields(Weights):
            if f.name == name:
                return object.__getattribute__(self.value, name)
        return super().__getattr__(name)

class IntermediateLayerGetter(nn.ModuleDict):
    _version = 2
    __annotations__ = {
        "return_layers": Dict[str, str],
    }

    def __init__(self, model: nn.Module, return_layers: Dict[str, str]) -> None:
        if not set(return_layers).issubset([name for name, _ in model.named_children()]):
            raise ValueError("return_layers are not present in model")
        orig_return_layers = return_layers
        return_layers = {str(k): str(v) for k, v in return_layers.items()}
        layers = OrderedDict()
        for name, module in model.named_children():
            layers[name] = module
            if name in return_layers:
                del return_layers[name]
            if not return_layers:
                break

        super().__init__(layers)
        self.return_layers = orig_return_layers

    def forward(self, x):
        out = OrderedDict()
        for name, module in self.items():
            x = module(x)
            if name in self.return_layers:
                out_name = self.return_layers[name]
                out[out_name] = x
        return out

class BackboneWithFPN(nn.Module):
    def __init__(
        self,
        backbone: nn.Module,
        return_layers: Dict[str, str],
        in_channels_list: List[int],
        out_channels: int,
        extra_blocks: Optional[ExtraFPNBlock] = None,
    ) -> None:
        super().__init__()

        if extra_blocks is None:
            extra_blocks = LastLevelMaxPool()

        self.body = IntermediateLayerGetter(backbone, return_layers=return_layers)
        self.fpn = FeaturePyramidNetwork(
            in_channels_list=in_channels_list,
            out_channels=out_channels,
            extra_blocks=extra_blocks,
        )
        self.out_channels = out_channels

    def forward(self, x: Tensor) -> Dict[str, Tensor]:
        x = self.body(x)
        x = self.fpn(x)
        return x

def _resnet_fpn_extractor(
    backbone: resnet.ResNet,
    trainable_layers: int,
    returned_layers: Optional[List[int]] = None,
    extra_blocks: Optional[ExtraFPNBlock] = None,
) -> BackboneWithFPN:

    # select layers that wont be frozen
    if trainable_layers < 0 or trainable_layers > 5:
        raise ValueError(f"Trainable layers should be in the range [0,5], got {trainable_layers}")
    layers_to_train = ["layer4", "layer3", "layer2", "layer1", "conv1"][:trainable_layers]
    if trainable_layers == 5:
        layers_to_train.append("bn1")
    for name, parameter in backbone.named_parameters():
        if all([not name.startswith(layer) for layer in layers_to_train]):
            parameter.requires_grad_(False)

    if extra_blocks is None:
        extra_blocks = LastLevelMaxPool()

    if returned_layers is None:
        returned_layers = [1, 2, 3, 4]
    if min(returned_layers) <= 0 or max(returned_layers) >= 5:
        raise ValueError(f"Each returned layer should be in the range [1,4]. Got {returned_layers}")
    return_layers = {f"layer{k}": str(v) for v, k in enumerate(returned_layers)}

    in_channels_stage2 = backbone.inplanes // 8
    in_channels_list = [in_channels_stage2 * 2 ** (i - 1) for i in returned_layers]
    out_channels = 256
    return BackboneWithFPN(backbone, return_layers, in_channels_list, out_channels, extra_blocks=extra_blocks)

def resnet_fpn_backbone(
    *,
    backbone_name: str,
    weights: Optional[WeightsEnum],
    norm_layer: Callable[..., nn.Module] = misc_nn_ops.FrozenBatchNorm2d,
    trainable_layers: int = 3,
    returned_layers: Optional[List[int]] = None,
    extra_blocks: Optional[ExtraFPNBlock] = None,
) -> BackboneWithFPN:
    
    backbone = resnet.__dict__[backbone_name](weights=weights, norm_layer=norm_layer)
    return _resnet_fpn_extractor(backbone, trainable_layers, returned_layers, extra_blocks)

# %%
# from vision.torchvision.models.detection.backbone_utils import _resnet_fpn_extractor,_validate_trainable_layers

# %% [markdown]
# #Setting datapath

# %%
import json
from pathlib import Path

from google.colab import drive
drive.mount('/drive', force_remount=True)
# Out:
# Mounted at /drive

# %%
hamamatsu_xr ='Hamamatsu XR'
hamamatsu_s360='Hamamatsu S360'
aperio_cs2='Aperio ScanScope CS2'

train_dataset_folder =  aperio_cs2+'/'
test_dataset_folder  =   hamamatsu_s360+'/'

df_train = pd.read_pickle('/drive/MyDrive/CSE499 Project/Patch Datasets/'+train_dataset_folder+'DataFrame.pkl')
df_test  = pd.read_pickle('/drive/MyDrive/CSE499 Project/Patch Datasets/'+test_dataset_folder+'DataFrame.pkl')

# %% [markdown]
# #Train and Test Class

# %%
class MitosisImagesDatasetTrain(torch.utils.data.Dataset):
  def __init__(self, files_dir, width, height,transforms=None):
    self.transforms = transforms
    self.files_dir  = files_dir
    self.height     = height
    self.width      = width

    self.imgs = [image for image in sorted(os.listdir(files_dir)) if image[-5:]=='.tiff']
    
    self.classes = [_, 'mitotic figure']

  def __getitem__(self, idx):
    img_name   = self.imgs[idx]
    image_path = os.path.join(self.files_dir, img_name)

    img     = cv2.imread(image_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
    img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)

    img_res /= 255.0
    
    dataframe = df_train[df_train['file_name']==img_name].copy()
    
    boxes = []
    labels = []

    wt = img.shape[1]
    ht = img.shape[0]
    
    for index in dataframe.index:
      labels.append(1)
      
      List = dataframe['box'][index]
      
      scale_x = float(481)/float(self.width)
      scale_y = float(451)/float(self.height)

      xmin = List[0]#/float(scale_x)
      xmax = List[2]#/float(scale_x)
      ymin = List[1]#/float(scale_y)
      ymax = List[3]#/float(scale_y)
      
      # print(xmin,xmax,ymin,ymax)
      # sys.exit()

      xmin_corr = (xmin)
      xmax_corr = (xmax)
      ymin_corr = (ymin)
      ymax_corr = (ymax)
          
      boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])
    


    boxes = torch.as_tensor(boxes, dtype=torch.float32)
    labels = torch.as_tensor(labels, dtype=torch.int64)
    area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
    #area = torch.as_tensor(area, dtype=torch.float32)
    iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)
    
    target = {}
    target["boxes"] = boxes
    target["labels"] = labels
    target["image_id"] = torch.tensor([idx])
    target["area"] = area
    target["iscrowd"] = iscrowd
    
    if self.transforms:
      sample = self.transforms(image = img_res,
                                bboxes = target['boxes'],
                                labels = labels)
      img_res = sample['image']
      target['boxes'] = torch.Tensor(sample['bboxes'])

    return img_res, target
    
  def __len__(self):
    return len(self.imgs)

class MitosisImagesDatasetTest(torch.utils.data.Dataset):
  def __init__(self, files_dir, width, height,transforms=None):
    self.transforms = transforms
    self.files_dir  = files_dir
    self.height     = height
    self.width      = width

    self.imgs = [image for image in sorted(os.listdir(files_dir)) if image[-5:]=='.tiff']
    
    self.classes = [_, 'mitotic figure']

  def __getitem__(self, idx):
    img_name   = self.imgs[idx]
    image_path = os.path.join(self.files_dir, img_name)

    img     = cv2.imread(image_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
    img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)

    img_res /= 255.0
    
    dataframe = df_test[df_test['file_name']==img_name].copy()
    
    boxes = []
    labels = []

    wt = img.shape[1]
    ht = img.shape[0]
    
    for index in dataframe.index:
      labels.append(1)
      
      List = dataframe['box'][index]
      
      scale_x = float(481)/float(self.width)
      scale_y = float(451)/float(self.height)

      xmin = List[0]#/float(scale_x)
      xmax = List[2]#/float(scale_x)
      ymin = List[1]#/float(scale_y)
      ymax = List[3]#/float(scale_y)

      

      xmin_corr = (xmin)
      xmax_corr = (xmax)
      ymin_corr = (ymin)
      ymax_corr = (ymax)
          
      boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])
    


    boxes = torch.as_tensor(boxes, dtype=torch.float32)
    labels = torch.as_tensor(labels, dtype=torch.int64)
    area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
    #area = torch.as_tensor(area, dtype=torch.float32)
    iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)
    
    target = {}
    target["boxes"] = boxes
    target["labels"] = labels
    target["image_id"] = torch.tensor([idx])
    target["area"] = area
    target["iscrowd"] = iscrowd
    
    if self.transforms:
      sample = self.transforms(image = img_res,
                                bboxes = target['boxes'],
                                labels = labels)
      img_res = sample['image']
      target['boxes'] = torch.Tensor(sample['bboxes'])

    return img_res, target
    
  def __len__(self):
    return len(self.imgs)

# %% [markdown]
# #Plotting and setting training data

# %%
# Function to visualize bounding boxes in the image
def plot_img_bbox(img, target):
  # plot the image and bboxes
  # Bounding boxes are defined as follows: x-min y-min width height
  fig, a = plt.subplots(1,1)
  fig.set_size_inches(5,5)
  a.imshow(img)
  for box in (target['boxes']):
    x, y, width, height  = box[0], box[1], box[2]-box[0], box[3]-box[1]
    rect = patches.Rectangle(
      (x, y),
      width, height,
      linewidth = 2,
      edgecolor = 'r',
      facecolor = 'none'
    )
    # Draw the bounding box on top of the image
    a.add_patch(rect)
  plt.show()

  # Send train=True for training transforms and False for val/test transforms
def get_transform(train):
  if train:
    return A.Compose(
      [
        A.HorizontalFlip(0.5),
        A.RandomBrightnessContrast(p=0.5),
        # ToTensorV2 converts image to pytorch tensor without div by 255
        ToTensorV2(p=1.0),
      ],
      bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']}
    )
  else:
    return A.Compose(
      [ToTensorV2(p=1.0)],
      bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']}
    )

# %%
train_dir = '/drive/MyDrive/CSE499 Project/Patch Datasets/'+train_dataset_folder
test_dir = '/drive/MyDrive/CSE499 Project/Patch Datasets/'+test_dataset_folder

print(train_dir)
print(test_dir)

dataset =      MitosisImagesDatasetTrain(train_dir, 481, 451)
dataset_test = MitosisImagesDatasetTest(test_dir, 481,451)

# plotting the image with bboxes. Feel free to change the index
img, target = dataset[100]
print(img.shape)
plot_img_bbox(img, target)
# Out:
# /drive/MyDrive/CSE499 Project/Patch Datasets/Aperio ScanScope CS2/
# /drive/MyDrive/CSE499 Project/Patch Datasets/Hamamatsu S360/
# (451, 481, 3)

# %%
train_dataset =      MitosisImagesDatasetTrain(train_dir, 481, 451,transforms=get_transform(train=True))

def collate_fn(batch):
    return tuple(zip(*batch))

train_data_loader  = DataLoader(train_dataset,batch_size=8,shuffle=True,num_workers=4,collate_fn=utils.collate_fn)

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# #Training part

# %%
# !git clone https://github.com/MCG-NKU/SCNet.git
# %cd /content/SCNet
# Out:
# Cloning into 'SCNet'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 31 (delta 14), reused 23 (delta 9), pack-reused 0
# Unpacking objects: 100% (31/31), done.
# /content/SCNet

# %%
from scnet import scnet50
sc_net = scnet50(pretrained=True)
# Out:
# Downloading: "https://backseason.oss-cn-beijing.aliyuncs.com/scnet/scnet50-dc6a7e87.pth" to /root/.cache/torch/hub/checkpoints/scnet50-dc6a7e87.pth
#   0%|          | 0.00/97.9M [00:00<?, ?B/s]

# %%
num_classes=2
backbone = _resnet_fpn_extractor(sc_net,trainable_layers=3)
model = FasterRCNN(backbone,num_classes=num_classes)
in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

model = model.to(device)

params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)
num_epochs = 50

# %%
# modelOG=torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=False)

# %%
# modelOG

# %%
# model

# %%
print(train_dir)
print(test_dir)
# Out:
# /drive/MyDrive/CSE499 Project/Patch Datasets/Aperio ScanScope CS2/
# /drive/MyDrive/CSE499 Project/Patch Datasets/Hamamatsu S360/

# %%
import mlnotify

# %%
# %cd '/drive/MyDrive/CSE499 Project/modelSaves/Attention Mechanism/ChannelSpatial/SCNet/model1pretrained'
# mlnotify.start()
for epoch in range(25):
    # training for one epoch
    train_one_epoch(model, optimizer, train_data_loader, device, epoch, print_freq=10)
    #save the model
    # torch.save(model.state_dict(), 'model.pth')
    # torch.save({
    # 'epoch':epoch+1,
    # 'model_state_dict':model.state_dict(),
    # 'optimizer_state_dict':optimizer.state_dict(),
    # },'ckpt.pth')
    # update the learning rate
    lr_scheduler.step()
# mlnotify.end()
# Out:
# Epoch: [0]  [  0/279]  eta: 0:21:57  lr: 0.000023  loss: 0.0539 (0.0539)  loss_classifier: 0.0221 (0.0221)  loss_box_reg: 0.0268 (0.0268)  loss_objectness: 0.0031 (0.0031)  loss_rpn_box_reg: 0.0020 (0.0020)  time: 4.7231  data: 3.2179  max mem: 10185
# Epoch: [0]  [ 10/279]  eta: 0:23:29  lr: 0.000203  loss: 0.0329 (0.0354)  loss_classifier: 0.0117 (0.0144)  loss_box_reg: 0.0172 (0.0179)  loss_objectness: 0.0007 (0.0016)  loss_rpn_box_reg: 0.0015 (0.0014)  time: 5.2393  data: 4.2167  max mem: 10452
# Epoch: [0]  [ 20/279]  eta: 0:13:52  lr: 0.000382  loss: 0.0340 (0.0381)  loss_classifier: 0.0130 (0.0158)  loss_box_reg: 0.0172 (0.0190)  loss_objectness: 0.0007 (0.0018)  loss_rpn_box_reg: 0.0014 (0.0015)  time: 3.1405  data: 2.1716  max mem: 10452
# Epoch: [0]  [ 30/279]  eta: 0:10:22  lr: 0.000562  loss: 0.0340 (0.0359)  loss_classifier: 0.0130 (0.0151)  loss_box_reg: 0.0157 (0.0177)  loss_objectness: 0.0007 (0.0017)  loss_rpn_box_reg: 0.0011 (0.0014)  time: 0.9926  data: 0.0279  max mem: 10452
# Epoch: [0]  [ 40/279]  eta: 0:08:29  lr: 0.000742  loss: 0.0279 (0.0343)  loss_classifier: 0.0098 (0.0142)  loss_box_reg: 0.0154 (0.0173)  loss_objectness: 0.0006 (0.0015)  loss_rpn_box_reg: 0.0011 (0.0013)  time: 0.9963  data: 0.0291  max mem: 10452
# Epoch: [0]  [ 50/279]  eta: 0:07:17  lr: 0.000921  loss: 0.0281 (0.0348)  loss_classifier: 0.0098 (0.0141)  loss_box_reg: 0.0146 (0.0172)  loss_objectness: 0.0007 (0.0021)  loss_rpn_box_reg: 0.0012 (0.0013)  time: 0.9952  data: 0.0278  max mem: 10452
# Epoch: [0]  [ 60/279]  eta: 0:06:25  lr: 0.001101  loss: 0.0322 (0.0358)  loss_classifier: 0.0116 (0.0146)  loss_box_reg: 0.0146 (0.0177)  loss_objectness: 0.0010 (0.0022)  loss_rpn_box_reg: 0.0014 (0.0014)  time: 0.9945  data: 0.0271  max mem: 10452
# Epoch: [0]  [ 70/279]  eta: 0:05:45  lr: 0.001281  loss: 0.0334 (0.0354)  loss_classifier: 0.0134 (0.0143)  loss_box_reg: 0.0158 (0.0177)  loss_objectness: 0.0007 (0.0020)  loss_rpn_box_reg: 0.0014 (0.0014)  time: 0.9962  data: 0.0279  max mem: 10452
# Epoch: [0]  [ 80/279]  eta: 0:05:12  lr: 0.001460  loss: 0.0316 (0.0364)  loss_classifier: 0.0123 (0.0149)  loss_box_reg: 0.0170 (0.0178)  loss_objectness: 0.0005 (0.0023)  loss_rpn_box_reg: 0.0015 (0.0014)  time: 0.9962  data: 0.0276  max mem: 10452
# Epoch: [0]  [ 90/279]  eta: 0:04:44  lr: 0.001640  loss: 0.0342 (0.0367)  loss_classifier: 0.0125 (0.0149)  loss_box_reg: 0.0182 (0.0179)  loss_objectness: 0.0014 (0.0025)  loss_rpn_box_reg: 0.0015 (0.0014)  time: 0.9955  data: 0.0284  max mem: 10452
# Epoch: [0]  [100/279]  eta: 0:04:20  lr: 0.001820  loss: 0.0342 (0.0365)  loss_classifier: 0.0125 (0.0148)  loss_box_reg: 0.0182 (0.0179)  loss_objectness: 0.0012 (0.0024)  loss_rpn_box_reg: 0.0015 (0.0014)  time: 0.9967  data: 0.0306  max mem: 10452
# Epoch: [0]  [110/279]  eta: 0:03:59  lr: 0.001999  loss: 0.0336 (0.0365)  loss_classifier: 0.0147 (0.0149)  loss_box_reg: 0.0180 (0.0179)  loss_objectness: 0.0010 (0.0023)  loss_rpn_box_reg: 0.0015 (0.0014)  time: 1.0007  data: 0.0310  max mem: 10452
# Epoch: [0]  [120/279]  eta: 0:03:39  lr: 0.002179  loss: 0.0331 (0.0362)  loss_classifier: 0.0127 (0.0147)  loss_box_reg: 0.0178 (0.0179)  loss_objectness: 0.0006 (0.0022)  loss_rpn_box_reg: 0.0017 (0.0014)  time: 1.0016  data: 0.0300  max mem: 10452
# Epoch: [0]  [130/279]  eta: 0:03:21  lr: 0.002359  loss: 0.0362 (0.0368)  loss_classifier: 0.0116 (0.0149)  loss_box_reg: 0.0196 (0.0182)  loss_objectness: 0.0007 (0.0022)  loss_rpn_box_reg: 0.0017 (0.0015)  time: 0.9985  data: 0.0296  max mem: 10452
# Epoch: [0]  [140/279]  eta: 0:03:04  lr: 0.002538  loss: 0.0366 (0.0367)  loss_classifier: 0.0134 (0.0149)  loss_box_reg: 0.0202 (0.0182)  loss_objectness: 0.0008 (0.0021)  loss_rpn_box_reg: 0.0016 (0.0015)  time: 0.9965  data: 0.0293  max mem: 10452
# Epoch: [0]  [150/279]  eta: 0:02:48  lr: 0.002718  loss: 0.0313 (0.0368)  loss_classifier: 0.0118 (0.0149)  loss_box_reg: 0.0187 (0.0183)  loss_objectness: 0.0005 (0.0022)  loss_rpn_box_reg: 0.0014 (0.0015)  time: 0.9968  data: 0.0289  max mem: 10452
# Epoch: [0]  [160/279]  eta: 0:02:33  lr: 0.002898  loss: 0.0331 (0.0369)  loss_classifier: 0.0119 (0.0148)  loss_box_reg: 0.0187 (0.0184)  loss_objectness: 0.0007 (0.0021)  loss_rpn_box_reg: 0.0015 (0.0015)  time: 0.9977  data: 0.0292  max mem: 10452
# Epoch: [0]  [170/279]  eta: 0:02:18  lr: 0.003077  loss: 0.0366 (0.0368)  loss_classifier: 0.0138 (0.0148)  loss_box_reg: 0.0177 (0.0184)  loss_objectness: 0.0010 (0.0021)  loss_rpn_box_reg: 0.0016 (0.0015)  time: 1.0003  data: 0.0294  max mem: 10452
# Epoch: [0]  [180/279]  eta: 0:02:04  lr: 0.003257  loss: 0.0369 (0.0370)  loss_classifier: 0.0140 (0.0149)  loss_box_reg: 0.0177 (0.0185)  loss_objectness: 0.0007 (0.0021)  loss_rpn_box_reg: 0.0017 (0.0015)  time: 1.0021  data: 0.0301  max mem: 10452
# Epoch: [0]  [190/279]  eta: 0:01:50  lr: 0.003437  loss: 0.0357 (0.0369)  loss_classifier: 0.0131 (0.0148)  loss_box_reg: 0.0192 (0.0185)  loss_objectness: 0.0007 (0.0020)  loss_rpn_box_reg: 0.0012 (0.0015)  time: 1.0033  data: 0.0308  max mem: 10452
# Epoch: [0]  [200/279]  eta: 0:01:37  lr: 0.003616  loss: 0.0312 (0.0369)  loss_classifier: 0.0109 (0.0148)  loss_box_reg: 0.0183 (0.0186)  loss_objectness: 0.0007 (0.0020)  loss_rpn_box_reg: 0.0012 (0.0015)  time: 1.0025  data: 0.0302  max mem: 10452
# Epoch: [0]  [210/279]  eta: 0:01:24  lr: 0.003796  loss: 0.0323 (0.0369)  loss_classifier: 0.0109 (0.0147)  loss_box_reg: 0.0190 (0.0187)  loss_objectness: 0.0008 (0.0020)  loss_rpn_box_reg: 0.0015 (0.0015)  time: 0.9979  data: 0.0299  max mem: 10452
# Epoch: [0]  [220/279]  eta: 0:01:11  lr: 0.003976  loss: 0.0382 (0.0373)  loss_classifier: 0.0138 (0.0149)  loss_box_reg: 0.0196 (0.0188)  loss_objectness: 0.0011 (0.0020)  loss_rpn_box_reg: 0.0017 (0.0015)  time: 0.9963  data: 0.0290  max mem: 10452
# Epoch: [0]  [230/279]  eta: 0:00:58  lr: 0.004156  loss: 0.0334 (0.0373)  loss_classifier: 0.0126 (0.0150)  loss_box_reg: 0.0186 (0.0188)  loss_objectness: 0.0011 (0.0020)  loss_rpn_box_reg: 0.0019 (0.0016)  time: 0.9972  data: 0.0271  max mem: 10452
# Epoch: [0]  [240/279]  eta: 0:00:46  lr: 0.004335  loss: 0.0325 (0.0372)  loss_classifier: 0.0126 (0.0149)  loss_box_reg: 0.0178 (0.0188)  loss_objectness: 0.0007 (0.0020)  loss_rpn_box_reg: 0.0017 (0.0016)  time: 0.9968  data: 0.0273  max mem: 10452
# Epoch: [0]  [250/279]  eta: 0:00:34  lr: 0.004515  loss: 0.0356 (0.0377)  loss_classifier: 0.0145 (0.0152)  loss_box_reg: 0.0197 (0.0189)  loss_objectness: 0.0012 (0.0020)  loss_rpn_box_reg: 0.0017 (0.0016)  time: 0.9967  data: 0.0289  max mem: 10452
# Epoch: [0]  [260/279]  eta: 0:00:22  lr: 0.004695  loss: 0.0358 (0.0375)  loss_classifier: 0.0129 (0.0150)  loss_box_reg: 0.0202 (0.0189)  loss_objectness: 0.0008 (0.0020)  loss_rpn_box_reg: 0.0017 (0.0016)  time: 0.9964  data: 0.0300  max mem: 10452
# Epoch: [0]  [270/279]  eta: 0:00:10  lr: 0.004874  loss: 0.0358 (0.0378)  loss_classifier: 0.0121 (0.0151)  loss_box_reg: 0.0202 (0.0191)  loss_objectness: 0.0005 (0.0021)  loss_rpn_box_reg: 0.0016 (0.0016)  time: 0.9975  data: 0.0293  max mem: 10452
# Epoch: [0]  [278/279]  eta: 0:00:01  lr: 0.005000  loss: 0.0391 (0.0381)  loss_classifier: 0.0148 (0.0152)  loss_box_reg: 0.0214 (0.0192)  loss_objectness: 0.0007 (0.0021)  loss_rpn_box_reg: 0.0019 (0.0016)  time: 0.9957  data: 0.0281  max mem: 10452
# Epoch: [0] Total time: 0:05:25 (1.1654 s / it)
# Epoch: [1]  [  0/279]  eta: 0:07:15  lr: 0.005000  loss: 0.0452 (0.0452)  loss_classifier: 0.0227 (0.0227)  loss_box_reg: 0.0190 (0.0190)  loss_objectness: 0.0017 (0.0017)  loss_rpn_box_reg: 0.0018 (0.0018)  time: 1.5605  data: 0.5470  max mem: 10452
# Epoch: [1]  [ 10/279]  eta: 0:04:42  lr: 0.005000  loss: 0.0439 (0.0443)  loss_classifier: 0.0176 (0.0191)  loss_box_reg: 0.0197 (0.0211)  loss_objectness: 0.0017 (0.0022)  loss_rpn_box_reg: 0.0017 (0.0018)  time: 1.0500  data: 0.0784  max mem: 10452
# Epoch: [1]  [ 20/279]  eta: 0:04:25  lr: 0.005000  loss: 0.0372 (0.0395)  loss_classifier: 0.0158 (0.0167)  loss_box_reg: 0.0192 (0.0195)  loss_objectness: 0.0005 (0.0017)  loss_rpn_box_reg: 0.0016 (0.0016)  time: 0.9964  data: 0.0305  max mem: 10452
# Epoch: [1]  [ 30/279]  eta: 0:04:13  lr: 0.005000  loss: 0.0367 (0.0404)  loss_classifier: 0.0143 (0.0165)  loss_box_reg: 0.0190 (0.0203)  loss_objectness: 0.0005 (0.0017)  loss_rpn_box_reg: 0.0016 (0.0018)  time: 0.9985  data: 0.0311  max mem: 10452
# Epoch: [1]  [ 40/279]  eta: 0:04:01  lr: 0.005000  loss: 0.0328 (0.0397)  loss_classifier: 0.0122 (0.0160)  loss_box_reg: 0.0194 (0.0203)  loss_objectness: 0.0007 (0.0015)  loss_rpn_box_reg: 0.0019 (0.0018)  time: 1.0012  data: 0.0308  max mem: 10452
# Epoch: [1]  [ 50/279]  eta: 0:03:51  lr: 0.005000  loss: 0.0384 (0.0404)  loss_classifier: 0.0123 (0.0161)  loss_box_reg: 0.0223 (0.0210)  loss_objectness: 0.0008 (0.0015)  loss_rpn_box_reg: 0.0017 (0.0018)  time: 0.9980  data: 0.0299  max mem: 10452
# Epoch: [1]  [ 60/279]  eta: 0:03:40  lr: 0.005000  loss: 0.0434 (0.0410)  loss_classifier: 0.0151 (0.0164)  loss_box_reg: 0.0229 (0.0213)  loss_objectness: 0.0009 (0.0015)  loss_rpn_box_reg: 0.0018 (0.0018)  time: 0.9965  data: 0.0295  max mem: 10452
# Epoch: [1]  [ 70/279]  eta: 0:03:30  lr: 0.005000  loss: 0.0445 (0.0415)  loss_classifier: 0.0156 (0.0165)  loss_box_reg: 0.0203 (0.0216)  loss_objectness: 0.0009 (0.0015)  loss_rpn_box_reg: 0.0021 (0.0018)  time: 0.9975  data: 0.0293  max mem: 10452
# Epoch: [1]  [ 80/279]  eta: 0:03:20  lr: 0.005000  loss: 0.0360 (0.0409)  loss_classifier: 0.0136 (0.0162)  loss_box_reg: 0.0186 (0.0214)  loss_objectness: 0.0007 (0.0015)  loss_rpn_box_reg: 0.0015 (0.0018)  time: 0.9983  data: 0.0305  max mem: 10452
# Epoch: [1]  [ 90/279]  eta: 0:03:09  lr: 0.005000  loss: 0.0405 (0.0411)  loss_classifier: 0.0153 (0.0161)  loss_box_reg: 0.0205 (0.0217)  loss_objectness: 0.0005 (0.0015)  loss_rpn_box_reg: 0.0014 (0.0018)  time: 0.9983  data: 0.0301  max mem: 10452
# Epoch: [1]  [100/279]  eta: 0:02:59  lr: 0.005000  loss: 0.0405 (0.0410)  loss_classifier: 0.0167 (0.0162)  loss_box_reg: 0.0212 (0.0215)  loss_objectness: 0.0008 (0.0015)  loss_rpn_box_reg: 0.0016 (0.0018)  time: 0.9975  data: 0.0285  max mem: 10452
# Epoch: [1]  [110/279]  eta: 0:02:49  lr: 0.005000  loss: 0.0356 (0.0406)  loss_classifier: 0.0146 (0.0161)  loss_box_reg: 0.0184 (0.0212)  loss_objectness: 0.0016 (0.0015)  loss_rpn_box_reg: 0.0016 (0.0018)  time: 0.9963  data: 0.0283  max mem: 10452
# Epoch: [1]  [120/279]  eta: 0:02:39  lr: 0.005000  loss: 0.0306 (0.0403)  loss_classifier: 0.0114 (0.0160)  loss_box_reg: 0.0171 (0.0210)  loss_objectness: 0.0018 (0.0015)  loss_rpn_box_reg: 0.0013 (0.0017)  time: 0.9999  data: 0.0310  max mem: 10452
# Epoch: [1]  [130/279]  eta: 0:02:29  lr: 0.005000  loss: 0.0323 (0.0401)  loss_classifier: 0.0133 (0.0159)  loss_box_reg: 0.0166 (0.0208)  loss_objectness: 0.0016 (0.0017)  loss_rpn_box_reg: 0.0013 (0.0017)  time: 1.0015  data: 0.0310  max mem: 10452
# Epoch: [1]  [140/279]  eta: 0:02:19  lr: 0.005000  loss: 0.0305 (0.0396)  loss_classifier: 0.0129 (0.0157)  loss_box_reg: 0.0162 (0.0205)  loss_objectness: 0.0012 (0.0017)  loss_rpn_box_reg: 0.0015 (0.0017)  time: 0.9975  data: 0.0290  max mem: 10452
# Epoch: [1]  [150/279]  eta: 0:02:09  lr: 0.005000  loss: 0.0303 (0.0393)  loss_classifier: 0.0118 (0.0156)  loss_box_reg: 0.0160 (0.0203)  loss_objectness: 0.0010 (0.0017)  loss_rpn_box_reg: 0.0015 (0.0017)  time: 0.9970  data: 0.0291  max mem: 10452
# Epoch: [1]  [160/279]  eta: 0:01:59  lr: 0.005000  loss: 0.0370 (0.0394)  loss_classifier: 0.0135 (0.0156)  loss_box_reg: 0.0193 (0.0204)  loss_objectness: 0.0008 (0.0017)  loss_rpn_box_reg: 0.0015 (0.0017)  time: 0.9961  data: 0.0301  max mem: 10452
# Epoch: [1]  [170/279]  eta: 0:01:49  lr: 0.005000  loss: 0.0365 (0.0391)  loss_classifier: 0.0127 (0.0154)  loss_box_reg: 0.0195 (0.0204)  loss_objectness: 0.0008 (0.0017)  loss_rpn_box_reg: 0.0015 (0.0017)  time: 0.9957  data: 0.0305  max mem: 10452
# Epoch: [1]  [180/279]  eta: 0:01:39  lr: 0.005000  loss: 0.0365 (0.0395)  loss_classifier: 0.0127 (0.0155)  loss_box_reg: 0.0210 (0.0205)  loss_objectness: 0.0009 (0.0017)  loss_rpn_box_reg: 0.0021 (0.0017)  time: 0.9965  data: 0.0300  max mem: 10452
# Epoch: [1]  [190/279]  eta: 0:01:29  lr: 0.005000  loss: 0.0357 (0.0391)  loss_classifier: 0.0108 (0.0154)  loss_box_reg: 0.0210 (0.0203)  loss_objectness: 0.0007 (0.0017)  loss_rpn_box_reg: 0.0020 (0.0017)  time: 0.9961  data: 0.0293  max mem: 10452
# Epoch: [1]  [200/279]  eta: 0:01:19  lr: 0.005000  loss: 0.0301 (0.0391)  loss_classifier: 0.0106 (0.0154)  loss_box_reg: 0.0168 (0.0203)  loss_objectness: 0.0006 (0.0017)  loss_rpn_box_reg: 0.0016 (0.0017)  time: 0.9980  data: 0.0294  max mem: 10452
# Epoch: [1]  [210/279]  eta: 0:01:09  lr: 0.005000  loss: 0.0326 (0.0391)  loss_classifier: 0.0122 (0.0154)  loss_box_reg: 0.0174 (0.0203)  loss_objectness: 0.0007 (0.0017)  loss_rpn_box_reg: 0.0014 (0.0017)  time: 0.9961  data: 0.0294  max mem: 10452
# Epoch: [1]  [220/279]  eta: 0:00:59  lr: 0.005000  loss: 0.0360 (0.0389)  loss_classifier: 0.0135 (0.0153)  loss_box_reg: 0.0165 (0.0201)  loss_objectness: 0.0009 (0.0017)  loss_rpn_box_reg: 0.0014 (0.0017)  time: 0.9947  data: 0.0284  max mem: 10452
# Epoch: [1]  [230/279]  eta: 0:00:48  lr: 0.005000  loss: 0.0328 (0.0389)  loss_classifier: 0.0125 (0.0153)  loss_box_reg: 0.0173 (0.0201)  loss_objectness: 0.0009 (0.0017)  loss_rpn_box_reg: 0.0014 (0.0017)  time: 0.9971  data: 0.0306  max mem: 10452
# Epoch: [1]  [240/279]  eta: 0:00:38  lr: 0.005000  loss: 0.0309 (0.0386)  loss_classifier: 0.0110 (0.0152)  loss_box_reg: 0.0176 (0.0200)  loss_objectness: 0.0011 (0.0017)  loss_rpn_box_reg: 0.0016 (0.0017)  time: 0.9989  data: 0.0314  max mem: 10452
# Epoch: [1]  [250/279]  eta: 0:00:28  lr: 0.005000  loss: 0.0308 (0.0383)  loss_classifier: 0.0110 (0.0150)  loss_box_reg: 0.0165 (0.0199)  loss_objectness: 0.0011 (0.0017)  loss_rpn_box_reg: 0.0016 (0.0017)  time: 0.9992  data: 0.0291  max mem: 10452
# Epoch: [1]  [260/279]  eta: 0:00:19  lr: 0.005000  loss: 0.0372 (0.0385)  loss_classifier: 0.0146 (0.0152)  loss_box_reg: 0.0165 (0.0199)  loss_objectness: 0.0013 (0.0017)  loss_rpn_box_reg: 0.0014 (0.0017)  time: 1.0010  data: 0.0291  max mem: 10452
# Epoch: [1]  [270/279]  eta: 0:00:09  lr: 0.005000  loss: 0.0392 (0.0386)  loss_classifier: 0.0168 (0.0153)  loss_box_reg: 0.0193 (0.0200)  loss_objectness: 0.0011 (0.0017)  loss_rpn_box_reg: 0.0014 (0.0017)  time: 1.0032  data: 0.0302  max mem: 10452
# Epoch: [1]  [278/279]  eta: 0:00:00  lr: 0.005000  loss: 0.0368 (0.0386)  loss_classifier: 0.0166 (0.0153)  loss_box_reg: 0.0188 (0.0199)  loss_objectness: 0.0010 (0.0017)  loss_rpn_box_reg: 0.0014 (0.0017)  time: 0.9970  data: 0.0291  max mem: 10452
# Epoch: [1] Total time: 0:04:39 (1.0002 s / it)
# Epoch: [2]  [  0/279]  eta: 0:07:52  lr: 0.005000  loss: 0.0467 (0.0467)  loss_classifier: 0.0205 (0.0205)  loss_box_reg: 0.0228 (0.0228)  loss_objectness: 0.0018 (0.0018)  loss_rpn_box_reg: 0.0016 (0.0016)  time: 1.6940  data: 0.7194  max mem: 10452
# Epoch: [2]  [ 10/279]  eta: 0:04:43  lr: 0.005000  loss: 0.0355 (0.0407)  loss_classifier: 0.0176 (0.0173)  loss_box_reg: 0.0207 (0.0201)  loss_objectness: 0.0009 (0.0016)  loss_rpn_box_reg: 0.0018 (0.0018)  time: 1.0542  data: 0.0835  max mem: 10452
# Epoch: [2]  [ 20/279]  eta: 0:04:25  lr: 0.005000  loss: 0.0314 (0.0364)  loss_classifier: 0.0113 (0.0150)  loss_box_reg: 0.0178 (0.0183)  loss_objectness: 0.0006 (0.0014)  loss_rpn_box_reg: 0.0016 (0.0017)  time: 0.9920  data: 0.0249  max mem: 10452
# Epoch: [2]  [ 30/279]  eta: 0:04:13  lr: 0.005000  loss: 0.0310 (0.0344)  loss_classifier: 0.0108 (0.0141)  loss_box_reg: 0.0149 (0.0176)  loss_objectness: 0.0004 (0.0012)  loss_rpn_box_reg: 0.0014 (0.0015)  time: 0.9972  data: 0.0299  max mem: 10452
# Epoch: [2]  [ 40/279]  eta: 0:04:02  lr: 0.005000  loss: 0.0275 (0.0341)  loss_classifier: 0.0108 (0.0140)  loss_box_reg: 0.0149 (0.0173)  loss_objectness: 0.0006 (0.0013)  loss_rpn_box_reg: 0.0014 (0.0015)  time: 1.0024  data: 0.0313  max mem: 10452
# Epoch: [2]  [ 50/279]  eta: 0:03:51  lr: 0.005000  loss: 0.0287 (0.0342)  loss_classifier: 0.0121 (0.0140)  loss_box_reg: 0.0163 (0.0176)  loss_objectness: 0.0006 (0.0012)  loss_rpn_box_reg: 0.0014 (0.0015)  time: 1.0028  data: 0.0320  max mem: 10452
# Epoch: [2]  [ 60/279]  eta: 0:03:40  lr: 0.005000  loss: 0.0332 (0.0350)  loss_classifier: 0.0149 (0.0145)  loss_box_reg: 0.0172 (0.0176)  loss_objectness: 0.0009 (0.0014)  loss_rpn_box_reg: 0.0014 (0.0015)  time: 0.9987  data: 0.0294  max mem: 10452
# Epoch: [2]  [ 70/279]  eta: 0:03:30  lr: 0.005000  loss: 0.0332 (0.0354)  loss_classifier: 0.0149 (0.0147)  loss_box_reg: 0.0181 (0.0177)  loss_objectness: 0.0011 (0.0014)  loss_rpn_box_reg: 0.0015 (0.0016)  time: 0.9965  data: 0.0282  max mem: 10452
# Epoch: [2]  [ 80/279]  eta: 0:03:20  lr: 0.005000  loss: 0.0323 (0.0353)  loss_classifier: 0.0111 (0.0145)  loss_box_reg: 0.0186 (0.0178)  loss_objectness: 0.0007 (0.0013)  loss_rpn_box_reg: 0.0017 (0.0016)  time: 0.9997  data: 0.0293  max mem: 10452
# Epoch: [2]  [ 90/279]  eta: 0:03:10  lr: 0.005000  loss: 0.0340 (0.0353)  loss_classifier: 0.0115 (0.0145)  loss_box_reg: 0.0190 (0.0178)  loss_objectness: 0.0007 (0.0014)  loss_rpn_box_reg: 0.0016 (0.0016)  time: 1.0019  data: 0.0297  max mem: 10452
# Epoch: [2]  [100/279]  eta: 0:02:59  lr: 0.005000  loss: 0.0322 (0.0353)  loss_classifier: 0.0101 (0.0144)  loss_box_reg: 0.0185 (0.0179)  loss_objectness: 0.0010 (0.0014)  loss_rpn_box_reg: 0.0013 (0.0016)  time: 0.9987  data: 0.0297  max mem: 10452
# Epoch: [2]  [110/279]  eta: 0:02:49  lr: 0.005000  loss: 0.0324 (0.0351)  loss_classifier: 0.0113 (0.0143)  loss_box_reg: 0.0185 (0.0179)  loss_objectness: 0.0006 (0.0013)  loss_rpn_box_reg: 0.0014 (0.0016)  time: 0.9982  data: 0.0286  max mem: 10452
# Epoch: [2]  [120/279]  eta: 0:02:39  lr: 0.005000  loss: 0.0300 (0.0345)  loss_classifier: 0.0109 (0.0141)  loss_box_reg: 0.0158 (0.0176)  loss_objectness: 0.0004 (0.0013)  loss_rpn_box_reg: 0.0013 (0.0016)  time: 0.9999  data: 0.0277  max mem: 10452
# Epoch: [2]  [130/279]  eta: 0:02:29  lr: 0.005000  loss: 0.0292 (0.0345)  loss_classifier: 0.0112 (0.0139)  loss_box_reg: 0.0158 (0.0178)  loss_objectness: 0.0004 (0.0012)  loss_rpn_box_reg: 0.0013 (0.0016)  time: 0.9979  data: 0.0276  max mem: 10452
# Epoch: [2]  [140/279]  eta: 0:02:19  lr: 0.005000  loss: 0.0327 (0.0343)  loss_classifier: 0.0115 (0.0138)  loss_box_reg: 0.0169 (0.0177)  loss_objectness: 0.0004 (0.0012)  loss_rpn_box_reg: 0.0019 (0.0016)  time: 0.9972  data: 0.0285  max mem: 10452
# Epoch: [2]  [150/279]  eta: 0:02:09  lr: 0.005000  loss: 0.0305 (0.0339)  loss_classifier: 0.0111 (0.0135)  loss_box_reg: 0.0165 (0.0175)  loss_objectness: 0.0004 (0.0012)  loss_rpn_box_reg: 0.0019 (0.0016)  time: 1.0008  data: 0.0313  max mem: 10452
# Epoch: [2]  [160/279]  eta: 0:01:59  lr: 0.005000  loss: 0.0247 (0.0336)  loss_classifier: 0.0090 (0.0134)  loss_box_reg: 0.0149 (0.0174)  loss_objectness: 0.0004 (0.0011)  loss_rpn_box_reg: 0.0012 (0.0016)  time: 1.0028  data: 0.0319  max mem: 10452
# Epoch: [2]  [170/279]  eta: 0:01:49  lr: 0.005000  loss: 0.0276 (0.0335)  loss_classifier: 0.0094 (0.0133)  loss_box_reg: 0.0169 (0.0175)  loss_objectness: 0.0003 (0.0011)  loss_rpn_box_reg: 0.0009 (0.0016)  time: 1.0022  data: 0.0302  max mem: 10452
# Epoch: [2]  [180/279]  eta: 0:01:39  lr: 0.005000  loss: 0.0311 (0.0338)  loss_classifier: 0.0102 (0.0135)  loss_box_reg: 0.0188 (0.0176)  loss_objectness: 0.0003 (0.0011)  loss_rpn_box_reg: 0.0010 (0.0016)  time: 1.0007  data: 0.0287  max mem: 10452
# Epoch: [2]  [190/279]  eta: 0:01:29  lr: 0.005000  loss: 0.0320 (0.0337)  loss_classifier: 0.0110 (0.0134)  loss_box_reg: 0.0167 (0.0176)  loss_objectness: 0.0005 (0.0011)  loss_rpn_box_reg: 0.0015 (0.0016)  time: 0.9972  data: 0.0281  max mem: 10452
# Epoch: [2]  [200/279]  eta: 0:01:19  lr: 0.005000  loss: 0.0317 (0.0338)  loss_classifier: 0.0124 (0.0134)  loss_box_reg: 0.0165 (0.0177)  loss_objectness: 0.0006 (0.0011)  loss_rpn_box_reg: 0.0015 (0.0016)  time: 0.9989  data: 0.0298  max mem: 10452
# Epoch: [2]  [210/279]  eta: 0:01:09  lr: 0.005000  loss: 0.0360 (0.0339)  loss_classifier: 0.0141 (0.0135)  loss_box_reg: 0.0193 (0.0178)  loss_objectness: 0.0006 (0.0011)  loss_rpn_box_reg: 0.0018 (0.0016)  time: 0.9992  data: 0.0308  max mem: 10452
# Epoch: [2]  [220/279]  eta: 0:00:59  lr: 0.005000  loss: 0.0332 (0.0340)  loss_classifier: 0.0134 (0.0136)  loss_box_reg: 0.0192 (0.0177)  loss_objectness: 0.0007 (0.0011)  loss_rpn_box_reg: 0.0016 (0.0016)  time: 0.9974  data: 0.0298  max mem: 10452
# Epoch: [2]  [230/279]  eta: 0:00:49  lr: 0.005000  loss: 0.0317 (0.0342)  loss_classifier: 0.0134 (0.0137)  loss_box_reg: 0.0167 (0.0177)  loss_objectness: 0.0013 (0.0012)  loss_rpn_box_reg: 0.0015 (0.0016)  time: 1.0007  data: 0.0298  max mem: 10452
# Epoch: [2]  [240/279]  eta: 0:00:39  lr: 0.005000  loss: 0.0317 (0.0342)  loss_classifier: 0.0114 (0.0137)  loss_box_reg: 0.0173 (0.0177)  loss_objectness: 0.0006 (0.0012)  loss_rpn_box_reg: 0.0014 (0.0016)  time: 1.0013  data: 0.0295  max mem: 10452
# Epoch: [2]  [250/279]  eta: 0:00:29  lr: 0.005000  loss: 0.0316 (0.0341)  loss_classifier: 0.0124 (0.0137)  loss_box_reg: 0.0169 (0.0177)  loss_objectness: 0.0004 (0.0012)  loss_rpn_box_reg: 0.0015 (0.0016)  time: 0.9962  data: 0.0283  max mem: 10452
# Epoch: [2]  [260/279]  eta: 0:00:19  lr: 0.005000  loss: 0.0300 (0.0340)  loss_classifier: 0.0129 (0.0136)  loss_box_reg: 0.0166 (0.0176)  loss_objectness: 0.0004 (0.0012)  loss_rpn_box_reg: 0.0012 (0.0016)  time: 0.9949  data: 0.0284  max mem: 10452
# Epoch: [2]  [270/279]  eta: 0:00:09  lr: 0.005000  loss: 0.0285 (0.0340)  loss_classifier: 0.0107 (0.0136)  loss_box_reg: 0.0155 (0.0176)  loss_objectness: 0.0003 (0.0012)  loss_rpn_box_reg: 0.0009 (0.0016)  time: 0.9956  data: 0.0292  max mem: 10452
# Epoch: [2]  [278/279]  eta: 0:00:01  lr: 0.005000  loss: 0.0308 (0.0340)  loss_classifier: 0.0118 (0.0136)  loss_box_reg: 0.0178 (0.0176)  loss_objectness: 0.0003 (0.0012)  loss_rpn_box_reg: 0.0009 (0.0015)  time: 0.9944  data: 0.0282  max mem: 10452
# Epoch: [2] Total time: 0:04:39 (1.0014 s / it)
# Epoch: [3]  [  0/279]  eta: 0:07:52  lr: 0.000500  loss: 0.0604 (0.0604)  loss_classifier: 0.0318 (0.0318)  loss_box_reg: 0.0243 (0.0243)  loss_objectness: 0.0024 (0.0024)  loss_rpn_box_reg: 0.0019 (0.0019)  time: 1.6951  data: 0.7072  max mem: 10452
# Epoch: [3]  [ 10/279]  eta: 0:04:43  lr: 0.000500  loss: 0.0214 (0.0271)  loss_classifier: 0.0076 (0.0116)  loss_box_reg: 0.0132 (0.0138)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 1.0548  data: 0.0860  max mem: 10452
# Epoch: [3]  [ 20/279]  eta: 0:04:26  lr: 0.000500  loss: 0.0230 (0.0284)  loss_classifier: 0.0090 (0.0126)  loss_box_reg: 0.0125 (0.0140)  loss_objectness: 0.0004 (0.0010)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.9940  data: 0.0274  max mem: 10452
# Epoch: [3]  [ 30/279]  eta: 0:04:13  lr: 0.000500  loss: 0.0245 (0.0279)  loss_classifier: 0.0103 (0.0122)  loss_box_reg: 0.0123 (0.0138)  loss_objectness: 0.0004 (0.0011)  loss_rpn_box_reg: 0.0008 (0.0009)  time: 0.9985  data: 0.0301  max mem: 10452
# Epoch: [3]  [ 40/279]  eta: 0:04:02  lr: 0.000500  loss: 0.0255 (0.0286)  loss_classifier: 0.0102 (0.0123)  loss_box_reg: 0.0126 (0.0144)  loss_objectness: 0.0005 (0.0010)  loss_rpn_box_reg: 0.0009 (0.0009)  time: 1.0011  data: 0.0291  max mem: 10452
# Epoch: [3]  [ 50/279]  eta: 0:03:51  lr: 0.000500  loss: 0.0258 (0.0275)  loss_classifier: 0.0099 (0.0119)  loss_box_reg: 0.0136 (0.0138)  loss_objectness: 0.0003 (0.0009)  loss_rpn_box_reg: 0.0008 (0.0008)  time: 1.0017  data: 0.0294  max mem: 10452
# Epoch: [3]  [ 60/279]  eta: 0:03:40  lr: 0.000500  loss: 0.0231 (0.0273)  loss_classifier: 0.0089 (0.0116)  loss_box_reg: 0.0117 (0.0140)  loss_objectness: 0.0002 (0.0009)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.9976  data: 0.0300  max mem: 10452
# Epoch: [3]  [ 70/279]  eta: 0:03:30  lr: 0.000500  loss: 0.0231 (0.0271)  loss_classifier: 0.0089 (0.0116)  loss_box_reg: 0.0111 (0.0138)  loss_objectness: 0.0003 (0.0009)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.9969  data: 0.0290  max mem: 10452
# Epoch: [3]  [ 80/279]  eta: 0:03:20  lr: 0.000500  loss: 0.0192 (0.0266)  loss_classifier: 0.0075 (0.0114)  loss_box_reg: 0.0105 (0.0135)  loss_objectness: 0.0003 (0.0009)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.9981  data: 0.0292  max mem: 10452
# Epoch: [3]  [ 90/279]  eta: 0:03:10  lr: 0.000500  loss: 0.0235 (0.0266)  loss_classifier: 0.0090 (0.0113)  loss_box_reg: 0.0132 (0.0136)  loss_objectness: 0.0002 (0.0009)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.9972  data: 0.0307  max mem: 10452
# Epoch: [3]  [100/279]  eta: 0:02:59  lr: 0.000500  loss: 0.0235 (0.0260)  loss_classifier: 0.0090 (0.0110)  loss_box_reg: 0.0132 (0.0134)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.9997  data: 0.0298  max mem: 10452
# Epoch: [3]  [110/279]  eta: 0:02:49  lr: 0.000500  loss: 0.0206 (0.0262)  loss_classifier: 0.0076 (0.0111)  loss_box_reg: 0.0122 (0.0135)  loss_objectness: 0.0002 (0.0009)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.9985  data: 0.0284  max mem: 10452
# Epoch: [3]  [120/279]  eta: 0:02:39  lr: 0.000500  loss: 0.0290 (0.0269)  loss_classifier: 0.0115 (0.0115)  loss_box_reg: 0.0136 (0.0137)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0008 (0.0008)  time: 0.9969  data: 0.0288  max mem: 10452
# Epoch: [3]  [130/279]  eta: 0:02:29  lr: 0.000500  loss: 0.0265 (0.0265)  loss_classifier: 0.0106 (0.0113)  loss_box_reg: 0.0136 (0.0136)  loss_objectness: 0.0003 (0.0009)  loss_rpn_box_reg: 0.0008 (0.0008)  time: 0.9985  data: 0.0286  max mem: 10452
# Epoch: [3]  [140/279]  eta: 0:02:19  lr: 0.000500  loss: 0.0265 (0.0268)  loss_classifier: 0.0111 (0.0115)  loss_box_reg: 0.0130 (0.0137)  loss_objectness: 0.0002 (0.0009)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.9977  data: 0.0288  max mem: 10452
# Epoch: [3]  [150/279]  eta: 0:02:09  lr: 0.000500  loss: 0.0266 (0.0266)  loss_classifier: 0.0111 (0.0114)  loss_box_reg: 0.0129 (0.0136)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.9992  data: 0.0313  max mem: 10452
# Epoch: [3]  [160/279]  eta: 0:01:59  lr: 0.000500  loss: 0.0199 (0.0266)  loss_classifier: 0.0074 (0.0114)  loss_box_reg: 0.0126 (0.0136)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 1.0008  data: 0.0311  max mem: 10452
# Epoch: [3]  [170/279]  eta: 0:01:49  lr: 0.000500  loss: 0.0226 (0.0268)  loss_classifier: 0.0084 (0.0115)  loss_box_reg: 0.0127 (0.0137)  loss_objectness: 0.0002 (0.0009)  loss_rpn_box_reg: 0.0008 (0.0008)  time: 0.9998  data: 0.0285  max mem: 10452
# Epoch: [3]  [180/279]  eta: 0:01:39  lr: 0.000500  loss: 0.0236 (0.0267)  loss_classifier: 0.0098 (0.0114)  loss_box_reg: 0.0127 (0.0136)  loss_objectness: 0.0002 (0.0009)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 1.0006  data: 0.0289  max mem: 10452
# Epoch: [3]  [190/279]  eta: 0:01:29  lr: 0.000500  loss: 0.0251 (0.0268)  loss_classifier: 0.0111 (0.0115)  loss_box_reg: 0.0134 (0.0136)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0008 (0.0008)  time: 1.0003  data: 0.0304  max mem: 10452
# Epoch: [3]  [200/279]  eta: 0:01:19  lr: 0.000500  loss: 0.0256 (0.0266)  loss_classifier: 0.0121 (0.0114)  loss_box_reg: 0.0125 (0.0136)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.9988  data: 0.0295  max mem: 10452
# Epoch: [3]  [210/279]  eta: 0:01:09  lr: 0.000500  loss: 0.0221 (0.0265)  loss_classifier: 0.0092 (0.0113)  loss_box_reg: 0.0120 (0.0135)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 1.0008  data: 0.0292  max mem: 10452
# Epoch: [3]  [220/279]  eta: 0:00:59  lr: 0.000500  loss: 0.0228 (0.0265)  loss_classifier: 0.0096 (0.0113)  loss_box_reg: 0.0120 (0.0135)  loss_objectness: 0.0003 (0.0009)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 1.0010  data: 0.0289  max mem: 10452
# Epoch: [3]  [230/279]  eta: 0:00:49  lr: 0.000500  loss: 0.0210 (0.0265)  loss_classifier: 0.0097 (0.0113)  loss_box_reg: 0.0115 (0.0135)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.9964  data: 0.0279  max mem: 10452
# Epoch: [3]  [240/279]  eta: 0:00:39  lr: 0.000500  loss: 0.0205 (0.0263)  loss_classifier: 0.0097 (0.0112)  loss_box_reg: 0.0111 (0.0134)  loss_objectness: 0.0003 (0.0009)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.9979  data: 0.0281  max mem: 10452
# Epoch: [3]  [250/279]  eta: 0:00:29  lr: 0.000500  loss: 0.0272 (0.0265)  loss_classifier: 0.0106 (0.0113)  loss_box_reg: 0.0128 (0.0135)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0008 (0.0008)  time: 1.0035  data: 0.0308  max mem: 10452
# Epoch: [3]  [260/279]  eta: 0:00:19  lr: 0.000500  loss: 0.0282 (0.0266)  loss_classifier: 0.0120 (0.0114)  loss_box_reg: 0.0135 (0.0135)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0008 (0.0008)  time: 1.0027  data: 0.0314  max mem: 10452
# Epoch: [3]  [270/279]  eta: 0:00:09  lr: 0.000500  loss: 0.0268 (0.0267)  loss_classifier: 0.0111 (0.0115)  loss_box_reg: 0.0134 (0.0135)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0008 (0.0008)  time: 1.0026  data: 0.0298  max mem: 10452
# Epoch: [3]  [278/279]  eta: 0:00:01  lr: 0.000500  loss: 0.0227 (0.0269)  loss_classifier: 0.0092 (0.0115)  loss_box_reg: 0.0118 (0.0136)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0008 (0.0009)  time: 1.0036  data: 0.0299  max mem: 10452
# Epoch: [3] Total time: 0:04:39 (1.0022 s / it)
# Epoch: [4]  [  0/279]  eta: 0:07:28  lr: 0.000500  loss: 0.0144 (0.0144)  loss_classifier: 0.0063 (0.0063)  loss_box_reg: 0.0076 (0.0076)  loss_objectness: 0.0001 (0.0001)  loss_rpn_box_reg: 0.0004 (0.0004)  time: 1.6070  data: 0.6102  max mem: 10452
# Epoch: [4]  [ 10/279]  eta: 0:04:42  lr: 0.000500  loss: 0.0237 (0.0238)  loss_classifier: 0.0100 (0.0101)  loss_box_reg: 0.0126 (0.0123)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 1.0516  data: 0.0809  max mem: 10452
# Epoch: [4]  [ 20/279]  eta: 0:04:25  lr: 0.000500  loss: 0.0248 (0.0267)  loss_classifier: 0.0100 (0.0115)  loss_box_reg: 0.0132 (0.0136)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.9959  data: 0.0290  max mem: 10452
# Epoch: [4]  [ 30/279]  eta: 0:04:13  lr: 0.000500  loss: 0.0248 (0.0260)  loss_classifier: 0.0093 (0.0112)  loss_box_reg: 0.0138 (0.0133)  loss_objectness: 0.0004 (0.0007)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 1.0003  data: 0.0317  max mem: 10452
# Epoch: [4]  [ 40/279]  eta: 0:04:02  lr: 0.000500  loss: 0.0214 (0.0250)  loss_classifier: 0.0087 (0.0106)  loss_box_reg: 0.0121 (0.0129)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 1.0037  data: 0.0312  max mem: 10452
# Epoch: [4]  [ 50/279]  eta: 0:03:51  lr: 0.000500  loss: 0.0212 (0.0245)  loss_classifier: 0.0084 (0.0104)  loss_box_reg: 0.0113 (0.0126)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.9994  data: 0.0286  max mem: 10452
# Epoch: [4]  [ 60/279]  eta: 0:03:40  lr: 0.000500  loss: 0.0202 (0.0243)  loss_classifier: 0.0085 (0.0103)  loss_box_reg: 0.0108 (0.0126)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.9961  data: 0.0284  max mem: 10452
# Epoch: [4]  [ 70/279]  eta: 0:03:30  lr: 0.000500  loss: 0.0202 (0.0242)  loss_classifier: 0.0079 (0.0102)  loss_box_reg: 0.0112 (0.0125)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.9994  data: 0.0293  max mem: 10452
# Epoch: [4]  [ 80/279]  eta: 0:03:20  lr: 0.000500  loss: 0.0237 (0.0252)  loss_classifier: 0.0079 (0.0107)  loss_box_reg: 0.0131 (0.0129)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 1.0027  data: 0.0301  max mem: 10452
# Epoch: [4]  [ 90/279]  eta: 0:03:10  lr: 0.000500  loss: 0.0268 (0.0259)  loss_classifier: 0.0104 (0.0110)  loss_box_reg: 0.0131 (0.0132)  loss_objectness: 0.0003 (0.0009)  loss_rpn_box_reg: 0.0008 (0.0008)  time: 1.0008  data: 0.0290  max mem: 10452
# Epoch: [4]  [100/279]  eta: 0:02:59  lr: 0.000500  loss: 0.0244 (0.0256)  loss_classifier: 0.0104 (0.0109)  loss_box_reg: 0.0127 (0.0130)  loss_objectness: 0.0005 (0.0009)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.9982  data: 0.0293  max mem: 10452
# Epoch: [4]  [110/279]  eta: 0:02:49  lr: 0.000500  loss: 0.0223 (0.0253)  loss_classifier: 0.0093 (0.0108)  loss_box_reg: 0.0104 (0.0129)  loss_objectness: 0.0002 (0.0008)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.9983  data: 0.0294  max mem: 10452
# Epoch: [4]  [120/279]  eta: 0:02:39  lr: 0.000500  loss: 0.0204 (0.0251)  loss_classifier: 0.0085 (0.0107)  loss_box_reg: 0.0104 (0.0128)  loss_objectness: 0.0002 (0.0008)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 1.0010  data: 0.0278  max mem: 10452
# Epoch: [4]  [130/279]  eta: 0:02:29  lr: 0.000500  loss: 0.0205 (0.0253)  loss_classifier: 0.0079 (0.0108)  loss_box_reg: 0.0120 (0.0129)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.9989  data: 0.0279  max mem: 10452
# Epoch: [4]  [140/279]  eta: 0:02:19  lr: 0.000500  loss: 0.0205 (0.0250)  loss_classifier: 0.0088 (0.0106)  loss_box_reg: 0.0109 (0.0128)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.9973  data: 0.0297  max mem: 10452
# Epoch: [4]  [150/279]  eta: 0:02:09  lr: 0.000500  loss: 0.0215 (0.0256)  loss_classifier: 0.0094 (0.0108)  loss_box_reg: 0.0105 (0.0129)  loss_objectness: 0.0004 (0.0010)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 1.0011  data: 0.0300  max mem: 10452
# Epoch: [4]  [160/279]  eta: 0:01:59  lr: 0.000500  loss: 0.0246 (0.0254)  loss_classifier: 0.0121 (0.0108)  loss_box_reg: 0.0110 (0.0128)  loss_objectness: 0.0003 (0.0010)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 1.0029  data: 0.0305  max mem: 10452
# Epoch: [4]  [170/279]  eta: 0:01:49  lr: 0.000500  loss: 0.0230 (0.0255)  loss_classifier: 0.0096 (0.0108)  loss_box_reg: 0.0116 (0.0128)  loss_objectness: 0.0002 (0.0010)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 1.0024  data: 0.0315  max mem: 10452
# Epoch: [4]  [180/279]  eta: 0:01:39  lr: 0.000500  loss: 0.0237 (0.0254)  loss_classifier: 0.0110 (0.0108)  loss_box_reg: 0.0124 (0.0128)  loss_objectness: 0.0002 (0.0010)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.9985  data: 0.0307  max mem: 10452
# Epoch: [4]  [190/279]  eta: 0:01:29  lr: 0.000500  loss: 0.0209 (0.0252)  loss_classifier: 0.0095 (0.0108)  loss_box_reg: 0.0110 (0.0127)  loss_objectness: 0.0003 (0.0010)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.9966  data: 0.0298  max mem: 10452
# Epoch: [4]  [200/279]  eta: 0:01:19  lr: 0.000500  loss: 0.0209 (0.0253)  loss_classifier: 0.0095 (0.0108)  loss_box_reg: 0.0112 (0.0127)  loss_objectness: 0.0003 (0.0009)  loss_rpn_box_reg: 0.0008 (0.0008)  time: 0.9990  data: 0.0287  max mem: 10452
# Epoch: [4]  [210/279]  eta: 0:01:09  lr: 0.000500  loss: 0.0225 (0.0253)  loss_classifier: 0.0098 (0.0108)  loss_box_reg: 0.0126 (0.0127)  loss_objectness: 0.0003 (0.0009)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.9999  data: 0.0295  max mem: 10452
# Epoch: [4]  [220/279]  eta: 0:00:59  lr: 0.000500  loss: 0.0287 (0.0254)  loss_classifier: 0.0110 (0.0109)  loss_box_reg: 0.0126 (0.0128)  loss_objectness: 0.0003 (0.0009)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.9987  data: 0.0310  max mem: 10452
# Epoch: [4]  [230/279]  eta: 0:00:49  lr: 0.000500  loss: 0.0268 (0.0254)  loss_classifier: 0.0131 (0.0109)  loss_box_reg: 0.0117 (0.0128)  loss_objectness: 0.0005 (0.0009)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.9991  data: 0.0313  max mem: 10452
# Epoch: [4]  [240/279]  eta: 0:00:39  lr: 0.000500  loss: 0.0218 (0.0253)  loss_classifier: 0.0094 (0.0109)  loss_box_reg: 0.0116 (0.0127)  loss_objectness: 0.0005 (0.0009)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.9995  data: 0.0322  max mem: 10452
# Epoch: [4]  [250/279]  eta: 0:00:29  lr: 0.000500  loss: 0.0197 (0.0251)  loss_classifier: 0.0072 (0.0107)  loss_box_reg: 0.0101 (0.0126)  loss_objectness: 0.0003 (0.0009)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.9972  data: 0.0327  max mem: 10452
# Epoch: [4]  [260/279]  eta: 0:00:19  lr: 0.000500  loss: 0.0196 (0.0249)  loss_classifier: 0.0072 (0.0107)  loss_box_reg: 0.0101 (0.0125)  loss_objectness: 0.0003 (0.0009)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 0.9968  data: 0.0320  max mem: 10452
# Epoch: [4]  [270/279]  eta: 0:00:09  lr: 0.000500  loss: 0.0183 (0.0248)  loss_classifier: 0.0075 (0.0106)  loss_box_reg: 0.0097 (0.0125)  loss_objectness: 0.0002 (0.0009)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 0.9949  data: 0.0301  max mem: 10452
# Epoch: [4]  [278/279]  eta: 0:00:01  lr: 0.000500  loss: 0.0215 (0.0249)  loss_classifier: 0.0080 (0.0107)  loss_box_reg: 0.0116 (0.0126)  loss_objectness: 0.0003 (0.0009)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.9925  data: 0.0294  max mem: 10452
# Epoch: [4] Total time: 0:04:39 (1.0013 s / it)
# Epoch: [5]  [  0/279]  eta: 0:07:26  lr: 0.000500  loss: 0.0290 (0.0290)  loss_classifier: 0.0127 (0.0127)  loss_box_reg: 0.0151 (0.0151)  loss_objectness: 0.0002 (0.0002)  loss_rpn_box_reg: 0.0011 (0.0011)  time: 1.5993  data: 0.6138  max mem: 10452
# Epoch: [5]  [ 10/279]  eta: 0:04:43  lr: 0.000500  loss: 0.0217 (0.0266)  loss_classifier: 0.0083 (0.0114)  loss_box_reg: 0.0115 (0.0135)  loss_objectness: 0.0004 (0.0009)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 1.0529  data: 0.0853  max mem: 10452
# Epoch: [5]  [ 20/279]  eta: 0:04:26  lr: 0.000500  loss: 0.0200 (0.0251)  loss_classifier: 0.0077 (0.0106)  loss_box_reg: 0.0109 (0.0127)  loss_objectness: 0.0002 (0.0010)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.9987  data: 0.0317  max mem: 10452
# Epoch: [5]  [ 30/279]  eta: 0:04:13  lr: 0.000500  loss: 0.0177 (0.0247)  loss_classifier: 0.0074 (0.0106)  loss_box_reg: 0.0099 (0.0124)  loss_objectness: 0.0002 (0.0008)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.9990  data: 0.0298  max mem: 10452
# Epoch: [5]  [ 40/279]  eta: 0:04:01  lr: 0.000500  loss: 0.0163 (0.0231)  loss_classifier: 0.0073 (0.0099)  loss_box_reg: 0.0096 (0.0118)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.9955  data: 0.0276  max mem: 10452
# Epoch: [5]  [ 50/279]  eta: 0:03:51  lr: 0.000500  loss: 0.0181 (0.0236)  loss_classifier: 0.0073 (0.0100)  loss_box_reg: 0.0111 (0.0120)  loss_objectness: 0.0002 (0.0008)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.9978  data: 0.0294  max mem: 10452
# Epoch: [5]  [ 60/279]  eta: 0:03:41  lr: 0.000500  loss: 0.0198 (0.0231)  loss_classifier: 0.0091 (0.0099)  loss_box_reg: 0.0112 (0.0117)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 1.0041  data: 0.0317  max mem: 10452
# Epoch: [5]  [ 70/279]  eta: 0:03:30  lr: 0.000500  loss: 0.0209 (0.0239)  loss_classifier: 0.0091 (0.0102)  loss_box_reg: 0.0114 (0.0121)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 1.0038  data: 0.0316  max mem: 10452
# Epoch: [5]  [ 80/279]  eta: 0:03:20  lr: 0.000500  loss: 0.0276 (0.0245)  loss_classifier: 0.0124 (0.0106)  loss_box_reg: 0.0137 (0.0123)  loss_objectness: 0.0005 (0.0008)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 1.0021  data: 0.0302  max mem: 10452
# Epoch: [5]  [ 90/279]  eta: 0:03:10  lr: 0.000500  loss: 0.0258 (0.0243)  loss_classifier: 0.0111 (0.0105)  loss_box_reg: 0.0128 (0.0123)  loss_objectness: 0.0004 (0.0008)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 1.0027  data: 0.0294  max mem: 10452
# Epoch: [5]  [100/279]  eta: 0:03:00  lr: 0.000500  loss: 0.0186 (0.0239)  loss_classifier: 0.0071 (0.0103)  loss_box_reg: 0.0111 (0.0121)  loss_objectness: 0.0004 (0.0007)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 0.9995  data: 0.0292  max mem: 10452
# Epoch: [5]  [110/279]  eta: 0:02:49  lr: 0.000500  loss: 0.0220 (0.0237)  loss_classifier: 0.0110 (0.0103)  loss_box_reg: 0.0107 (0.0119)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 0.9970  data: 0.0289  max mem: 10452
# Epoch: [5]  [120/279]  eta: 0:02:39  lr: 0.000500  loss: 0.0252 (0.0240)  loss_classifier: 0.0116 (0.0105)  loss_box_reg: 0.0108 (0.0120)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0008 (0.0008)  time: 1.0010  data: 0.0307  max mem: 10452
# Epoch: [5]  [130/279]  eta: 0:02:29  lr: 0.000500  loss: 0.0275 (0.0242)  loss_classifier: 0.0110 (0.0106)  loss_box_reg: 0.0147 (0.0122)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0008 (0.0008)  time: 1.0027  data: 0.0311  max mem: 10452
# Epoch: [5]  [140/279]  eta: 0:02:19  lr: 0.000500  loss: 0.0229 (0.0243)  loss_classifier: 0.0087 (0.0106)  loss_box_reg: 0.0130 (0.0122)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0008 (0.0008)  time: 1.0026  data: 0.0308  max mem: 10452
# Epoch: [5]  [150/279]  eta: 0:02:09  lr: 0.000500  loss: 0.0186 (0.0240)  loss_classifier: 0.0072 (0.0104)  loss_box_reg: 0.0106 (0.0121)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 1.0024  data: 0.0317  max mem: 10452
# Epoch: [5]  [160/279]  eta: 0:01:59  lr: 0.000500  loss: 0.0177 (0.0237)  loss_classifier: 0.0061 (0.0103)  loss_box_reg: 0.0095 (0.0119)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 0.9991  data: 0.0324  max mem: 10452
# Epoch: [5]  [170/279]  eta: 0:01:49  lr: 0.000500  loss: 0.0187 (0.0238)  loss_classifier: 0.0081 (0.0103)  loss_box_reg: 0.0101 (0.0120)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.9973  data: 0.0311  max mem: 10452
# Epoch: [5]  [180/279]  eta: 0:01:39  lr: 0.000500  loss: 0.0207 (0.0238)  loss_classifier: 0.0081 (0.0103)  loss_box_reg: 0.0111 (0.0120)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0007 (0.0008)  time: 1.0000  data: 0.0297  max mem: 10452
# Epoch: [5]  [190/279]  eta: 0:01:29  lr: 0.000500  loss: 0.0202 (0.0237)  loss_classifier: 0.0075 (0.0103)  loss_box_reg: 0.0107 (0.0119)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 0.9979  data: 0.0294  max mem: 10452
# Epoch: [5]  [200/279]  eta: 0:01:19  lr: 0.000500  loss: 0.0200 (0.0235)  loss_classifier: 0.0074 (0.0102)  loss_box_reg: 0.0106 (0.0119)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 0.9969  data: 0.0290  max mem: 10452
# Epoch: [5]  [210/279]  eta: 0:01:09  lr: 0.000500  loss: 0.0181 (0.0234)  loss_classifier: 0.0073 (0.0101)  loss_box_reg: 0.0096 (0.0118)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 1.0006  data: 0.0299  max mem: 10452
# Epoch: [5]  [220/279]  eta: 0:00:59  lr: 0.000500  loss: 0.0208 (0.0235)  loss_classifier: 0.0078 (0.0102)  loss_box_reg: 0.0111 (0.0118)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 1.0028  data: 0.0316  max mem: 10452
# Epoch: [5]  [230/279]  eta: 0:00:49  lr: 0.000500  loss: 0.0198 (0.0233)  loss_classifier: 0.0077 (0.0101)  loss_box_reg: 0.0111 (0.0118)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 1.0018  data: 0.0321  max mem: 10452
# Epoch: [5]  [240/279]  eta: 0:00:39  lr: 0.000500  loss: 0.0175 (0.0233)  loss_classifier: 0.0079 (0.0101)  loss_box_reg: 0.0097 (0.0118)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 0.9978  data: 0.0301  max mem: 10452
# Epoch: [5]  [250/279]  eta: 0:00:29  lr: 0.000500  loss: 0.0217 (0.0233)  loss_classifier: 0.0093 (0.0101)  loss_box_reg: 0.0114 (0.0118)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.9995  data: 0.0304  max mem: 10452
# Epoch: [5]  [260/279]  eta: 0:00:19  lr: 0.000500  loss: 0.0236 (0.0238)  loss_classifier: 0.0100 (0.0103)  loss_box_reg: 0.0122 (0.0119)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0008 (0.0008)  time: 1.0018  data: 0.0304  max mem: 10452
# Epoch: [5]  [270/279]  eta: 0:00:09  lr: 0.000500  loss: 0.0199 (0.0237)  loss_classifier: 0.0085 (0.0103)  loss_box_reg: 0.0107 (0.0119)  loss_objectness: 0.0004 (0.0008)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 0.9975  data: 0.0278  max mem: 10452
# Epoch: [5]  [278/279]  eta: 0:00:01  lr: 0.000500  loss: 0.0188 (0.0236)  loss_classifier: 0.0069 (0.0102)  loss_box_reg: 0.0098 (0.0119)  loss_objectness: 0.0002 (0.0008)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 0.9947  data: 0.0265  max mem: 10452
# Epoch: [5] Total time: 0:04:39 (1.0023 s / it)
# Epoch: [6]  [  0/279]  eta: 0:07:57  lr: 0.000050  loss: 0.0280 (0.0280)  loss_classifier: 0.0142 (0.0142)  loss_box_reg: 0.0125 (0.0125)  loss_objectness: 0.0006 (0.0006)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 1.7098  data: 0.7333  max mem: 10452
# Epoch: [6]  [ 10/279]  eta: 0:04:45  lr: 0.000050  loss: 0.0176 (0.0210)  loss_classifier: 0.0083 (0.0094)  loss_box_reg: 0.0084 (0.0106)  loss_objectness: 0.0002 (0.0003)  loss_rpn_box_reg: 0.0006 (0.0006)  time: 1.0605  data: 0.0883  max mem: 10452
# Epoch: [6]  [ 20/279]  eta: 0:04:28  lr: 0.000050  loss: 0.0148 (0.0210)  loss_classifier: 0.0059 (0.0092)  loss_box_reg: 0.0082 (0.0107)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0005 (0.0006)  time: 1.0010  data: 0.0279  max mem: 10452
# Epoch: [6]  [ 30/279]  eta: 0:04:15  lr: 0.000050  loss: 0.0182 (0.0213)  loss_classifier: 0.0076 (0.0092)  loss_box_reg: 0.0097 (0.0108)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 1.0044  data: 0.0312  max mem: 10452
# Epoch: [6]  [ 40/279]  eta: 0:04:03  lr: 0.000050  loss: 0.0182 (0.0212)  loss_classifier: 0.0076 (0.0091)  loss_box_reg: 0.0102 (0.0109)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0005 (0.0006)  time: 1.0020  data: 0.0285  max mem: 10452
# Epoch: [6]  [ 50/279]  eta: 0:03:52  lr: 0.000050  loss: 0.0204 (0.0214)  loss_classifier: 0.0077 (0.0090)  loss_box_reg: 0.0113 (0.0111)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 1.0028  data: 0.0291  max mem: 10452
# Epoch: [6]  [ 60/279]  eta: 0:03:42  lr: 0.000050  loss: 0.0208 (0.0213)  loss_classifier: 0.0085 (0.0090)  loss_box_reg: 0.0113 (0.0110)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 1.0034  data: 0.0309  max mem: 10452
# Epoch: [6]  [ 70/279]  eta: 0:03:31  lr: 0.000050  loss: 0.0190 (0.0213)  loss_classifier: 0.0075 (0.0090)  loss_box_reg: 0.0100 (0.0110)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 1.0000  data: 0.0303  max mem: 10452
# Epoch: [6]  [ 80/279]  eta: 0:03:20  lr: 0.000050  loss: 0.0183 (0.0213)  loss_classifier: 0.0073 (0.0090)  loss_box_reg: 0.0101 (0.0110)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 0.9973  data: 0.0290  max mem: 10452
# Epoch: [6]  [ 90/279]  eta: 0:03:10  lr: 0.000050  loss: 0.0176 (0.0216)  loss_classifier: 0.0076 (0.0092)  loss_box_reg: 0.0100 (0.0111)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 1.0013  data: 0.0283  max mem: 10452
# Epoch: [6]  [100/279]  eta: 0:03:00  lr: 0.000050  loss: 0.0157 (0.0213)  loss_classifier: 0.0062 (0.0090)  loss_box_reg: 0.0083 (0.0109)  loss_objectness: 0.0001 (0.0007)  loss_rpn_box_reg: 0.0004 (0.0007)  time: 1.0031  data: 0.0292  max mem: 10452
# Epoch: [6]  [110/279]  eta: 0:02:50  lr: 0.000050  loss: 0.0178 (0.0221)  loss_classifier: 0.0071 (0.0094)  loss_box_reg: 0.0102 (0.0112)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 1.0016  data: 0.0300  max mem: 10452
# Epoch: [6]  [120/279]  eta: 0:02:40  lr: 0.000050  loss: 0.0216 (0.0222)  loss_classifier: 0.0096 (0.0096)  loss_box_reg: 0.0109 (0.0112)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 1.0028  data: 0.0323  max mem: 10452
# Epoch: [6]  [130/279]  eta: 0:02:30  lr: 0.000050  loss: 0.0216 (0.0224)  loss_classifier: 0.0096 (0.0097)  loss_box_reg: 0.0107 (0.0113)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 1.0008  data: 0.0329  max mem: 10452
# Epoch: [6]  [140/279]  eta: 0:02:19  lr: 0.000050  loss: 0.0195 (0.0221)  loss_classifier: 0.0072 (0.0095)  loss_box_reg: 0.0103 (0.0112)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 0.9984  data: 0.0324  max mem: 10452
# Epoch: [6]  [150/279]  eta: 0:02:09  lr: 0.000050  loss: 0.0177 (0.0222)  loss_classifier: 0.0071 (0.0095)  loss_box_reg: 0.0105 (0.0113)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 0.9998  data: 0.0308  max mem: 10452
# ...
# Epoch: [22]  [250/279]  eta: 0:00:29  lr: 0.000000  loss: 0.0200 (0.0225)  loss_classifier: 0.0080 (0.0098)  loss_box_reg: 0.0103 (0.0111)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 1.0059  data: 0.0317  max mem: 10452
# Epoch: [22]  [260/279]  eta: 0:00:19  lr: 0.000000  loss: 0.0164 (0.0222)  loss_classifier: 0.0066 (0.0097)  loss_box_reg: 0.0089 (0.0110)  loss_objectness: 0.0001 (0.0008)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 1.0051  data: 0.0309  max mem: 10452
# Epoch: [22]  [270/279]  eta: 0:00:09  lr: 0.000000  loss: 0.0162 (0.0222)  loss_classifier: 0.0066 (0.0097)  loss_box_reg: 0.0097 (0.0110)  loss_objectness: 0.0001 (0.0008)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 1.0028  data: 0.0294  max mem: 10452
# Epoch: [22]  [278/279]  eta: 0:00:01  lr: 0.000000  loss: 0.0164 (0.0221)  loss_classifier: 0.0064 (0.0097)  loss_box_reg: 0.0097 (0.0109)  loss_objectness: 0.0001 (0.0008)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 0.9997  data: 0.0292  max mem: 10452
# Epoch: [22] Total time: 0:04:40 (1.0036 s / it)
# Epoch: [23]  [  0/279]  eta: 0:07:41  lr: 0.000000  loss: 0.0343 (0.0343)  loss_classifier: 0.0156 (0.0156)  loss_box_reg: 0.0146 (0.0146)  loss_objectness: 0.0028 (0.0028)  loss_rpn_box_reg: 0.0012 (0.0012)  time: 1.6558  data: 0.6609  max mem: 10452
# Epoch: [23]  [ 10/279]  eta: 0:04:43  lr: 0.000000  loss: 0.0166 (0.0204)  loss_classifier: 0.0071 (0.0089)  loss_box_reg: 0.0085 (0.0098)  loss_objectness: 0.0002 (0.0010)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 1.0551  data: 0.0829  max mem: 10452
# Epoch: [23]  [ 20/279]  eta: 0:04:26  lr: 0.000000  loss: 0.0214 (0.0255)  loss_classifier: 0.0077 (0.0116)  loss_box_reg: 0.0091 (0.0120)  loss_objectness: 0.0003 (0.0011)  loss_rpn_box_reg: 0.0006 (0.0009)  time: 0.9981  data: 0.0289  max mem: 10452
# Epoch: [23]  [ 30/279]  eta: 0:04:14  lr: 0.000000  loss: 0.0214 (0.0243)  loss_classifier: 0.0096 (0.0109)  loss_box_reg: 0.0100 (0.0116)  loss_objectness: 0.0003 (0.0009)  loss_rpn_box_reg: 0.0006 (0.0008)  time: 1.0011  data: 0.0311  max mem: 10452
# Epoch: [23]  [ 40/279]  eta: 0:04:02  lr: 0.000000  loss: 0.0165 (0.0240)  loss_classifier: 0.0071 (0.0107)  loss_box_reg: 0.0090 (0.0117)  loss_objectness: 0.0002 (0.0008)  loss_rpn_box_reg: 0.0005 (0.0008)  time: 1.0020  data: 0.0300  max mem: 10452
# Epoch: [23]  [ 50/279]  eta: 0:03:52  lr: 0.000000  loss: 0.0181 (0.0233)  loss_classifier: 0.0070 (0.0104)  loss_box_reg: 0.0102 (0.0114)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 1.0041  data: 0.0310  max mem: 10452
# Epoch: [23]  [ 60/279]  eta: 0:03:41  lr: 0.000000  loss: 0.0194 (0.0234)  loss_classifier: 0.0089 (0.0105)  loss_box_reg: 0.0102 (0.0114)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 1.0041  data: 0.0304  max mem: 10452
# Epoch: [23]  [ 70/279]  eta: 0:03:31  lr: 0.000000  loss: 0.0194 (0.0229)  loss_classifier: 0.0089 (0.0103)  loss_box_reg: 0.0108 (0.0113)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 1.0026  data: 0.0286  max mem: 10452
# Epoch: [23]  [ 80/279]  eta: 0:03:20  lr: 0.000000  loss: 0.0194 (0.0228)  loss_classifier: 0.0075 (0.0102)  loss_box_reg: 0.0106 (0.0113)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 1.0037  data: 0.0302  max mem: 10452
# Epoch: [23]  [ 90/279]  eta: 0:03:10  lr: 0.000000  loss: 0.0195 (0.0223)  loss_classifier: 0.0081 (0.0099)  loss_box_reg: 0.0103 (0.0111)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 1.0009  data: 0.0298  max mem: 10452
# Epoch: [23]  [100/279]  eta: 0:03:00  lr: 0.000000  loss: 0.0165 (0.0218)  loss_classifier: 0.0066 (0.0096)  loss_box_reg: 0.0093 (0.0109)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 0.9976  data: 0.0287  max mem: 10452
# Epoch: [23]  [110/279]  eta: 0:02:50  lr: 0.000000  loss: 0.0156 (0.0220)  loss_classifier: 0.0065 (0.0098)  loss_box_reg: 0.0090 (0.0110)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 0.9995  data: 0.0299  max mem: 10452
# Epoch: [23]  [120/279]  eta: 0:02:40  lr: 0.000000  loss: 0.0156 (0.0217)  loss_classifier: 0.0066 (0.0096)  loss_box_reg: 0.0089 (0.0108)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0004 (0.0007)  time: 1.0023  data: 0.0317  max mem: 10452
# Epoch: [23]  [130/279]  eta: 0:02:29  lr: 0.000000  loss: 0.0158 (0.0218)  loss_classifier: 0.0073 (0.0096)  loss_box_reg: 0.0088 (0.0109)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0004 (0.0007)  time: 1.0034  data: 0.0320  max mem: 10452
# Epoch: [23]  [140/279]  eta: 0:02:19  lr: 0.000000  loss: 0.0164 (0.0217)  loss_classifier: 0.0070 (0.0095)  loss_box_reg: 0.0101 (0.0109)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 1.0029  data: 0.0298  max mem: 10452
# Epoch: [23]  [150/279]  eta: 0:02:09  lr: 0.000000  loss: 0.0186 (0.0218)  loss_classifier: 0.0070 (0.0096)  loss_box_reg: 0.0104 (0.0109)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 1.0036  data: 0.0299  max mem: 10452
# Epoch: [23]  [160/279]  eta: 0:01:59  lr: 0.000000  loss: 0.0230 (0.0222)  loss_classifier: 0.0100 (0.0098)  loss_box_reg: 0.0125 (0.0111)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 1.0009  data: 0.0296  max mem: 10452
# Epoch: [23]  [170/279]  eta: 0:01:49  lr: 0.000000  loss: 0.0250 (0.0224)  loss_classifier: 0.0124 (0.0099)  loss_box_reg: 0.0125 (0.0112)  loss_objectness: 0.0004 (0.0006)  loss_rpn_box_reg: 0.0008 (0.0007)  time: 0.9975  data: 0.0295  max mem: 10452
# Epoch: [23]  [180/279]  eta: 0:01:39  lr: 0.000000  loss: 0.0155 (0.0221)  loss_classifier: 0.0071 (0.0098)  loss_box_reg: 0.0084 (0.0111)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 0.9995  data: 0.0309  max mem: 10452
# Epoch: [23]  [190/279]  eta: 0:01:29  lr: 0.000000  loss: 0.0186 (0.0221)  loss_classifier: 0.0068 (0.0097)  loss_box_reg: 0.0087 (0.0111)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 1.0023  data: 0.0314  max mem: 10452
# Epoch: [23]  [200/279]  eta: 0:01:19  lr: 0.000000  loss: 0.0216 (0.0220)  loss_classifier: 0.0098 (0.0097)  loss_box_reg: 0.0094 (0.0110)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 1.0017  data: 0.0293  max mem: 10452
# Epoch: [23]  [210/279]  eta: 0:01:09  lr: 0.000000  loss: 0.0156 (0.0218)  loss_classifier: 0.0083 (0.0096)  loss_box_reg: 0.0083 (0.0109)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 1.0026  data: 0.0293  max mem: 10452
# Epoch: [23]  [220/279]  eta: 0:00:59  lr: 0.000000  loss: 0.0155 (0.0218)  loss_classifier: 0.0083 (0.0096)  loss_box_reg: 0.0083 (0.0109)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 1.0044  data: 0.0308  max mem: 10452
# Epoch: [23]  [230/279]  eta: 0:00:49  lr: 0.000000  loss: 0.0146 (0.0215)  loss_classifier: 0.0075 (0.0095)  loss_box_reg: 0.0072 (0.0108)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0004 (0.0007)  time: 0.9995  data: 0.0288  max mem: 10452
# Epoch: [23]  [240/279]  eta: 0:00:39  lr: 0.000000  loss: 0.0146 (0.0215)  loss_classifier: 0.0071 (0.0095)  loss_box_reg: 0.0074 (0.0108)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0004 (0.0007)  time: 0.9975  data: 0.0281  max mem: 10452
# Epoch: [23]  [250/279]  eta: 0:00:29  lr: 0.000000  loss: 0.0168 (0.0214)  loss_classifier: 0.0072 (0.0095)  loss_box_reg: 0.0100 (0.0108)  loss_objectness: 0.0001 (0.0005)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 1.0020  data: 0.0299  max mem: 10452
# Epoch: [23]  [260/279]  eta: 0:00:19  lr: 0.000000  loss: 0.0190 (0.0216)  loss_classifier: 0.0081 (0.0095)  loss_box_reg: 0.0102 (0.0108)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 1.0036  data: 0.0303  max mem: 10452
# Epoch: [23]  [270/279]  eta: 0:00:09  lr: 0.000000  loss: 0.0210 (0.0217)  loss_classifier: 0.0088 (0.0095)  loss_box_reg: 0.0124 (0.0109)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 1.0005  data: 0.0281  max mem: 10452
# Epoch: [23]  [278/279]  eta: 0:00:01  lr: 0.000000  loss: 0.0236 (0.0218)  loss_classifier: 0.0095 (0.0096)  loss_box_reg: 0.0122 (0.0110)  loss_objectness: 0.0003 (0.0005)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 0.9959  data: 0.0269  max mem: 10452
# Epoch: [23] Total time: 0:04:40 (1.0037 s / it)
# Epoch: [24]  [  0/279]  eta: 0:07:31  lr: 0.000000  loss: 0.0305 (0.0305)  loss_classifier: 0.0143 (0.0143)  loss_box_reg: 0.0144 (0.0144)  loss_objectness: 0.0010 (0.0010)  loss_rpn_box_reg: 0.0008 (0.0008)  time: 1.6189  data: 0.6264  max mem: 10452
# Epoch: [24]  [ 10/279]  eta: 0:04:44  lr: 0.000000  loss: 0.0269 (0.0239)  loss_classifier: 0.0120 (0.0103)  loss_box_reg: 0.0130 (0.0117)  loss_objectness: 0.0005 (0.0011)  loss_rpn_box_reg: 0.0008 (0.0008)  time: 1.0587  data: 0.0862  max mem: 10452
# Epoch: [24]  [ 20/279]  eta: 0:04:27  lr: 0.000000  loss: 0.0202 (0.0216)  loss_classifier: 0.0085 (0.0094)  loss_box_reg: 0.0093 (0.0108)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 1.0024  data: 0.0311  max mem: 10452
# Epoch: [24]  [ 30/279]  eta: 0:04:14  lr: 0.000000  loss: 0.0214 (0.0221)  loss_classifier: 0.0092 (0.0098)  loss_box_reg: 0.0093 (0.0109)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 1.0025  data: 0.0300  max mem: 10452
# Epoch: [24]  [ 40/279]  eta: 0:04:03  lr: 0.000000  loss: 0.0219 (0.0221)  loss_classifier: 0.0096 (0.0097)  loss_box_reg: 0.0105 (0.0110)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 1.0028  data: 0.0302  max mem: 10452
# Epoch: [24]  [ 50/279]  eta: 0:03:51  lr: 0.000000  loss: 0.0165 (0.0213)  loss_classifier: 0.0065 (0.0093)  loss_box_reg: 0.0094 (0.0108)  loss_objectness: 0.0001 (0.0005)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 0.9982  data: 0.0291  max mem: 10452
# Epoch: [24]  [ 60/279]  eta: 0:03:41  lr: 0.000000  loss: 0.0163 (0.0216)  loss_classifier: 0.0064 (0.0096)  loss_box_reg: 0.0094 (0.0108)  loss_objectness: 0.0001 (0.0005)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 0.9979  data: 0.0296  max mem: 10452
# Epoch: [24]  [ 70/279]  eta: 0:03:31  lr: 0.000000  loss: 0.0183 (0.0216)  loss_classifier: 0.0068 (0.0095)  loss_box_reg: 0.0104 (0.0110)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 1.0012  data: 0.0299  max mem: 10452
# Epoch: [24]  [ 80/279]  eta: 0:03:20  lr: 0.000000  loss: 0.0226 (0.0221)  loss_classifier: 0.0096 (0.0097)  loss_box_reg: 0.0118 (0.0112)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 0.9982  data: 0.0285  max mem: 10452
# Epoch: [24]  [ 90/279]  eta: 0:03:10  lr: 0.000000  loss: 0.0248 (0.0234)  loss_classifier: 0.0108 (0.0104)  loss_box_reg: 0.0113 (0.0117)  loss_objectness: 0.0002 (0.0005)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 0.9960  data: 0.0275  max mem: 10452
# Epoch: [24]  [100/279]  eta: 0:03:00  lr: 0.000000  loss: 0.0201 (0.0231)  loss_classifier: 0.0075 (0.0102)  loss_box_reg: 0.0103 (0.0116)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 0.9990  data: 0.0274  max mem: 10452
# Epoch: [24]  [110/279]  eta: 0:02:49  lr: 0.000000  loss: 0.0199 (0.0232)  loss_classifier: 0.0074 (0.0102)  loss_box_reg: 0.0104 (0.0117)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 0.9988  data: 0.0284  max mem: 10452
# Epoch: [24]  [120/279]  eta: 0:02:39  lr: 0.000000  loss: 0.0203 (0.0234)  loss_classifier: 0.0080 (0.0103)  loss_box_reg: 0.0109 (0.0117)  loss_objectness: 0.0003 (0.0006)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 0.9974  data: 0.0305  max mem: 10452
# Epoch: [24]  [130/279]  eta: 0:02:29  lr: 0.000000  loss: 0.0185 (0.0233)  loss_classifier: 0.0083 (0.0103)  loss_box_reg: 0.0092 (0.0116)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 1.0017  data: 0.0316  max mem: 10452
# Epoch: [24]  [140/279]  eta: 0:02:19  lr: 0.000000  loss: 0.0185 (0.0231)  loss_classifier: 0.0079 (0.0102)  loss_box_reg: 0.0088 (0.0115)  loss_objectness: 0.0002 (0.0006)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 1.0033  data: 0.0311  max mem: 10452
# Epoch: [24]  [150/279]  eta: 0:02:09  lr: 0.000000  loss: 0.0219 (0.0233)  loss_classifier: 0.0079 (0.0102)  loss_box_reg: 0.0118 (0.0116)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0008 (0.0007)  time: 1.0013  data: 0.0298  max mem: 10452
# Epoch: [24]  [160/279]  eta: 0:01:59  lr: 0.000000  loss: 0.0169 (0.0230)  loss_classifier: 0.0070 (0.0101)  loss_box_reg: 0.0098 (0.0115)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 0.9985  data: 0.0299  max mem: 10452
# Epoch: [24]  [170/279]  eta: 0:01:49  lr: 0.000000  loss: 0.0196 (0.0229)  loss_classifier: 0.0078 (0.0100)  loss_box_reg: 0.0100 (0.0115)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 0.9985  data: 0.0301  max mem: 10452
# Epoch: [24]  [180/279]  eta: 0:01:39  lr: 0.000000  loss: 0.0199 (0.0230)  loss_classifier: 0.0089 (0.0100)  loss_box_reg: 0.0108 (0.0115)  loss_objectness: 0.0004 (0.0007)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 1.0006  data: 0.0301  max mem: 10452
# Epoch: [24]  [190/279]  eta: 0:01:29  lr: 0.000000  loss: 0.0196 (0.0228)  loss_classifier: 0.0079 (0.0100)  loss_box_reg: 0.0097 (0.0113)  loss_objectness: 0.0003 (0.0007)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 1.0028  data: 0.0311  max mem: 10452
# Epoch: [24]  [200/279]  eta: 0:01:19  lr: 0.000000  loss: 0.0196 (0.0229)  loss_classifier: 0.0079 (0.0100)  loss_box_reg: 0.0097 (0.0114)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0006 (0.0007)  time: 0.9996  data: 0.0286  max mem: 10452
# Epoch: [24]  [210/279]  eta: 0:01:09  lr: 0.000000  loss: 0.0168 (0.0228)  loss_classifier: 0.0084 (0.0100)  loss_box_reg: 0.0093 (0.0113)  loss_objectness: 0.0002 (0.0008)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 0.9947  data: 0.0266  max mem: 10452
# Epoch: [24]  [220/279]  eta: 0:00:59  lr: 0.000000  loss: 0.0168 (0.0226)  loss_classifier: 0.0073 (0.0099)  loss_box_reg: 0.0094 (0.0112)  loss_objectness: 0.0002 (0.0008)  loss_rpn_box_reg: 0.0004 (0.0007)  time: 0.9972  data: 0.0281  max mem: 10452
# Epoch: [24]  [230/279]  eta: 0:00:49  lr: 0.000000  loss: 0.0168 (0.0224)  loss_classifier: 0.0060 (0.0097)  loss_box_reg: 0.0098 (0.0112)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0004 (0.0007)  time: 0.9978  data: 0.0303  max mem: 10452
# Epoch: [24]  [240/279]  eta: 0:00:39  lr: 0.000000  loss: 0.0168 (0.0223)  loss_classifier: 0.0068 (0.0097)  loss_box_reg: 0.0096 (0.0111)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 0.9978  data: 0.0300  max mem: 10452
# Epoch: [24]  [250/279]  eta: 0:00:29  lr: 0.000000  loss: 0.0175 (0.0220)  loss_classifier: 0.0070 (0.0096)  loss_box_reg: 0.0090 (0.0110)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0004 (0.0007)  time: 1.0001  data: 0.0285  max mem: 10452
# Epoch: [24]  [260/279]  eta: 0:00:19  lr: 0.000000  loss: 0.0182 (0.0221)  loss_classifier: 0.0086 (0.0096)  loss_box_reg: 0.0093 (0.0110)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0005 (0.0007)  time: 0.9982  data: 0.0296  max mem: 10452
# Epoch: [24]  [270/279]  eta: 0:00:09  lr: 0.000000  loss: 0.0238 (0.0221)  loss_classifier: 0.0101 (0.0096)  loss_box_reg: 0.0102 (0.0110)  loss_objectness: 0.0002 (0.0007)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 0.9982  data: 0.0308  max mem: 10452
# Epoch: [24]  [278/279]  eta: 0:00:01  lr: 0.000000  loss: 0.0267 (0.0222)  loss_classifier: 0.0113 (0.0097)  loss_box_reg: 0.0117 (0.0111)  loss_objectness: 0.0003 (0.0008)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 1.0007  data: 0.0313  max mem: 10452
# Epoch: [24] Total time: 0:04:39 (1.0021 s / it)

# %% [markdown]
# Saving Model

# %%
# %cd '/drive/MyDrive/CSE499 Project/modelSaves/Attention Mechanism/ChannelSpatial/SCNet/model3augmented'
# %cd '/drive/MyDrive/CSE499 Project/modelSaves/Attention Mechanism/ChannelSpatial/SCNet/model1pretrained'

torch.save(model.state_dict(), 'model.pth')

torch.save({
'epoch':num_epochs,
'model_state_dict':model.state_dict(),
'optimizer_state_dict':optimizer.state_dict(),
},'ckpt.pth')

# %% [markdown]
# Loading model

# %%
# %cd '/drive/MyDrive/CSE499 Project/modelSaves/Attention Mechanism/ChannelSpatial/SCNet/model3augmented'
# %cd '/drive/MyDrive/CSE499 Project/modelSaves/Attention Mechanism/ChannelSpatial/SCNet/model2augmented'
# %cd '/drive/MyDrive/CSE499 Project/modelSaves/Attention Mechanism/ChannelSpatial/SCNet/model1augmented'
# %cd '/drive/MyDrive/CSE499 Project/modelSaves/Attention Mechanism/ChannelSpatial/SCNet/model1pretrained'
# %cd '/drive/MyDrive/CSE499 Project/modelSaves/Attention Mechanism/ChannelSpatial/SCNet/model2'
# %cd '/drive/MyDrive/CSE499 Project/modelSaves/Attention Mechanism/ChannelSpatial/SCNet/model2pretrained'


model.load_state_dict(torch.load('./model.pth'))
model = model.to(device)
# Out:
# /drive/.shortcut-targets-by-id/1M-kTVs7g43FucvCjcPvKwiR8r1e1qtHe/CSE499_Project/modelSaves/Attention Mechanism/ChannelSpatial/SCNet/model3augmented

# %% [markdown]
# #Testing

# %%
test_dataset = MitosisImagesDatasetTest(test_dir, 481, 451,transforms=get_transform(train=False))

torch.manual_seed(1)
indices = torch.randperm(len(dataset_test)).tolist()

test_split = 0.2
tsize = int(len(test_dataset)*test_split)

test_dataset = torch.utils.data.Subset(test_dataset, indices[-tsize:])

test_data_loader = torch.utils.data.DataLoader(
  test_dataset,
  batch_size=8,
  shuffle=False,
  num_workers=4,
  collate_fn=utils.collate_fn,
)
test_dir
# Out:
# '/drive/MyDrive/CSE499 Project/Patch Datasets/Hamamatsu S360/'

# %%
def apply_nms(orig_prediction, iou_thresh=0.3):
  keep = torchvision.ops.nms(orig_prediction['boxes'], orig_prediction['scores'], iou_thresh)
  
  final_prediction = orig_prediction
  final_prediction['boxes'] = final_prediction['boxes'][keep]
  final_prediction['scores'] = final_prediction['scores'][keep]
  final_prediction['labels'] = final_prediction['labels'][keep]
  
  return final_prediction

# function to convert a torchtensor back to PIL image
def torch_to_pil(img):
  return torchtrans.ToPILImage()(img).convert('RGB')

# %%
test_dataset = MitosisImagesDatasetTest(test_dir, 481, 451, transforms = get_transform(train=False))
dataset      = MitosisImagesDatasetTest(test_dir, 481, 451)
test_dir
# Out:
# '/drive/MyDrive/CSE499 Project/Patch Datasets/Hamamatsu S360/'

# %% [markdown]
# Predicted labels

# %%
# pick one image from the test set
INDEX_PICK = 205
model=model.to('cpu')
img, target = test_dataset[INDEX_PICK]
# put the model in evaluation mode
model.eval()
with torch.no_grad():
  img = img.to('cpu')
  prediction = model([img])[0]

print('MODEL OUTPUT\n')
nms_prediction = apply_nms(prediction,iou_thresh=0.3)

plot_img_bbox(torch_to_pil(img), nms_prediction)
# Out:
# MODEL OUTPUT

# %% [markdown]
# Ground Truth labels

# %%
img, target = dataset[INDEX_PICK]
plot_img_bbox(img, target)

# %%
def make_prediction(model, img, threshold):
    model.eval()
    preds = model(img)
    for id in range(len(preds)) :
        idx_list = []

        for idx, score in enumerate(preds[id]['scores']) :
            if score > threshold : 
                idx_list.append(idx)

        preds[id]['boxes'] = preds[id]['boxes'][idx_list]
        preds[id]['labels'] = preds[id]['labels'][idx_list]
        preds[id]['scores'] = preds[id]['scores'][idx_list]

    return preds

# %%
model=model.to(device)

# %%
from tqdm import tqdm

labels = []
preds_adj_all = []
annot_all = []

for im, annot in tqdm(test_data_loader, position = 0, leave = True):
    im = list(img.to(device) for img in im)
    #annot = [{k: v.to(device) for k, v in t.items()} for t in annot]

    for t in annot:
        labels += t['labels']

    with torch.no_grad():
        preds_adj = make_prediction(model, im, 0.3)
        preds_adj = [{k: v.to(torch.device('cpu')) for k, v in t.items()} for t in preds_adj]
        preds_adj_all.append(preds_adj)
        annot_all.append(annot)
# Out:
# 100%|██████████| 47/47 [00:42<00:00,  1.12it/s]

# %%
# %cd /content/Tutorial-Book-Utils
import utils_ObjectDetection as utils2
# Out:
# /content/Tutorial-Book-Utils

# %% [markdown]
# Trained on Dataset X, Tested on Dataset Y

# %%
sample_metrics = []
for batch_i in range(len(preds_adj_all)):
    sample_metrics += utils2.get_batch_statistics(preds_adj_all[batch_i], annot_all[batch_i], iou_threshold=0.3) 

true_positives, pred_scores, pred_labels = [torch.cat(x, 0) for x in list(zip(*sample_metrics))]
precision, recall, AP, f1, ap_class = utils2.ap_per_class(true_positives, pred_scores, pred_labels, torch.tensor(labels))
mAP = torch.mean(AP)
print(f'mAP : {mAP}')
# print(f'AP : {AP}')
# Out:
# mAP : 0.72436448474729

# %%
print('precision: ',precision)
print('recall: ',recall)
print('AP: ',AP)
print('f1: ',f1)
print('ap_class: ',ap_class)
# Out:
# precision:  tensor([0.7953])
# recall:  tensor([0.7711])
# AP:  tensor([0.7243], dtype=torch.float64)
# f1:  tensor([0.7830])
# ap_class:  tensor([1])

# %%
print(train_dir)
print(test_dir)
# Out:
# /drive/MyDrive/CSE499 Project/Patch Datasets/Aperio ScanScope CS2/
# /drive/MyDrive/CSE499 Project/Patch Datasets/Hamamatsu S360/
