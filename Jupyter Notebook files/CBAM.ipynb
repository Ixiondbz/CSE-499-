# %% [markdown]
# #Installing libraries etc.

# %%
from IPython.display import clear_output
# %load_ext autoreload
# %autoreload 2
# Install dependencies and 
# !pip install albumentations==0.4.6
# !pip install pycocotools --quiet

# !git clone https://github.com/Pseudo-Lab/Tutorial-Book-Utils
# !python Tutorial-Book-Utils/PL_data_loader.py --data FaceMaskDetection

# Clone TorchVision repo and copy helper files
# !git clone https://github.com/pytorch/vision.git
# %cd vision
# !git checkout v0.3.0
# %cd ..
# !cp vision/references/detection/utils.py ./
# !cp vision/references/detection/transforms.py ./
# !cp vision/references/detection/coco_eval.py ./
# !cp vision/references/detection/engine.py ./
# !cp vision/references/detection/coco_utils.py ./


# basic python and ML Libraries
import os
import random
import numpy as np
import pandas as pd

# for ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# We will be reading images using OpenCV
import cv2

# matplotlib for visualization
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# torchvision libraries
import torch
import torchvision
from torchvision import transforms as torchtrans  
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.backbone_utils import resnet_fpn_backbone

from torchvision.models.detection.rpn import AnchorGenerator

import torch.nn as nn
import torch.nn.functional as F

# helper libraries
from engine import train_one_epoch, evaluate
import utils
import transforms as T

# for image augmentations
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

# !apt-get install python3-openslide
from openslide import open_slide

import plotly.express as px
clear_output()

# %%
from torchvision.models.detection import FasterRCNN
from torch.utils.data import DataLoader, Dataset
import sys
import os
from torchvision.ops import misc as misc_nn_ops

import torch.hub
from functools import partial
from typing import Type, Any, Callable, Union, List, Optional
import torch
import warnings
from typing import Callable, Dict, List, Optional, Union
from torch import nn, Tensor
from torchvision.ops import misc as misc_nn_ops
from torchvision.ops.feature_pyramid_network import ExtraFPNBlock, FeaturePyramidNetwork, LastLevelMaxPool
from collections import OrderedDict
from torchvision.models import resnet 
from torch.hub import load_state_dict_from_url
import enum
from typing import Sequence, TypeVar, Type
from dataclasses import dataclass,fields

T = TypeVar("T", bound=enum.Enum)


class StrEnumMeta(enum.EnumMeta):
    auto = enum.auto

    def from_str(self: Type[T], member: str) -> T:  # type: ignore[misc]
        try:
            return self[member]
        except KeyError:
            # TODO: use `add_suggestion` from torchvision.prototype.utils._internal to improve the error message as
            #  soon as it is migrated.
            raise ValueError(f"Unknown value '{member}' for {self.__name__}.") from None


class StrEnum(enum.Enum, metaclass=StrEnumMeta):
    pass

@dataclass
class Weights:
    """
    This class is used to group important attributes associated with the pre-trained weights.
    Args:
        url (str): The location where we find the weights.
        transforms (Callable): A callable that constructs the preprocessing method (or validation preset transforms)
            needed to use the model. The reason we attach a constructor method rather than an already constructed
            object is because the specific object might have memory and thus we want to delay initialization until
            needed.
        meta (Dict[str, Any]): Stores meta-data related to the weights of the model and its configuration. These can be
            informative attributes (for example the number of parameters/flops, recipe link/methods used in training
            etc), configuration parameters (for example the `num_classes`) needed to construct the model or important
            meta-data (for example the `classes` of a classification model) needed to use the model.
    """

    url: str
    transforms: Callable
    meta: Dict[str, Any]

class WeightsEnum(StrEnum):
    """
    This class is the parent class of all model weights. Each model building method receives an optional `weights`
    parameter with its associated pre-trained weights. It inherits from `Enum` and its values should be of type
    `Weights`.
    Args:
        value (Weights): The data class entry with the weight information.
    """

    def __init__(self, value: Weights):
        self._value_ = value

    @classmethod
    def verify(cls, obj: Any) -> Any:
        if obj is not None:
            if type(obj) is str:
                obj = cls.from_str(obj.replace(cls.__name__ + ".", ""))
            elif not isinstance(obj, cls):
                raise TypeError(
                    f"Invalid Weight class provided; expected {cls.__name__} but received {obj.__class__.__name__}."
                )
        return obj

    def get_state_dict(self, progress: bool) -> OrderedDict:
        return load_state_dict_from_url(self.url, progress=progress)

    def __repr__(self) -> str:
        return f"{self.__class__.__name__}.{self._name_}"

    def __getattr__(self, name):
        # Be able to fetch Weights attributes directly
        for f in fields(Weights):
            if f.name == name:
                return object.__getattribute__(self.value, name)
        return super().__getattr__(name)

class IntermediateLayerGetter(nn.ModuleDict):
    _version = 2
    __annotations__ = {
        "return_layers": Dict[str, str],
    }

    def __init__(self, model: nn.Module, return_layers: Dict[str, str]) -> None:
        if not set(return_layers).issubset([name for name, _ in model.named_children()]):
            raise ValueError("return_layers are not present in model")
        orig_return_layers = return_layers
        return_layers = {str(k): str(v) for k, v in return_layers.items()}
        layers = OrderedDict()
        for name, module in model.named_children():
            layers[name] = module
            if name in return_layers:
                del return_layers[name]
            if not return_layers:
                break

        super().__init__(layers)
        self.return_layers = orig_return_layers

    def forward(self, x):
        out = OrderedDict()
        for name, module in self.items():
            x = module(x)
            if name in self.return_layers:
                out_name = self.return_layers[name]
                out[out_name] = x
        return out

class BackboneWithFPN(nn.Module):
    def __init__(
        self,
        backbone: nn.Module,
        return_layers: Dict[str, str],
        in_channels_list: List[int],
        out_channels: int,
        extra_blocks: Optional[ExtraFPNBlock] = None,
    ) -> None:
        super().__init__()

        if extra_blocks is None:
            extra_blocks = LastLevelMaxPool()

        self.body = IntermediateLayerGetter(backbone, return_layers=return_layers)
        self.fpn = FeaturePyramidNetwork(
            in_channels_list=in_channels_list,
            out_channels=out_channels,
            extra_blocks=extra_blocks,
        )
        self.out_channels = out_channels

    def forward(self, x: Tensor) -> Dict[str, Tensor]:
        x = self.body(x)
        x = self.fpn(x)
        return x

def _resnet_fpn_extractor(
    backbone: resnet.ResNet,
    trainable_layers: int,
    returned_layers: Optional[List[int]] = None,
    extra_blocks: Optional[ExtraFPNBlock] = None,
) -> BackboneWithFPN:

    # select layers that wont be frozen
    if trainable_layers < 0 or trainable_layers > 5:
        raise ValueError(f"Trainable layers should be in the range [0,5], got {trainable_layers}")
    layers_to_train = ["layer4", "layer3", "layer2", "layer1", "conv1"][:trainable_layers]
    if trainable_layers == 5:
        layers_to_train.append("bn1")
    for name, parameter in backbone.named_parameters():
        if all([not name.startswith(layer) for layer in layers_to_train]):
            parameter.requires_grad_(False)

    if extra_blocks is None:
        extra_blocks = LastLevelMaxPool()

    if returned_layers is None:
        returned_layers = [1, 2, 3, 4]
    if min(returned_layers) <= 0 or max(returned_layers) >= 5:
        raise ValueError(f"Each returned layer should be in the range [1,4]. Got {returned_layers}")
    return_layers = {f"layer{k}": str(v) for v, k in enumerate(returned_layers)}

    in_channels_stage2 = backbone.inplanes // 8
    in_channels_list = [in_channels_stage2 * 2 ** (i - 1) for i in returned_layers]
    out_channels = 256
    return BackboneWithFPN(backbone, return_layers, in_channels_list, out_channels, extra_blocks=extra_blocks)

def resnet_fpn_backbone(
    *,
    backbone_name: str,
    weights: Optional[WeightsEnum],
    norm_layer: Callable[..., nn.Module] = misc_nn_ops.FrozenBatchNorm2d,
    trainable_layers: int = 3,
    returned_layers: Optional[List[int]] = None,
    extra_blocks: Optional[ExtraFPNBlock] = None,
) -> BackboneWithFPN:
    
    backbone = resnet.__dict__[backbone_name](weights=weights, norm_layer=norm_layer)
    return _resnet_fpn_extractor(backbone, trainable_layers, returned_layers, extra_blocks)

# %%
# from vision.torchvision.models.detection.backbone_utils import _resnet_fpn_extractor,_validate_trainable_layers

# %% [markdown]
# #Setting datapath

# %%
import json
from pathlib import Path

from google.colab import drive
drive.mount('/drive', force_remount=True)
# Out:
# Mounted at /drive

# %%
hamamatsu_xr ='Hamamatsu XR'
hamamatsu_s360='Hamamatsu S360'
aperio_cs2='Aperio ScanScope CS2'

train_dataset_folder =  aperio_cs2+'/'
test_dataset_folder  =   hamamatsu_s360+'/'

df_train = pd.read_pickle('/drive/MyDrive/CSE499 Project/Patch Datasets/'+train_dataset_folder+'DataFrame.pkl')
df_test  = pd.read_pickle('/drive/MyDrive/CSE499 Project/Patch Datasets/'+test_dataset_folder+'DataFrame.pkl')

# %% [markdown]
# #Train and Test Class

# %%
class MitosisImagesDatasetTrain(torch.utils.data.Dataset):
  def __init__(self, files_dir, width, height,transforms=None):
    self.transforms = transforms
    self.files_dir  = files_dir
    self.height     = height
    self.width      = width

    self.imgs = [image for image in sorted(os.listdir(files_dir)) if image[-5:]=='.tiff']
    
    self.classes = [_, 'mitotic figure']

  def __getitem__(self, idx):
    img_name   = self.imgs[idx]
    image_path = os.path.join(self.files_dir, img_name)

    img     = cv2.imread(image_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
    img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)

    img_res /= 255.0
    
    dataframe = df_train[df_train['file_name']==img_name].copy()
    
    boxes = []
    labels = []

    wt = img.shape[1]
    ht = img.shape[0]
    
    for index in dataframe.index:
      labels.append(1)
      
      List = dataframe['box'][index]
      
      scale_x = float(481)/float(self.width)
      scale_y = float(451)/float(self.height)

      xmin = List[0]#/float(scale_x)
      xmax = List[2]#/float(scale_x)
      ymin = List[1]#/float(scale_y)
      ymax = List[3]#/float(scale_y)
      
      # print(xmin,xmax,ymin,ymax)
      # sys.exit()

      xmin_corr = (xmin)
      xmax_corr = (xmax)
      ymin_corr = (ymin)
      ymax_corr = (ymax)
          
      boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])
    


    boxes = torch.as_tensor(boxes, dtype=torch.float32)
    labels = torch.as_tensor(labels, dtype=torch.int64)
    area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
    #area = torch.as_tensor(area, dtype=torch.float32)
    iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)
    
    target = {}
    target["boxes"] = boxes
    target["labels"] = labels
    target["image_id"] = torch.tensor([idx])
    target["area"] = area
    target["iscrowd"] = iscrowd
    
    if self.transforms:
      sample = self.transforms(image = img_res,
                                bboxes = target['boxes'],
                                labels = labels)
      img_res = sample['image']
      target['boxes'] = torch.Tensor(sample['bboxes'])

    return img_res, target
    
  def __len__(self):
    return len(self.imgs)

class MitosisImagesDatasetTest(torch.utils.data.Dataset):
  def __init__(self, files_dir, width, height,transforms=None):
    self.transforms = transforms
    self.files_dir  = files_dir
    self.height     = height
    self.width      = width

    self.imgs = [image for image in sorted(os.listdir(files_dir)) if image[-5:]=='.tiff']
    
    self.classes = [_, 'mitotic figure']

  def __getitem__(self, idx):
    img_name   = self.imgs[idx]
    image_path = os.path.join(self.files_dir, img_name)

    img     = cv2.imread(image_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
    img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)

    img_res /= 255.0
    
    dataframe = df_test[df_test['file_name']==img_name].copy()
    
    boxes = []
    labels = []

    wt = img.shape[1]
    ht = img.shape[0]
    
    for index in dataframe.index:
      labels.append(1)
      
      List = dataframe['box'][index]
      
      scale_x = float(481)/float(self.width)
      scale_y = float(451)/float(self.height)

      xmin = List[0]#/float(scale_x)
      xmax = List[2]#/float(scale_x)
      ymin = List[1]#/float(scale_y)
      ymax = List[3]#/float(scale_y)

      

      xmin_corr = (xmin)
      xmax_corr = (xmax)
      ymin_corr = (ymin)
      ymax_corr = (ymax)
          
      boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])
    


    boxes = torch.as_tensor(boxes, dtype=torch.float32)
    labels = torch.as_tensor(labels, dtype=torch.int64)
    area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
    #area = torch.as_tensor(area, dtype=torch.float32)
    iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)
    
    target = {}
    target["boxes"] = boxes
    target["labels"] = labels
    target["image_id"] = torch.tensor([idx])
    target["area"] = area
    target["iscrowd"] = iscrowd
    
    if self.transforms:
      sample = self.transforms(image = img_res,
                                bboxes = target['boxes'],
                                labels = labels)
      img_res = sample['image']
      target['boxes'] = torch.Tensor(sample['bboxes'])

    return img_res, target
    
  def __len__(self):
    return len(self.imgs)

# %% [markdown]
# #Plotting and setting training data

# %%
# Function to visualize bounding boxes in the image
def plot_img_bbox(img, target):
  # plot the image and bboxes
  # Bounding boxes are defined as follows: x-min y-min width height
  fig, a = plt.subplots(1,1)
  fig.set_size_inches(5,5)
  a.imshow(img)
  for box in (target['boxes']):
    x, y, width, height  = box[0], box[1], box[2]-box[0], box[3]-box[1]
    rect = patches.Rectangle(
      (x, y),
      width, height,
      linewidth = 2,
      edgecolor = 'r',
      facecolor = 'none'
    )
    # Draw the bounding box on top of the image
    a.add_patch(rect)
  plt.show()

  # Send train=True for training transforms and False for val/test transforms
def get_transform(train):
  if train:
    return A.Compose(
      [
        A.HorizontalFlip(0.5),
        # ToTensorV2 converts image to pytorch tensor without div by 255
        ToTensorV2(p=1.0) 
      ],
      bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']}
    )
  else:
    return A.Compose(
      [ToTensorV2(p=1.0)],
      bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']}
    )

# %%
train_dir = '/drive/MyDrive/CSE499 Project/Patch Datasets/'+train_dataset_folder
test_dir = '/drive/MyDrive/CSE499 Project/Patch Datasets/'+test_dataset_folder

print(train_dir)
print(test_dir)

dataset =      MitosisImagesDatasetTrain(train_dir, 481, 451)
dataset_test = MitosisImagesDatasetTest(test_dir, 481,451)

# plotting the image with bboxes. Feel free to change the index
img, target = dataset[100]
print(img.shape)
plot_img_bbox(img, target)
# Out:
# /drive/MyDrive/CSE499 Project/Patch Datasets/Aperio ScanScope CS2/
# /drive/MyDrive/CSE499 Project/Patch Datasets/Hamamatsu S360/
# (451, 481, 3)

# %%
train_dataset =      MitosisImagesDatasetTrain(train_dir, 481, 451,transforms=get_transform(train=True))

def collate_fn(batch):
    return tuple(zip(*batch))

train_data_loader  = DataLoader(train_dataset,batch_size=8,shuffle=True,num_workers=4,collate_fn=utils.collate_fn)

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# #Training part

# %%
# !git clone https://github.com/ZjjConan/SimAM.git
# %cd /content/SimAM
from networks.imagenet import create_net
import argparse
# Out:
# Cloning into 'SimAM'...
# remote: Enumerating objects: 176, done.
# remote: Total 176 (delta 0), reused 0 (delta 0), pack-reused 176
# Receiving objects: 100% (176/176), 74.68 MiB | 11.65 MiB/s, done.
# Resolving deltas: 100% (47/47), done.
# /content/SimAM

# %%
import sys
sys.argv=['']
del sys

# %%
parser = argparse.ArgumentParser(description='PyTorch ImageNet Training')

parser.add_argument("--attention_type", type=str, default="cbam",
                    help="attention type (possible choices none | se | cbam | simam)")

parser.add_argument("--attention_param", type=float, default=4,
                    help="attention parameter (reduction factor in se and cbam, e_lambda in simam)")

parser.add_argument('-a', '--arch', metavar='ARCH', default='resnet50',
                    help='model architecture (default: resnet18)')


args=parser.parse_args()
backbone = create_net(args)

# %%
num_classes=2
backbone = _resnet_fpn_extractor(backbone,trainable_layers=3)
model = FasterRCNN(backbone,num_classes=num_classes)
in_features = model.roi_heads.box_predictor.cls_score.in_features
model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

model = model.to(device)

params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)
num_epochs = 50

# %%
# print("ResNet50")
# print(vanillaResnet50.layer1)
# print(" ")
# print("ResNet50 with SE")
# print(resnet50_SE.layer1)

# %%
print(train_dir)
print(test_dir)
# Out:
# /drive/MyDrive/CSE499 Project/Patch Datasets/Aperio ScanScope CS2/
# /drive/MyDrive/CSE499 Project/Patch Datasets/Hamamatsu XR/

# %%
# with torch.no_grad():
#     torch.cuda.empty_cache()

# %%
# %cd '/drive/MyDrive/CSE499 Project/modelSaves/Attention Mechanism/SENet/model3'

for epoch in range(num_epochs):
    # training for one epoch
    train_one_epoch(model, optimizer, train_data_loader, device, epoch, print_freq=10)
    #save the model
    # torch.save(model.state_dict(), 'model.pth')
    # torch.save({
    # 'epoch':epoch+1,
    # 'model_state_dict':model.state_dict(),
    # 'optimizer_state_dict':optimizer.state_dict(),
    # },'ckpt.pth')
    # update the learning rate
    lr_scheduler.step()
# Out:
# Epoch: [0]  [  0/279]  eta: 0:56:37  lr: 0.000023  loss: 1.4674 (1.4674)  loss_classifier: 0.6967 (0.6967)  loss_box_reg: 0.0225 (0.0225)  loss_objectness: 0.7063 (0.7063)  loss_rpn_box_reg: 0.0419 (0.0419)  time: 12.1759  data: 10.2940  max mem: 11368
# Epoch: [0]  [ 10/279]  eta: 0:32:59  lr: 0.000203  loss: 1.3512 (1.2930)  loss_classifier: 0.5855 (0.5369)  loss_box_reg: 0.0189 (0.0180)  loss_objectness: 0.7049 (0.7020)  loss_rpn_box_reg: 0.0351 (0.0361)  time: 7.3589  data: 5.8850  max mem: 11708
# Epoch: [0]  [ 20/279]  eta: 0:19:36  lr: 0.000382  loss: 0.9593 (1.0792)  loss_classifier: 0.2142 (0.3490)  loss_box_reg: 0.0196 (0.0203)  loss_objectness: 0.6841 (0.6793)  loss_rpn_box_reg: 0.0296 (0.0306)  time: 4.1600  data: 2.7302  max mem: 11708
# Epoch: [0]  [ 30/279]  eta: 0:14:43  lr: 0.000562  loss: 0.8019 (0.9780)  loss_classifier: 0.1709 (0.2985)  loss_box_reg: 0.0213 (0.0211)  loss_objectness: 0.6017 (0.6340)  loss_rpn_box_reg: 0.0150 (0.0244)  time: 1.4506  data: 0.0175  max mem: 11708
# Epoch: [0]  [ 40/279]  eta: 0:12:06  lr: 0.000742  loss: 0.6244 (0.8612)  loss_classifier: 0.1447 (0.2525)  loss_box_reg: 0.0191 (0.0195)  loss_objectness: 0.4502 (0.5679)  loss_rpn_box_reg: 0.0109 (0.0213)  time: 1.4594  data: 0.0186  max mem: 11708
# Epoch: [0]  [ 50/279]  eta: 0:10:24  lr: 0.000921  loss: 0.3731 (0.7520)  loss_classifier: 0.0824 (0.2188)  loss_box_reg: 0.0125 (0.0180)  loss_objectness: 0.2578 (0.4959)  loss_rpn_box_reg: 0.0114 (0.0193)  time: 1.4590  data: 0.0181  max mem: 11708
# Epoch: [0]  [ 60/279]  eta: 0:09:11  lr: 0.001101  loss: 0.2691 (0.6717)  loss_classifier: 0.0839 (0.1999)  loss_box_reg: 0.0128 (0.0184)  loss_objectness: 0.1531 (0.4357)  loss_rpn_box_reg: 0.0097 (0.0178)  time: 1.4588  data: 0.0179  max mem: 11708
# Epoch: [0]  [ 70/279]  eta: 0:08:15  lr: 0.001281  loss: 0.2484 (0.6096)  loss_classifier: 0.0995 (0.1848)  loss_box_reg: 0.0275 (0.0202)  loss_objectness: 0.1109 (0.3880)  loss_rpn_box_reg: 0.0087 (0.0165)  time: 1.4584  data: 0.0175  max mem: 11708
# Epoch: [0]  [ 80/279]  eta: 0:07:29  lr: 0.001460  loss: 0.2088 (0.5587)  loss_classifier: 0.0786 (0.1712)  loss_box_reg: 0.0335 (0.0222)  loss_objectness: 0.0869 (0.3499)  loss_rpn_box_reg: 0.0079 (0.0154)  time: 1.4583  data: 0.0174  max mem: 11708
# Epoch: [0]  [ 90/279]  eta: 0:06:50  lr: 0.001640  loss: 0.1831 (0.5165)  loss_classifier: 0.0707 (0.1600)  loss_box_reg: 0.0359 (0.0239)  loss_objectness: 0.0679 (0.3181)  loss_rpn_box_reg: 0.0072 (0.0144)  time: 1.4618  data: 0.0189  max mem: 11708
# Epoch: [0]  [100/279]  eta: 0:06:15  lr: 0.001820  loss: 0.1602 (0.4810)  loss_classifier: 0.0616 (0.1500)  loss_box_reg: 0.0359 (0.0251)  loss_objectness: 0.0591 (0.2922)  loss_rpn_box_reg: 0.0068 (0.0137)  time: 1.4622  data: 0.0197  max mem: 11708
# Epoch: [0]  [110/279]  eta: 0:05:45  lr: 0.001999  loss: 0.1514 (0.4505)  loss_classifier: 0.0561 (0.1414)  loss_box_reg: 0.0357 (0.0262)  loss_objectness: 0.0497 (0.2698)  loss_rpn_box_reg: 0.0060 (0.0130)  time: 1.4606  data: 0.0193  max mem: 11708
# Epoch: [0]  [120/279]  eta: 0:05:17  lr: 0.002179  loss: 0.1330 (0.4246)  loss_classifier: 0.0524 (0.1339)  loss_box_reg: 0.0349 (0.0270)  loss_objectness: 0.0412 (0.2511)  loss_rpn_box_reg: 0.0060 (0.0125)  time: 1.4609  data: 0.0188  max mem: 11708
# Epoch: [0]  [130/279]  eta: 0:04:51  lr: 0.002359  loss: 0.1266 (0.4015)  loss_classifier: 0.0453 (0.1269)  loss_box_reg: 0.0338 (0.0274)  loss_objectness: 0.0415 (0.2352)  loss_rpn_box_reg: 0.0061 (0.0120)  time: 1.4618  data: 0.0190  max mem: 11708
# Epoch: [0]  [140/279]  eta: 0:04:26  lr: 0.002538  loss: 0.1207 (0.3815)  loss_classifier: 0.0418 (0.1210)  loss_box_reg: 0.0306 (0.0278)  loss_objectness: 0.0389 (0.2211)  loss_rpn_box_reg: 0.0061 (0.0116)  time: 1.4671  data: 0.0203  max mem: 11708
# Epoch: [0]  [150/279]  eta: 0:04:03  lr: 0.002718  loss: 0.1112 (0.3636)  loss_classifier: 0.0407 (0.1156)  loss_box_reg: 0.0317 (0.0280)  loss_objectness: 0.0350 (0.2087)  loss_rpn_box_reg: 0.0055 (0.0112)  time: 1.4671  data: 0.0207  max mem: 11708
# Epoch: [0]  [160/279]  eta: 0:03:41  lr: 0.002898  loss: 0.1058 (0.3474)  loss_classifier: 0.0376 (0.1108)  loss_box_reg: 0.0291 (0.0280)  loss_objectness: 0.0308 (0.1977)  loss_rpn_box_reg: 0.0049 (0.0108)  time: 1.4640  data: 0.0208  max mem: 11708
# Epoch: [0]  [170/279]  eta: 0:03:20  lr: 0.003077  loss: 0.0964 (0.3325)  loss_classifier: 0.0344 (0.1063)  loss_box_reg: 0.0268 (0.0279)  loss_objectness: 0.0259 (0.1878)  loss_rpn_box_reg: 0.0053 (0.0105)  time: 1.4631  data: 0.0204  max mem: 11708
# Epoch: [0]  [180/279]  eta: 0:03:00  lr: 0.003257  loss: 0.0964 (0.3200)  loss_classifier: 0.0342 (0.1025)  loss_box_reg: 0.0253 (0.0279)  loss_objectness: 0.0250 (0.1793)  loss_rpn_box_reg: 0.0056 (0.0102)  time: 1.4622  data: 0.0193  max mem: 11708
# Epoch: [0]  [190/279]  eta: 0:02:40  lr: 0.003437  loss: 0.0986 (0.3084)  loss_classifier: 0.0356 (0.0990)  loss_box_reg: 0.0260 (0.0279)  loss_objectness: 0.0269 (0.1714)  loss_rpn_box_reg: 0.0059 (0.0100)  time: 1.4628  data: 0.0184  max mem: 11708
# Epoch: [0]  [200/279]  eta: 0:02:20  lr: 0.003616  loss: 0.0954 (0.2978)  loss_classifier: 0.0347 (0.0958)  loss_box_reg: 0.0260 (0.0279)  loss_objectness: 0.0251 (0.1643)  loss_rpn_box_reg: 0.0058 (0.0098)  time: 1.4632  data: 0.0183  max mem: 11708
# Epoch: [0]  [210/279]  eta: 0:02:02  lr: 0.003796  loss: 0.0937 (0.2882)  loss_classifier: 0.0336 (0.0929)  loss_box_reg: 0.0262 (0.0279)  loss_objectness: 0.0252 (0.1579)  loss_rpn_box_reg: 0.0050 (0.0096)  time: 1.4624  data: 0.0183  max mem: 11708
# Epoch: [0]  [220/279]  eta: 0:01:43  lr: 0.003976  loss: 0.0908 (0.2794)  loss_classifier: 0.0336 (0.0903)  loss_box_reg: 0.0258 (0.0279)  loss_objectness: 0.0242 (0.1518)  loss_rpn_box_reg: 0.0050 (0.0094)  time: 1.4608  data: 0.0179  max mem: 11708
# Epoch: [0]  [230/279]  eta: 0:01:25  lr: 0.004156  loss: 0.0919 (0.2718)  loss_classifier: 0.0349 (0.0881)  loss_box_reg: 0.0246 (0.0279)  loss_objectness: 0.0258 (0.1467)  loss_rpn_box_reg: 0.0049 (0.0092)  time: 1.4615  data: 0.0181  max mem: 11708
# Epoch: [0]  [240/279]  eta: 0:01:07  lr: 0.004335  loss: 0.1009 (0.2646)  loss_classifier: 0.0373 (0.0860)  loss_box_reg: 0.0263 (0.0278)  loss_objectness: 0.0266 (0.1418)  loss_rpn_box_reg: 0.0045 (0.0090)  time: 1.4614  data: 0.0180  max mem: 11708
# Epoch: [0]  [250/279]  eta: 0:00:49  lr: 0.004515  loss: 0.0983 (0.2581)  loss_classifier: 0.0361 (0.0840)  loss_box_reg: 0.0278 (0.0279)  loss_objectness: 0.0269 (0.1373)  loss_rpn_box_reg: 0.0048 (0.0088)  time: 1.4620  data: 0.0178  max mem: 11708
# Epoch: [0]  [260/279]  eta: 0:00:32  lr: 0.004695  loss: 0.1081 (0.2523)  loss_classifier: 0.0360 (0.0823)  loss_box_reg: 0.0291 (0.0280)  loss_objectness: 0.0291 (0.1332)  loss_rpn_box_reg: 0.0055 (0.0087)  time: 1.4614  data: 0.0171  max mem: 11708
# Epoch: [0]  [270/279]  eta: 0:00:15  lr: 0.004874  loss: 0.0990 (0.2464)  loss_classifier: 0.0336 (0.0805)  loss_box_reg: 0.0265 (0.0279)  loss_objectness: 0.0276 (0.1294)  loss_rpn_box_reg: 0.0050 (0.0086)  time: 1.4629  data: 0.0179  max mem: 11708
# Epoch: [0]  [278/279]  eta: 0:00:01  lr: 0.005000  loss: 0.0882 (0.2419)  loss_classifier: 0.0325 (0.0792)  loss_box_reg: 0.0265 (0.0279)  loss_objectness: 0.0247 (0.1263)  loss_rpn_box_reg: 0.0047 (0.0085)  time: 1.4652  data: 0.0194  max mem: 11708
# Epoch: [0] Total time: 0:07:52 (1.6940 s / it)
# Epoch: [1]  [  0/279]  eta: 0:08:39  lr: 0.005000  loss: 0.1376 (0.1376)  loss_classifier: 0.0415 (0.0415)  loss_box_reg: 0.0233 (0.0233)  loss_objectness: 0.0679 (0.0679)  loss_rpn_box_reg: 0.0049 (0.0049)  time: 1.8638  data: 0.4053  max mem: 11708
# Epoch: [1]  [ 10/279]  eta: 0:06:44  lr: 0.005000  loss: 0.0935 (0.1008)  loss_classifier: 0.0337 (0.0362)  loss_box_reg: 0.0247 (0.0257)  loss_objectness: 0.0310 (0.0349)  loss_rpn_box_reg: 0.0040 (0.0040)  time: 1.5024  data: 0.0552  max mem: 11708
# Epoch: [1]  [ 20/279]  eta: 0:06:24  lr: 0.005000  loss: 0.0893 (0.0930)  loss_classifier: 0.0324 (0.0348)  loss_box_reg: 0.0244 (0.0248)  loss_objectness: 0.0250 (0.0291)  loss_rpn_box_reg: 0.0040 (0.0042)  time: 1.4654  data: 0.0195  max mem: 11708
# Epoch: [1]  [ 30/279]  eta: 0:06:07  lr: 0.005000  loss: 0.0894 (0.0922)  loss_classifier: 0.0324 (0.0347)  loss_box_reg: 0.0247 (0.0254)  loss_objectness: 0.0217 (0.0277)  loss_rpn_box_reg: 0.0043 (0.0043)  time: 1.4635  data: 0.0190  max mem: 11708
# Epoch: [1]  [ 40/279]  eta: 0:05:52  lr: 0.005000  loss: 0.0878 (0.0903)  loss_classifier: 0.0351 (0.0347)  loss_box_reg: 0.0260 (0.0259)  loss_objectness: 0.0200 (0.0255)  loss_rpn_box_reg: 0.0042 (0.0043)  time: 1.4638  data: 0.0193  max mem: 11708
# Epoch: [1]  [ 50/279]  eta: 0:05:37  lr: 0.005000  loss: 0.0850 (0.0909)  loss_classifier: 0.0332 (0.0342)  loss_box_reg: 0.0260 (0.0260)  loss_objectness: 0.0189 (0.0264)  loss_rpn_box_reg: 0.0042 (0.0043)  time: 1.4635  data: 0.0197  max mem: 11708
# Epoch: [1]  [ 60/279]  eta: 0:05:22  lr: 0.005000  loss: 0.0854 (0.0900)  loss_classifier: 0.0296 (0.0337)  loss_box_reg: 0.0236 (0.0258)  loss_objectness: 0.0259 (0.0263)  loss_rpn_box_reg: 0.0042 (0.0042)  time: 1.4635  data: 0.0196  max mem: 11708
# Epoch: [1]  [ 70/279]  eta: 0:05:07  lr: 0.005000  loss: 0.0799 (0.0883)  loss_classifier: 0.0290 (0.0331)  loss_box_reg: 0.0231 (0.0254)  loss_objectness: 0.0228 (0.0256)  loss_rpn_box_reg: 0.0039 (0.0042)  time: 1.4642  data: 0.0187  max mem: 11708
# Epoch: [1]  [ 80/279]  eta: 0:04:52  lr: 0.005000  loss: 0.0777 (0.0879)  loss_classifier: 0.0303 (0.0333)  loss_box_reg: 0.0243 (0.0254)  loss_objectness: 0.0171 (0.0252)  loss_rpn_box_reg: 0.0037 (0.0041)  time: 1.4656  data: 0.0198  max mem: 11708
# Epoch: [1]  [ 90/279]  eta: 0:04:37  lr: 0.005000  loss: 0.0852 (0.0885)  loss_classifier: 0.0334 (0.0333)  loss_box_reg: 0.0250 (0.0254)  loss_objectness: 0.0207 (0.0258)  loss_rpn_box_reg: 0.0035 (0.0041)  time: 1.4655  data: 0.0199  max mem: 11708
# Epoch: [1]  [100/279]  eta: 0:04:22  lr: 0.005000  loss: 0.0823 (0.0879)  loss_classifier: 0.0292 (0.0331)  loss_box_reg: 0.0228 (0.0250)  loss_objectness: 0.0263 (0.0258)  loss_rpn_box_reg: 0.0035 (0.0040)  time: 1.4636  data: 0.0177  max mem: 11708
# Epoch: [1]  [110/279]  eta: 0:04:08  lr: 0.005000  loss: 0.0790 (0.0874)  loss_classifier: 0.0292 (0.0327)  loss_box_reg: 0.0219 (0.0249)  loss_objectness: 0.0261 (0.0258)  loss_rpn_box_reg: 0.0033 (0.0040)  time: 1.4651  data: 0.0185  max mem: 11708
# Epoch: [1]  [120/279]  eta: 0:03:53  lr: 0.005000  loss: 0.0866 (0.0877)  loss_classifier: 0.0316 (0.0329)  loss_box_reg: 0.0230 (0.0248)  loss_objectness: 0.0234 (0.0260)  loss_rpn_box_reg: 0.0038 (0.0040)  time: 1.4638  data: 0.0188  max mem: 11708
# Epoch: [1]  [130/279]  eta: 0:03:38  lr: 0.005000  loss: 0.0902 (0.0877)  loss_classifier: 0.0341 (0.0329)  loss_box_reg: 0.0214 (0.0246)  loss_objectness: 0.0301 (0.0263)  loss_rpn_box_reg: 0.0039 (0.0040)  time: 1.4615  data: 0.0172  max mem: 11708
# Epoch: [1]  [140/279]  eta: 0:03:23  lr: 0.005000  loss: 0.0866 (0.0877)  loss_classifier: 0.0322 (0.0330)  loss_box_reg: 0.0225 (0.0247)  loss_objectness: 0.0252 (0.0260)  loss_rpn_box_reg: 0.0038 (0.0040)  time: 1.4618  data: 0.0174  max mem: 11708
# Epoch: [1]  [150/279]  eta: 0:03:09  lr: 0.005000  loss: 0.0793 (0.0869)  loss_classifier: 0.0298 (0.0328)  loss_box_reg: 0.0223 (0.0245)  loss_objectness: 0.0210 (0.0257)  loss_rpn_box_reg: 0.0034 (0.0040)  time: 1.4633  data: 0.0184  max mem: 11708
# Epoch: [1]  [160/279]  eta: 0:02:54  lr: 0.005000  loss: 0.0700 (0.0861)  loss_classifier: 0.0287 (0.0324)  loss_box_reg: 0.0210 (0.0243)  loss_objectness: 0.0186 (0.0255)  loss_rpn_box_reg: 0.0033 (0.0039)  time: 1.4628  data: 0.0182  max mem: 11708
# Epoch: [1]  [170/279]  eta: 0:02:39  lr: 0.005000  loss: 0.0713 (0.0856)  loss_classifier: 0.0265 (0.0323)  loss_box_reg: 0.0221 (0.0243)  loss_objectness: 0.0167 (0.0252)  loss_rpn_box_reg: 0.0030 (0.0039)  time: 1.4638  data: 0.0185  max mem: 11708
# Epoch: [1]  [180/279]  eta: 0:02:25  lr: 0.005000  loss: 0.0732 (0.0850)  loss_classifier: 0.0298 (0.0321)  loss_box_reg: 0.0239 (0.0243)  loss_objectness: 0.0167 (0.0248)  loss_rpn_box_reg: 0.0032 (0.0038)  time: 1.4662  data: 0.0195  max mem: 11708
# Epoch: [1]  [190/279]  eta: 0:02:10  lr: 0.005000  loss: 0.0763 (0.0844)  loss_classifier: 0.0298 (0.0319)  loss_box_reg: 0.0241 (0.0242)  loss_objectness: 0.0181 (0.0245)  loss_rpn_box_reg: 0.0035 (0.0038)  time: 1.4657  data: 0.0196  max mem: 11708
# Epoch: [1]  [200/279]  eta: 0:01:55  lr: 0.005000  loss: 0.0793 (0.0841)  loss_classifier: 0.0309 (0.0320)  loss_box_reg: 0.0237 (0.0243)  loss_objectness: 0.0188 (0.0241)  loss_rpn_box_reg: 0.0036 (0.0038)  time: 1.4665  data: 0.0199  max mem: 11708
# Epoch: [1]  [210/279]  eta: 0:01:41  lr: 0.005000  loss: 0.0780 (0.0838)  loss_classifier: 0.0309 (0.0319)  loss_box_reg: 0.0239 (0.0242)  loss_objectness: 0.0135 (0.0239)  loss_rpn_box_reg: 0.0036 (0.0038)  time: 1.4655  data: 0.0202  max mem: 11708
# Epoch: [1]  [220/279]  eta: 0:01:26  lr: 0.005000  loss: 0.0743 (0.0835)  loss_classifier: 0.0298 (0.0318)  loss_box_reg: 0.0219 (0.0241)  loss_objectness: 0.0172 (0.0239)  loss_rpn_box_reg: 0.0037 (0.0038)  time: 1.4649  data: 0.0201  max mem: 11708
# Epoch: [1]  [230/279]  eta: 0:01:11  lr: 0.005000  loss: 0.0834 (0.0834)  loss_classifier: 0.0296 (0.0317)  loss_box_reg: 0.0212 (0.0240)  loss_objectness: 0.0206 (0.0238)  loss_rpn_box_reg: 0.0033 (0.0038)  time: 1.4653  data: 0.0190  max mem: 11708
# Epoch: [1]  [240/279]  eta: 0:00:57  lr: 0.005000  loss: 0.0776 (0.0831)  loss_classifier: 0.0283 (0.0318)  loss_box_reg: 0.0212 (0.0240)  loss_objectness: 0.0201 (0.0236)  loss_rpn_box_reg: 0.0033 (0.0038)  time: 1.4640  data: 0.0174  max mem: 11708
# Epoch: [1]  [250/279]  eta: 0:00:42  lr: 0.005000  loss: 0.0727 (0.0829)  loss_classifier: 0.0278 (0.0316)  loss_box_reg: 0.0217 (0.0240)  loss_objectness: 0.0152 (0.0236)  loss_rpn_box_reg: 0.0037 (0.0038)  time: 1.4641  data: 0.0186  max mem: 11708
# Epoch: [1]  [260/279]  eta: 0:00:27  lr: 0.005000  loss: 0.0734 (0.0827)  loss_classifier: 0.0258 (0.0315)  loss_box_reg: 0.0212 (0.0239)  loss_objectness: 0.0152 (0.0235)  loss_rpn_box_reg: 0.0040 (0.0038)  time: 1.4642  data: 0.0204  max mem: 11708
# Epoch: [1]  [270/279]  eta: 0:00:13  lr: 0.005000  loss: 0.0734 (0.0825)  loss_classifier: 0.0291 (0.0314)  loss_box_reg: 0.0223 (0.0239)  loss_objectness: 0.0162 (0.0234)  loss_rpn_box_reg: 0.0034 (0.0038)  time: 1.4637  data: 0.0191  max mem: 11708
# Epoch: [1]  [278/279]  eta: 0:00:01  lr: 0.005000  loss: 0.0734 (0.0824)  loss_classifier: 0.0291 (0.0314)  loss_box_reg: 0.0223 (0.0239)  loss_objectness: 0.0183 (0.0234)  loss_rpn_box_reg: 0.0029 (0.0037)  time: 1.4611  data: 0.0177  max mem: 11708
# Epoch: [1] Total time: 0:06:48 (1.4658 s / it)
# Epoch: [2]  [  0/279]  eta: 0:08:52  lr: 0.005000  loss: 0.0861 (0.0861)  loss_classifier: 0.0379 (0.0379)  loss_box_reg: 0.0202 (0.0202)  loss_objectness: 0.0225 (0.0225)  loss_rpn_box_reg: 0.0055 (0.0055)  time: 1.9094  data: 0.4511  max mem: 11708
# Epoch: [2]  [ 10/279]  eta: 0:06:44  lr: 0.005000  loss: 0.0785 (0.0764)  loss_classifier: 0.0298 (0.0292)  loss_box_reg: 0.0216 (0.0232)  loss_objectness: 0.0168 (0.0203)  loss_rpn_box_reg: 0.0033 (0.0037)  time: 1.5041  data: 0.0583  max mem: 11708
# Epoch: [2]  [ 20/279]  eta: 0:06:24  lr: 0.005000  loss: 0.0763 (0.0739)  loss_classifier: 0.0265 (0.0284)  loss_box_reg: 0.0216 (0.0233)  loss_objectness: 0.0159 (0.0187)  loss_rpn_box_reg: 0.0033 (0.0035)  time: 1.4635  data: 0.0191  max mem: 11708
# Epoch: [2]  [ 30/279]  eta: 0:06:07  lr: 0.005000  loss: 0.0666 (0.0723)  loss_classifier: 0.0262 (0.0276)  loss_box_reg: 0.0191 (0.0222)  loss_objectness: 0.0179 (0.0192)  loss_rpn_box_reg: 0.0031 (0.0034)  time: 1.4630  data: 0.0183  max mem: 11708
# Epoch: [2]  [ 40/279]  eta: 0:05:52  lr: 0.005000  loss: 0.0704 (0.0720)  loss_classifier: 0.0271 (0.0279)  loss_box_reg: 0.0210 (0.0223)  loss_objectness: 0.0163 (0.0185)  loss_rpn_box_reg: 0.0031 (0.0033)  time: 1.4619  data: 0.0182  max mem: 11708
# Epoch: [2]  [ 50/279]  eta: 0:05:36  lr: 0.005000  loss: 0.0690 (0.0714)  loss_classifier: 0.0251 (0.0274)  loss_box_reg: 0.0222 (0.0226)  loss_objectness: 0.0139 (0.0183)  loss_rpn_box_reg: 0.0029 (0.0032)  time: 1.4618  data: 0.0190  max mem: 11708
# Epoch: [2]  [ 60/279]  eta: 0:05:21  lr: 0.005000  loss: 0.0725 (0.0727)  loss_classifier: 0.0277 (0.0282)  loss_box_reg: 0.0220 (0.0225)  loss_objectness: 0.0158 (0.0188)  loss_rpn_box_reg: 0.0029 (0.0032)  time: 1.4623  data: 0.0187  max mem: 11708
# Epoch: [2]  [ 70/279]  eta: 0:05:06  lr: 0.005000  loss: 0.0756 (0.0730)  loss_classifier: 0.0309 (0.0283)  loss_box_reg: 0.0228 (0.0229)  loss_objectness: 0.0153 (0.0185)  loss_rpn_box_reg: 0.0029 (0.0032)  time: 1.4615  data: 0.0185  max mem: 11708
# Epoch: [2]  [ 80/279]  eta: 0:04:52  lr: 0.005000  loss: 0.0713 (0.0723)  loss_classifier: 0.0280 (0.0282)  loss_box_reg: 0.0246 (0.0231)  loss_objectness: 0.0118 (0.0179)  loss_rpn_box_reg: 0.0032 (0.0032)  time: 1.4618  data: 0.0180  max mem: 11708
# Epoch: [2]  [ 90/279]  eta: 0:04:37  lr: 0.005000  loss: 0.0719 (0.0728)  loss_classifier: 0.0288 (0.0285)  loss_box_reg: 0.0231 (0.0228)  loss_objectness: 0.0192 (0.0184)  loss_rpn_box_reg: 0.0029 (0.0032)  time: 1.4618  data: 0.0173  max mem: 11708
# Epoch: [2]  [100/279]  eta: 0:04:22  lr: 0.005000  loss: 0.0781 (0.0736)  loss_classifier: 0.0302 (0.0289)  loss_box_reg: 0.0217 (0.0228)  loss_objectness: 0.0226 (0.0186)  loss_rpn_box_reg: 0.0032 (0.0032)  time: 1.4612  data: 0.0183  max mem: 11708
# Epoch: [2]  [110/279]  eta: 0:04:07  lr: 0.005000  loss: 0.0754 (0.0732)  loss_classifier: 0.0295 (0.0287)  loss_box_reg: 0.0230 (0.0227)  loss_objectness: 0.0195 (0.0186)  loss_rpn_box_reg: 0.0032 (0.0032)  time: 1.4615  data: 0.0185  max mem: 11708
# Epoch: [2]  [120/279]  eta: 0:03:53  lr: 0.005000  loss: 0.0708 (0.0731)  loss_classifier: 0.0264 (0.0286)  loss_box_reg: 0.0215 (0.0226)  loss_objectness: 0.0163 (0.0186)  loss_rpn_box_reg: 0.0030 (0.0032)  time: 1.4625  data: 0.0181  max mem: 11708
# Epoch: [2]  [130/279]  eta: 0:03:38  lr: 0.005000  loss: 0.0741 (0.0739)  loss_classifier: 0.0286 (0.0290)  loss_box_reg: 0.0215 (0.0228)  loss_objectness: 0.0150 (0.0189)  loss_rpn_box_reg: 0.0032 (0.0032)  time: 1.4643  data: 0.0193  max mem: 11708
# Epoch: [2]  [140/279]  eta: 0:03:23  lr: 0.005000  loss: 0.0689 (0.0731)  loss_classifier: 0.0246 (0.0285)  loss_box_reg: 0.0215 (0.0226)  loss_objectness: 0.0147 (0.0188)  loss_rpn_box_reg: 0.0027 (0.0032)  time: 1.4640  data: 0.0192  max mem: 11708
# Epoch: [2]  [150/279]  eta: 0:03:09  lr: 0.005000  loss: 0.0633 (0.0731)  loss_classifier: 0.0235 (0.0285)  loss_box_reg: 0.0215 (0.0225)  loss_objectness: 0.0149 (0.0189)  loss_rpn_box_reg: 0.0027 (0.0031)  time: 1.4617  data: 0.0176  max mem: 11708
# Epoch: [2]  [160/279]  eta: 0:02:54  lr: 0.005000  loss: 0.0633 (0.0727)  loss_classifier: 0.0263 (0.0284)  loss_box_reg: 0.0202 (0.0224)  loss_objectness: 0.0139 (0.0187)  loss_rpn_box_reg: 0.0026 (0.0031)  time: 1.4617  data: 0.0185  max mem: 11708
# Epoch: [2]  [170/279]  eta: 0:02:39  lr: 0.005000  loss: 0.0726 (0.0731)  loss_classifier: 0.0296 (0.0285)  loss_box_reg: 0.0218 (0.0225)  loss_objectness: 0.0144 (0.0189)  loss_rpn_box_reg: 0.0032 (0.0031)  time: 1.4629  data: 0.0194  max mem: 11708
# Epoch: [2]  [180/279]  eta: 0:02:25  lr: 0.005000  loss: 0.0751 (0.0730)  loss_classifier: 0.0296 (0.0285)  loss_box_reg: 0.0246 (0.0227)  loss_objectness: 0.0175 (0.0187)  loss_rpn_box_reg: 0.0032 (0.0031)  time: 1.4633  data: 0.0189  max mem: 11708
# Epoch: [2]  [190/279]  eta: 0:02:10  lr: 0.005000  loss: 0.0765 (0.0731)  loss_classifier: 0.0296 (0.0286)  loss_box_reg: 0.0253 (0.0229)  loss_objectness: 0.0115 (0.0184)  loss_rpn_box_reg: 0.0030 (0.0031)  time: 1.4632  data: 0.0188  max mem: 11708
# Epoch: [2]  [200/279]  eta: 0:01:55  lr: 0.005000  loss: 0.0814 (0.0738)  loss_classifier: 0.0329 (0.0289)  loss_box_reg: 0.0329 (0.0237)  loss_objectness: 0.0087 (0.0180)  loss_rpn_box_reg: 0.0031 (0.0032)  time: 1.4630  data: 0.0194  max mem: 11708
# Epoch: [2]  [210/279]  eta: 0:01:41  lr: 0.005000  loss: 0.0811 (0.0743)  loss_classifier: 0.0330 (0.0291)  loss_box_reg: 0.0339 (0.0240)  loss_objectness: 0.0074 (0.0180)  loss_rpn_box_reg: 0.0030 (0.0031)  time: 1.4639  data: 0.0202  max mem: 11708
# Epoch: [2]  [220/279]  eta: 0:01:26  lr: 0.005000  loss: 0.0705 (0.0741)  loss_classifier: 0.0281 (0.0290)  loss_box_reg: 0.0219 (0.0239)  loss_objectness: 0.0129 (0.0181)  loss_rpn_box_reg: 0.0029 (0.0031)  time: 1.4652  data: 0.0198  max mem: 11708
# Epoch: [2]  [230/279]  eta: 0:01:11  lr: 0.005000  loss: 0.0645 (0.0738)  loss_classifier: 0.0267 (0.0289)  loss_box_reg: 0.0211 (0.0239)  loss_objectness: 0.0129 (0.0179)  loss_rpn_box_reg: 0.0029 (0.0031)  time: 1.4650  data: 0.0198  max mem: 11708
# Epoch: [2]  [240/279]  eta: 0:00:57  lr: 0.005000  loss: 0.0672 (0.0740)  loss_classifier: 0.0274 (0.0290)  loss_box_reg: 0.0238 (0.0239)  loss_objectness: 0.0126 (0.0179)  loss_rpn_box_reg: 0.0031 (0.0031)  time: 1.4643  data: 0.0203  max mem: 11708
# Epoch: [2]  [250/279]  eta: 0:00:42  lr: 0.005000  loss: 0.0672 (0.0737)  loss_classifier: 0.0266 (0.0288)  loss_box_reg: 0.0236 (0.0239)  loss_objectness: 0.0126 (0.0178)  loss_rpn_box_reg: 0.0032 (0.0031)  time: 1.4634  data: 0.0196  max mem: 11708
# Epoch: [2]  [260/279]  eta: 0:00:27  lr: 0.005000  loss: 0.0640 (0.0736)  loss_classifier: 0.0237 (0.0288)  loss_box_reg: 0.0261 (0.0240)  loss_objectness: 0.0126 (0.0177)  loss_rpn_box_reg: 0.0030 (0.0031)  time: 1.4632  data: 0.0192  max mem: 11708
# Epoch: [2]  [270/279]  eta: 0:00:13  lr: 0.005000  loss: 0.0652 (0.0736)  loss_classifier: 0.0259 (0.0288)  loss_box_reg: 0.0258 (0.0240)  loss_objectness: 0.0152 (0.0177)  loss_rpn_box_reg: 0.0031 (0.0031)  time: 1.4636  data: 0.0201  max mem: 11708
# Epoch: [2]  [278/279]  eta: 0:00:01  lr: 0.005000  loss: 0.0753 (0.0737)  loss_classifier: 0.0273 (0.0288)  loss_box_reg: 0.0258 (0.0244)  loss_objectness: 0.0095 (0.0174)  loss_rpn_box_reg: 0.0033 (0.0031)  time: 1.4628  data: 0.0195  max mem: 11708
# Epoch: [2] Total time: 0:06:48 (1.4647 s / it)
# Epoch: [3]  [  0/279]  eta: 0:09:33  lr: 0.000500  loss: 0.1350 (0.1350)  loss_classifier: 0.0542 (0.0542)  loss_box_reg: 0.0375 (0.0375)  loss_objectness: 0.0405 (0.0405)  loss_rpn_box_reg: 0.0028 (0.0028)  time: 2.0558  data: 0.5857  max mem: 11708
# Epoch: [3]  [ 10/279]  eta: 0:06:46  lr: 0.000500  loss: 0.0971 (0.1041)  loss_classifier: 0.0377 (0.0404)  loss_box_reg: 0.0439 (0.0442)  loss_objectness: 0.0145 (0.0166)  loss_rpn_box_reg: 0.0028 (0.0028)  time: 1.5122  data: 0.0645  max mem: 11708
# Epoch: [3]  [ 20/279]  eta: 0:06:25  lr: 0.000500  loss: 0.0915 (0.0971)  loss_classifier: 0.0349 (0.0383)  loss_box_reg: 0.0401 (0.0420)  loss_objectness: 0.0101 (0.0140)  loss_rpn_box_reg: 0.0026 (0.0028)  time: 1.4606  data: 0.0155  max mem: 11708
# Epoch: [3]  [ 30/279]  eta: 0:06:08  lr: 0.000500  loss: 0.0868 (0.0944)  loss_classifier: 0.0330 (0.0369)  loss_box_reg: 0.0371 (0.0396)  loss_objectness: 0.0138 (0.0151)  loss_rpn_box_reg: 0.0029 (0.0029)  time: 1.4623  data: 0.0187  max mem: 11708
# Epoch: [3]  [ 40/279]  eta: 0:05:52  lr: 0.000500  loss: 0.0790 (0.0883)  loss_classifier: 0.0327 (0.0350)  loss_box_reg: 0.0285 (0.0359)  loss_objectness: 0.0138 (0.0146)  loss_rpn_box_reg: 0.0025 (0.0028)  time: 1.4616  data: 0.0190  max mem: 11708
# Epoch: [3]  [ 50/279]  eta: 0:05:37  lr: 0.000500  loss: 0.0678 (0.0848)  loss_classifier: 0.0269 (0.0337)  loss_box_reg: 0.0247 (0.0338)  loss_objectness: 0.0112 (0.0146)  loss_rpn_box_reg: 0.0023 (0.0027)  time: 1.4623  data: 0.0192  max mem: 11708
# Epoch: [3]  [ 60/279]  eta: 0:05:22  lr: 0.000500  loss: 0.0678 (0.0831)  loss_classifier: 0.0281 (0.0330)  loss_box_reg: 0.0234 (0.0321)  loss_objectness: 0.0145 (0.0153)  loss_rpn_box_reg: 0.0024 (0.0027)  time: 1.4621  data: 0.0183  max mem: 11708
# Epoch: [3]  [ 70/279]  eta: 0:05:07  lr: 0.000500  loss: 0.0655 (0.0802)  loss_classifier: 0.0281 (0.0321)  loss_box_reg: 0.0224 (0.0303)  loss_objectness: 0.0089 (0.0152)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 1.4599  data: 0.0172  max mem: 11708
# Epoch: [3]  [ 80/279]  eta: 0:04:52  lr: 0.000500  loss: 0.0604 (0.0784)  loss_classifier: 0.0253 (0.0313)  loss_box_reg: 0.0201 (0.0293)  loss_objectness: 0.0092 (0.0152)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 1.4601  data: 0.0178  max mem: 11708
# Epoch: [3]  [ 90/279]  eta: 0:04:37  lr: 0.000500  loss: 0.0630 (0.0762)  loss_classifier: 0.0237 (0.0305)  loss_box_reg: 0.0220 (0.0286)  loss_objectness: 0.0099 (0.0145)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 1.4616  data: 0.0183  max mem: 11708
# Epoch: [3]  [100/279]  eta: 0:04:22  lr: 0.000500  loss: 0.0630 (0.0758)  loss_classifier: 0.0248 (0.0304)  loss_box_reg: 0.0239 (0.0283)  loss_objectness: 0.0091 (0.0145)  loss_rpn_box_reg: 0.0022 (0.0026)  time: 1.4619  data: 0.0177  max mem: 11708
# Epoch: [3]  [110/279]  eta: 0:04:07  lr: 0.000500  loss: 0.0643 (0.0752)  loss_classifier: 0.0261 (0.0300)  loss_box_reg: 0.0239 (0.0278)  loss_objectness: 0.0124 (0.0148)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 1.4614  data: 0.0176  max mem: 11708
# Epoch: [3]  [120/279]  eta: 0:03:53  lr: 0.000500  loss: 0.0582 (0.0740)  loss_classifier: 0.0228 (0.0296)  loss_box_reg: 0.0211 (0.0274)  loss_objectness: 0.0088 (0.0145)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 1.4618  data: 0.0184  max mem: 11708
# Epoch: [3]  [130/279]  eta: 0:03:38  lr: 0.000500  loss: 0.0536 (0.0734)  loss_classifier: 0.0222 (0.0294)  loss_box_reg: 0.0223 (0.0271)  loss_objectness: 0.0078 (0.0142)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 1.4632  data: 0.0189  max mem: 11708
# Epoch: [3]  [140/279]  eta: 0:03:23  lr: 0.000500  loss: 0.0610 (0.0728)  loss_classifier: 0.0245 (0.0292)  loss_box_reg: 0.0240 (0.0269)  loss_objectness: 0.0082 (0.0141)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 1.4642  data: 0.0195  max mem: 11708
# Epoch: [3]  [150/279]  eta: 0:03:09  lr: 0.000500  loss: 0.0570 (0.0718)  loss_classifier: 0.0243 (0.0289)  loss_box_reg: 0.0231 (0.0265)  loss_objectness: 0.0075 (0.0139)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 1.4646  data: 0.0196  max mem: 11708
# Epoch: [3]  [160/279]  eta: 0:02:54  lr: 0.000500  loss: 0.0509 (0.0709)  loss_classifier: 0.0215 (0.0284)  loss_box_reg: 0.0231 (0.0263)  loss_objectness: 0.0081 (0.0135)  loss_rpn_box_reg: 0.0023 (0.0026)  time: 1.4649  data: 0.0203  max mem: 11708
# Epoch: [3]  [170/279]  eta: 0:02:39  lr: 0.000500  loss: 0.0596 (0.0708)  loss_classifier: 0.0224 (0.0283)  loss_box_reg: 0.0252 (0.0264)  loss_objectness: 0.0074 (0.0135)  loss_rpn_box_reg: 0.0023 (0.0026)  time: 1.4650  data: 0.0214  max mem: 11708
# Epoch: [3]  [180/279]  eta: 0:02:25  lr: 0.000500  loss: 0.0653 (0.0706)  loss_classifier: 0.0259 (0.0282)  loss_box_reg: 0.0248 (0.0262)  loss_objectness: 0.0093 (0.0136)  loss_rpn_box_reg: 0.0028 (0.0026)  time: 1.4634  data: 0.0199  max mem: 11708
# Epoch: [3]  [190/279]  eta: 0:02:10  lr: 0.000500  loss: 0.0587 (0.0704)  loss_classifier: 0.0260 (0.0281)  loss_box_reg: 0.0216 (0.0261)  loss_objectness: 0.0104 (0.0136)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 1.4622  data: 0.0191  max mem: 11708
# Epoch: [3]  [200/279]  eta: 0:01:55  lr: 0.000500  loss: 0.0582 (0.0705)  loss_classifier: 0.0249 (0.0281)  loss_box_reg: 0.0221 (0.0260)  loss_objectness: 0.0104 (0.0138)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 1.4642  data: 0.0192  max mem: 11708
# Epoch: [3]  [210/279]  eta: 0:01:41  lr: 0.000500  loss: 0.0582 (0.0702)  loss_classifier: 0.0238 (0.0280)  loss_box_reg: 0.0241 (0.0259)  loss_objectness: 0.0124 (0.0137)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 1.4644  data: 0.0190  max mem: 11708
# Epoch: [3]  [220/279]  eta: 0:01:26  lr: 0.000500  loss: 0.0573 (0.0695)  loss_classifier: 0.0236 (0.0278)  loss_box_reg: 0.0209 (0.0256)  loss_objectness: 0.0124 (0.0136)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 1.4625  data: 0.0186  max mem: 11708
# Epoch: [3]  [230/279]  eta: 0:01:11  lr: 0.000500  loss: 0.0573 (0.0689)  loss_classifier: 0.0216 (0.0275)  loss_box_reg: 0.0189 (0.0253)  loss_objectness: 0.0093 (0.0136)  loss_rpn_box_reg: 0.0023 (0.0026)  time: 1.4629  data: 0.0186  max mem: 11708
# Epoch: [3]  [240/279]  eta: 0:00:57  lr: 0.000500  loss: 0.0641 (0.0693)  loss_classifier: 0.0220 (0.0276)  loss_box_reg: 0.0212 (0.0253)  loss_objectness: 0.0113 (0.0138)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 1.4628  data: 0.0187  max mem: 11708
# Epoch: [3]  [250/279]  eta: 0:00:42  lr: 0.000500  loss: 0.0640 (0.0688)  loss_classifier: 0.0229 (0.0274)  loss_box_reg: 0.0224 (0.0251)  loss_objectness: 0.0113 (0.0137)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 1.4628  data: 0.0191  max mem: 11708
# Epoch: [3]  [260/279]  eta: 0:00:27  lr: 0.000500  loss: 0.0604 (0.0687)  loss_classifier: 0.0245 (0.0274)  loss_box_reg: 0.0217 (0.0250)  loss_objectness: 0.0100 (0.0138)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 1.4643  data: 0.0207  max mem: 11708
# Epoch: [3]  [270/279]  eta: 0:00:13  lr: 0.000500  loss: 0.0613 (0.0686)  loss_classifier: 0.0251 (0.0274)  loss_box_reg: 0.0181 (0.0247)  loss_objectness: 0.0137 (0.0139)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 1.4650  data: 0.0213  max mem: 11708
# Epoch: [3]  [278/279]  eta: 0:00:01  lr: 0.000500  loss: 0.0613 (0.0683)  loss_classifier: 0.0251 (0.0273)  loss_box_reg: 0.0184 (0.0246)  loss_objectness: 0.0107 (0.0138)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 1.4641  data: 0.0205  max mem: 11708
# Epoch: [3] Total time: 0:06:48 (1.4651 s / it)
# Epoch: [4]  [  0/279]  eta: 0:09:00  lr: 0.000500  loss: 0.0801 (0.0801)  loss_classifier: 0.0340 (0.0340)  loss_box_reg: 0.0178 (0.0178)  loss_objectness: 0.0251 (0.0251)  loss_rpn_box_reg: 0.0031 (0.0031)  time: 1.9368  data: 0.4949  max mem: 11708
# Epoch: [4]  [ 10/279]  eta: 0:06:44  lr: 0.000500  loss: 0.0631 (0.0630)  loss_classifier: 0.0245 (0.0260)  loss_box_reg: 0.0225 (0.0208)  loss_objectness: 0.0120 (0.0137)  loss_rpn_box_reg: 0.0026 (0.0024)  time: 1.5039  data: 0.0586  max mem: 11708
# Epoch: [4]  [ 20/279]  eta: 0:06:24  lr: 0.000500  loss: 0.0615 (0.0627)  loss_classifier: 0.0231 (0.0251)  loss_box_reg: 0.0225 (0.0211)  loss_objectness: 0.0115 (0.0140)  loss_rpn_box_reg: 0.0021 (0.0025)  time: 1.4608  data: 0.0164  max mem: 11708
# Epoch: [4]  [ 30/279]  eta: 0:06:08  lr: 0.000500  loss: 0.0597 (0.0605)  loss_classifier: 0.0247 (0.0246)  loss_box_reg: 0.0192 (0.0208)  loss_objectness: 0.0093 (0.0127)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 1.4640  data: 0.0196  max mem: 11708
# Epoch: [4]  [ 40/279]  eta: 0:05:52  lr: 0.000500  loss: 0.0597 (0.0609)  loss_classifier: 0.0259 (0.0250)  loss_box_reg: 0.0192 (0.0208)  loss_objectness: 0.0085 (0.0126)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 1.4650  data: 0.0208  max mem: 11708
# Epoch: [4]  [ 50/279]  eta: 0:05:37  lr: 0.000500  loss: 0.0625 (0.0618)  loss_classifier: 0.0259 (0.0254)  loss_box_reg: 0.0224 (0.0213)  loss_objectness: 0.0097 (0.0127)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.4636  data: 0.0189  max mem: 11708
# Epoch: [4]  [ 60/279]  eta: 0:05:22  lr: 0.000500  loss: 0.0621 (0.0625)  loss_classifier: 0.0256 (0.0258)  loss_box_reg: 0.0222 (0.0212)  loss_objectness: 0.0105 (0.0130)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.4635  data: 0.0187  max mem: 11708
# Epoch: [4]  [ 70/279]  eta: 0:05:07  lr: 0.000500  loss: 0.0562 (0.0620)  loss_classifier: 0.0246 (0.0257)  loss_box_reg: 0.0221 (0.0213)  loss_objectness: 0.0105 (0.0126)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.4631  data: 0.0190  max mem: 11708
# Epoch: [4]  [ 80/279]  eta: 0:04:52  lr: 0.000500  loss: 0.0562 (0.0615)  loss_classifier: 0.0237 (0.0253)  loss_box_reg: 0.0220 (0.0214)  loss_objectness: 0.0105 (0.0124)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.4632  data: 0.0187  max mem: 11708
# Epoch: [4]  [ 90/279]  eta: 0:04:37  lr: 0.000500  loss: 0.0555 (0.0611)  loss_classifier: 0.0212 (0.0251)  loss_box_reg: 0.0194 (0.0212)  loss_objectness: 0.0114 (0.0124)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 1.4634  data: 0.0194  max mem: 11708
# Epoch: [4]  [100/279]  eta: 0:04:22  lr: 0.000500  loss: 0.0481 (0.0608)  loss_classifier: 0.0203 (0.0248)  loss_box_reg: 0.0196 (0.0212)  loss_objectness: 0.0099 (0.0123)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 1.4615  data: 0.0190  max mem: 11708
# Epoch: [4]  [110/279]  eta: 0:04:07  lr: 0.000500  loss: 0.0608 (0.0620)  loss_classifier: 0.0246 (0.0254)  loss_box_reg: 0.0225 (0.0216)  loss_objectness: 0.0115 (0.0126)  loss_rpn_box_reg: 0.0026 (0.0024)  time: 1.4605  data: 0.0183  max mem: 11708
# Epoch: [4]  [120/279]  eta: 0:03:53  lr: 0.000500  loss: 0.0610 (0.0617)  loss_classifier: 0.0264 (0.0253)  loss_box_reg: 0.0226 (0.0214)  loss_objectness: 0.0122 (0.0126)  loss_rpn_box_reg: 0.0026 (0.0024)  time: 1.4630  data: 0.0194  max mem: 11708
# Epoch: [4]  [130/279]  eta: 0:03:38  lr: 0.000500  loss: 0.0588 (0.0619)  loss_classifier: 0.0247 (0.0253)  loss_box_reg: 0.0193 (0.0213)  loss_objectness: 0.0103 (0.0128)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 1.4631  data: 0.0196  max mem: 11708
# Epoch: [4]  [140/279]  eta: 0:03:23  lr: 0.000500  loss: 0.0615 (0.0619)  loss_classifier: 0.0248 (0.0252)  loss_box_reg: 0.0201 (0.0213)  loss_objectness: 0.0148 (0.0128)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.4623  data: 0.0187  max mem: 11708
# Epoch: [4]  [150/279]  eta: 0:03:09  lr: 0.000500  loss: 0.0572 (0.0615)  loss_classifier: 0.0223 (0.0251)  loss_box_reg: 0.0216 (0.0215)  loss_objectness: 0.0070 (0.0125)  loss_rpn_box_reg: 0.0026 (0.0025)  time: 1.4621  data: 0.0190  max mem: 11708
# Epoch: [4]  [160/279]  eta: 0:02:54  lr: 0.000500  loss: 0.0524 (0.0614)  loss_classifier: 0.0210 (0.0250)  loss_box_reg: 0.0206 (0.0214)  loss_objectness: 0.0070 (0.0126)  loss_rpn_box_reg: 0.0026 (0.0025)  time: 1.4617  data: 0.0185  max mem: 11708
# Epoch: [4]  [170/279]  eta: 0:02:39  lr: 0.000500  loss: 0.0524 (0.0614)  loss_classifier: 0.0226 (0.0250)  loss_box_reg: 0.0206 (0.0214)  loss_objectness: 0.0103 (0.0126)  loss_rpn_box_reg: 0.0026 (0.0025)  time: 1.4624  data: 0.0189  max mem: 11708
# Epoch: [4]  [180/279]  eta: 0:02:25  lr: 0.000500  loss: 0.0552 (0.0619)  loss_classifier: 0.0226 (0.0252)  loss_box_reg: 0.0210 (0.0213)  loss_objectness: 0.0109 (0.0129)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.4636  data: 0.0198  max mem: 11708
# Epoch: [4]  [190/279]  eta: 0:02:10  lr: 0.000500  loss: 0.0578 (0.0617)  loss_classifier: 0.0219 (0.0250)  loss_box_reg: 0.0206 (0.0213)  loss_objectness: 0.0093 (0.0128)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.4638  data: 0.0190  max mem: 11708
# Epoch: [4]  [200/279]  eta: 0:01:55  lr: 0.000500  loss: 0.0577 (0.0616)  loss_classifier: 0.0220 (0.0251)  loss_box_reg: 0.0213 (0.0212)  loss_objectness: 0.0093 (0.0128)  loss_rpn_box_reg: 0.0026 (0.0025)  time: 1.4630  data: 0.0180  max mem: 11708
# Epoch: [4]  [210/279]  eta: 0:01:41  lr: 0.000500  loss: 0.0574 (0.0614)  loss_classifier: 0.0241 (0.0250)  loss_box_reg: 0.0213 (0.0213)  loss_objectness: 0.0101 (0.0127)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.4623  data: 0.0184  max mem: 11708
# Epoch: [4]  [220/279]  eta: 0:01:26  lr: 0.000500  loss: 0.0579 (0.0615)  loss_classifier: 0.0229 (0.0249)  loss_box_reg: 0.0209 (0.0213)  loss_objectness: 0.0119 (0.0128)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.4638  data: 0.0195  max mem: 11708
# Epoch: [4]  [230/279]  eta: 0:01:11  lr: 0.000500  loss: 0.0595 (0.0616)  loss_classifier: 0.0232 (0.0250)  loss_box_reg: 0.0211 (0.0212)  loss_objectness: 0.0134 (0.0129)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.4634  data: 0.0194  max mem: 11708
# Epoch: [4]  [240/279]  eta: 0:00:57  lr: 0.000500  loss: 0.0565 (0.0614)  loss_classifier: 0.0239 (0.0250)  loss_box_reg: 0.0187 (0.0211)  loss_objectness: 0.0108 (0.0129)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.4627  data: 0.0191  max mem: 11708
# Epoch: [4]  [250/279]  eta: 0:00:42  lr: 0.000500  loss: 0.0597 (0.0617)  loss_classifier: 0.0243 (0.0250)  loss_box_reg: 0.0208 (0.0212)  loss_objectness: 0.0117 (0.0130)  loss_rpn_box_reg: 0.0027 (0.0025)  time: 1.4644  data: 0.0189  max mem: 11708
# Epoch: [4]  [260/279]  eta: 0:00:27  lr: 0.000500  loss: 0.0688 (0.0618)  loss_classifier: 0.0252 (0.0250)  loss_box_reg: 0.0210 (0.0212)  loss_objectness: 0.0172 (0.0131)  loss_rpn_box_reg: 0.0028 (0.0025)  time: 1.4628  data: 0.0181  max mem: 11708
# Epoch: [4]  [270/279]  eta: 0:00:13  lr: 0.000500  loss: 0.0629 (0.0619)  loss_classifier: 0.0252 (0.0250)  loss_box_reg: 0.0204 (0.0212)  loss_objectness: 0.0139 (0.0131)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.4624  data: 0.0182  max mem: 11708
# Epoch: [4]  [278/279]  eta: 0:00:01  lr: 0.000500  loss: 0.0571 (0.0617)  loss_classifier: 0.0242 (0.0250)  loss_box_reg: 0.0188 (0.0211)  loss_objectness: 0.0096 (0.0131)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.4611  data: 0.0174  max mem: 11708
# Epoch: [4] Total time: 0:06:48 (1.4647 s / it)
# Epoch: [5]  [  0/279]  eta: 0:08:38  lr: 0.000500  loss: 0.0824 (0.0824)  loss_classifier: 0.0284 (0.0284)  loss_box_reg: 0.0216 (0.0216)  loss_objectness: 0.0288 (0.0288)  loss_rpn_box_reg: 0.0035 (0.0035)  time: 1.8594  data: 0.4088  max mem: 11708
# Epoch: [5]  [ 10/279]  eta: 0:06:43  lr: 0.000500  loss: 0.0581 (0.0611)  loss_classifier: 0.0233 (0.0242)  loss_box_reg: 0.0177 (0.0182)  loss_objectness: 0.0091 (0.0165)  loss_rpn_box_reg: 0.0023 (0.0023)  time: 1.4990  data: 0.0550  max mem: 11708
# Epoch: [5]  [ 20/279]  eta: 0:06:23  lr: 0.000500  loss: 0.0581 (0.0634)  loss_classifier: 0.0243 (0.0254)  loss_box_reg: 0.0192 (0.0200)  loss_objectness: 0.0089 (0.0155)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.4622  data: 0.0188  max mem: 11708
# Epoch: [5]  [ 30/279]  eta: 0:06:07  lr: 0.000500  loss: 0.0578 (0.0610)  loss_classifier: 0.0243 (0.0246)  loss_box_reg: 0.0194 (0.0200)  loss_objectness: 0.0100 (0.0140)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.4617  data: 0.0182  max mem: 11708
# Epoch: [5]  [ 40/279]  eta: 0:05:51  lr: 0.000500  loss: 0.0552 (0.0587)  loss_classifier: 0.0212 (0.0236)  loss_box_reg: 0.0204 (0.0201)  loss_objectness: 0.0069 (0.0124)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.4617  data: 0.0190  max mem: 11708
# Epoch: [5]  [ 50/279]  eta: 0:05:36  lr: 0.000500  loss: 0.0526 (0.0581)  loss_classifier: 0.0219 (0.0233)  loss_box_reg: 0.0201 (0.0200)  loss_objectness: 0.0075 (0.0124)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.4633  data: 0.0194  max mem: 11708
# Epoch: [5]  [ 60/279]  eta: 0:05:21  lr: 0.000500  loss: 0.0549 (0.0590)  loss_classifier: 0.0230 (0.0238)  loss_box_reg: 0.0195 (0.0202)  loss_objectness: 0.0105 (0.0124)  loss_rpn_box_reg: 0.0026 (0.0025)  time: 1.4651  data: 0.0196  max mem: 11708
# Epoch: [5]  [ 70/279]  eta: 0:05:06  lr: 0.000500  loss: 0.0588 (0.0595)  loss_classifier: 0.0239 (0.0243)  loss_box_reg: 0.0206 (0.0205)  loss_objectness: 0.0097 (0.0121)  loss_rpn_box_reg: 0.0028 (0.0026)  time: 1.4643  data: 0.0196  max mem: 11708
# Epoch: [5]  [ 80/279]  eta: 0:04:52  lr: 0.000500  loss: 0.0617 (0.0605)  loss_classifier: 0.0258 (0.0247)  loss_box_reg: 0.0204 (0.0205)  loss_objectness: 0.0109 (0.0128)  loss_rpn_box_reg: 0.0028 (0.0026)  time: 1.4620  data: 0.0195  max mem: 11708
# Epoch: [5]  [ 90/279]  eta: 0:04:37  lr: 0.000500  loss: 0.0652 (0.0612)  loss_classifier: 0.0264 (0.0249)  loss_box_reg: 0.0212 (0.0207)  loss_objectness: 0.0136 (0.0130)  loss_rpn_box_reg: 0.0027 (0.0026)  time: 1.4635  data: 0.0202  max mem: 11708
# Epoch: [5]  [100/279]  eta: 0:04:22  lr: 0.000500  loss: 0.0557 (0.0603)  loss_classifier: 0.0231 (0.0247)  loss_box_reg: 0.0182 (0.0204)  loss_objectness: 0.0098 (0.0127)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.4642  data: 0.0197  max mem: 11708
# Epoch: [5]  [110/279]  eta: 0:04:07  lr: 0.000500  loss: 0.0557 (0.0605)  loss_classifier: 0.0249 (0.0249)  loss_box_reg: 0.0188 (0.0204)  loss_objectness: 0.0086 (0.0127)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.4622  data: 0.0190  max mem: 11708
# Epoch: [5]  [120/279]  eta: 0:03:53  lr: 0.000500  loss: 0.0554 (0.0598)  loss_classifier: 0.0249 (0.0247)  loss_box_reg: 0.0191 (0.0202)  loss_objectness: 0.0080 (0.0124)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.4632  data: 0.0191  max mem: 11708
# Epoch: [5]  [130/279]  eta: 0:03:38  lr: 0.000500  loss: 0.0554 (0.0601)  loss_classifier: 0.0231 (0.0248)  loss_box_reg: 0.0187 (0.0203)  loss_objectness: 0.0101 (0.0124)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.4624  data: 0.0182  max mem: 11708
# Epoch: [5]  [140/279]  eta: 0:03:23  lr: 0.000500  loss: 0.0565 (0.0601)  loss_classifier: 0.0238 (0.0248)  loss_box_reg: 0.0193 (0.0203)  loss_objectness: 0.0108 (0.0125)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.4601  data: 0.0174  max mem: 11708
# Epoch: [5]  [150/279]  eta: 0:03:09  lr: 0.000500  loss: 0.0536 (0.0599)  loss_classifier: 0.0227 (0.0247)  loss_box_reg: 0.0184 (0.0203)  loss_objectness: 0.0106 (0.0124)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.4625  data: 0.0190  max mem: 11708
# Epoch: [5]  [160/279]  eta: 0:02:54  lr: 0.000500  loss: 0.0516 (0.0595)  loss_classifier: 0.0219 (0.0246)  loss_box_reg: 0.0186 (0.0201)  loss_objectness: 0.0068 (0.0123)  loss_rpn_box_reg: 0.0022 (0.0025)  time: 1.4638  data: 0.0197  max mem: 11708
# Epoch: [5]  [170/279]  eta: 0:02:39  lr: 0.000500  loss: 0.0520 (0.0594)  loss_classifier: 0.0229 (0.0246)  loss_box_reg: 0.0206 (0.0203)  loss_objectness: 0.0065 (0.0121)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.4632  data: 0.0189  max mem: 11708
# Epoch: [5]  [180/279]  eta: 0:02:25  lr: 0.000500  loss: 0.0573 (0.0597)  loss_classifier: 0.0234 (0.0246)  loss_box_reg: 0.0218 (0.0203)  loss_objectness: 0.0087 (0.0122)  loss_rpn_box_reg: 0.0026 (0.0025)  time: 1.4646  data: 0.0195  max mem: 11708
# Epoch: [5]  [190/279]  eta: 0:02:10  lr: 0.000500  loss: 0.0504 (0.0592)  loss_classifier: 0.0219 (0.0244)  loss_box_reg: 0.0182 (0.0203)  loss_objectness: 0.0073 (0.0120)  loss_rpn_box_reg: 0.0022 (0.0025)  time: 1.4631  data: 0.0192  max mem: 11708
# Epoch: [5]  [200/279]  eta: 0:01:55  lr: 0.000500  loss: 0.0508 (0.0590)  loss_classifier: 0.0203 (0.0243)  loss_box_reg: 0.0184 (0.0203)  loss_objectness: 0.0072 (0.0119)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.4623  data: 0.0189  max mem: 11708
# Epoch: [5]  [210/279]  eta: 0:01:41  lr: 0.000500  loss: 0.0516 (0.0589)  loss_classifier: 0.0207 (0.0242)  loss_box_reg: 0.0204 (0.0204)  loss_objectness: 0.0067 (0.0118)  loss_rpn_box_reg: 0.0027 (0.0025)  time: 1.4640  data: 0.0183  max mem: 11708
# Epoch: [5]  [220/279]  eta: 0:01:26  lr: 0.000500  loss: 0.0552 (0.0590)  loss_classifier: 0.0212 (0.0242)  loss_box_reg: 0.0202 (0.0204)  loss_objectness: 0.0064 (0.0119)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.4637  data: 0.0185  max mem: 11708
# Epoch: [5]  [230/279]  eta: 0:01:11  lr: 0.000500  loss: 0.0602 (0.0593)  loss_classifier: 0.0250 (0.0244)  loss_box_reg: 0.0226 (0.0205)  loss_objectness: 0.0102 (0.0119)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.4634  data: 0.0196  max mem: 11708
# Epoch: [5]  [240/279]  eta: 0:00:57  lr: 0.000500  loss: 0.0579 (0.0592)  loss_classifier: 0.0240 (0.0243)  loss_box_reg: 0.0216 (0.0205)  loss_objectness: 0.0102 (0.0119)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.4629  data: 0.0181  max mem: 11708
# Epoch: [5]  [250/279]  eta: 0:00:42  lr: 0.000500  loss: 0.0554 (0.0593)  loss_classifier: 0.0224 (0.0244)  loss_box_reg: 0.0191 (0.0205)  loss_objectness: 0.0102 (0.0120)  loss_rpn_box_reg: 0.0021 (0.0025)  time: 1.4650  data: 0.0196  max mem: 11708
# Epoch: [5]  [260/279]  eta: 0:00:27  lr: 0.000500  loss: 0.0589 (0.0597)  loss_classifier: 0.0235 (0.0246)  loss_box_reg: 0.0219 (0.0206)  loss_objectness: 0.0109 (0.0121)  loss_rpn_box_reg: 0.0026 (0.0025)  time: 1.4674  data: 0.0207  max mem: 11708
# Epoch: [5]  [270/279]  eta: 0:00:13  lr: 0.000500  loss: 0.0606 (0.0597)  loss_classifier: 0.0250 (0.0245)  loss_box_reg: 0.0191 (0.0205)  loss_objectness: 0.0127 (0.0122)  loss_rpn_box_reg: 0.0026 (0.0025)  time: 1.4654  data: 0.0200  max mem: 11708
# Epoch: [5]  [278/279]  eta: 0:00:01  lr: 0.000500  loss: 0.0606 (0.0599)  loss_classifier: 0.0271 (0.0246)  loss_box_reg: 0.0190 (0.0206)  loss_objectness: 0.0103 (0.0122)  loss_rpn_box_reg: 0.0026 (0.0025)  time: 1.4630  data: 0.0186  max mem: 11708
# Epoch: [5] Total time: 0:06:48 (1.4650 s / it)
# Epoch: [6]  [  0/279]  eta: 0:08:53  lr: 0.000050  loss: 0.0767 (0.0767)  loss_classifier: 0.0393 (0.0393)  loss_box_reg: 0.0234 (0.0234)  loss_objectness: 0.0116 (0.0116)  loss_rpn_box_reg: 0.0023 (0.0023)  time: 1.9112  data: 0.4580  max mem: 11708
# Epoch: [6]  [ 10/279]  eta: 0:06:44  lr: 0.000050  loss: 0.0563 (0.0573)  loss_classifier: 0.0253 (0.0256)  loss_box_reg: 0.0198 (0.0201)  loss_objectness: 0.0070 (0.0092)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 1.5046  data: 0.0595  max mem: 11708
# Epoch: [6]  [ 20/279]  eta: 0:06:24  lr: 0.000050  loss: 0.0476 (0.0525)  loss_classifier: 0.0191 (0.0225)  loss_box_reg: 0.0177 (0.0186)  loss_objectness: 0.0070 (0.0092)  loss_rpn_box_reg: 0.0021 (0.0022)  time: 1.4641  data: 0.0192  max mem: 11708
# Epoch: [6]  [ 30/279]  eta: 0:06:08  lr: 0.000050  loss: 0.0452 (0.0535)  loss_classifier: 0.0193 (0.0225)  loss_box_reg: 0.0168 (0.0184)  loss_objectness: 0.0082 (0.0104)  loss_rpn_box_reg: 0.0021 (0.0022)  time: 1.4650  data: 0.0194  max mem: 11708
# Epoch: [6]  [ 40/279]  eta: 0:05:52  lr: 0.000050  loss: 0.0529 (0.0547)  loss_classifier: 0.0221 (0.0225)  loss_box_reg: 0.0192 (0.0192)  loss_objectness: 0.0087 (0.0106)  loss_rpn_box_reg: 0.0026 (0.0024)  time: 1.4647  data: 0.0196  max mem: 11708
# Epoch: [6]  [ 50/279]  eta: 0:05:37  lr: 0.000050  loss: 0.0588 (0.0568)  loss_classifier: 0.0241 (0.0233)  loss_box_reg: 0.0214 (0.0200)  loss_objectness: 0.0097 (0.0110)  loss_rpn_box_reg: 0.0027 (0.0025)  time: 1.4616  data: 0.0185  max mem: 11708
# Epoch: [6]  [ 60/279]  eta: 0:05:21  lr: 0.000050  loss: 0.0608 (0.0576)  loss_classifier: 0.0254 (0.0236)  loss_box_reg: 0.0226 (0.0201)  loss_objectness: 0.0103 (0.0113)  loss_rpn_box_reg: 0.0027 (0.0025)  time: 1.4600  data: 0.0175  max mem: 11708
# Epoch: [6]  [ 70/279]  eta: 0:05:07  lr: 0.000050  loss: 0.0648 (0.0593)  loss_classifier: 0.0268 (0.0244)  loss_box_reg: 0.0217 (0.0204)  loss_objectness: 0.0139 (0.0119)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.4619  data: 0.0186  max mem: 11708
# Epoch: [6]  [ 80/279]  eta: 0:04:52  lr: 0.000050  loss: 0.0587 (0.0590)  loss_classifier: 0.0242 (0.0243)  loss_box_reg: 0.0195 (0.0203)  loss_objectness: 0.0139 (0.0119)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.4626  data: 0.0189  max mem: 11708
# Epoch: [6]  [ 90/279]  eta: 0:04:37  lr: 0.000050  loss: 0.0496 (0.0580)  loss_classifier: 0.0203 (0.0239)  loss_box_reg: 0.0191 (0.0201)  loss_objectness: 0.0082 (0.0116)  loss_rpn_box_reg: 0.0021 (0.0025)  time: 1.4632  data: 0.0181  max mem: 11708
# Epoch: [6]  [100/279]  eta: 0:04:22  lr: 0.000050  loss: 0.0483 (0.0576)  loss_classifier: 0.0194 (0.0236)  loss_box_reg: 0.0200 (0.0200)  loss_objectness: 0.0064 (0.0114)  loss_rpn_box_reg: 0.0022 (0.0025)  time: 1.4631  data: 0.0176  max mem: 11708
# Epoch: [6]  [110/279]  eta: 0:04:07  lr: 0.000050  loss: 0.0569 (0.0578)  loss_classifier: 0.0230 (0.0238)  loss_box_reg: 0.0192 (0.0200)  loss_objectness: 0.0069 (0.0115)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.4632  data: 0.0177  max mem: 11708
# Epoch: [6]  [120/279]  eta: 0:03:53  lr: 0.000050  loss: 0.0587 (0.0586)  loss_classifier: 0.0255 (0.0241)  loss_box_reg: 0.0187 (0.0202)  loss_objectness: 0.0107 (0.0118)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.4644  data: 0.0186  max mem: 11708
# Epoch: [6]  [130/279]  eta: 0:03:38  lr: 0.000050  loss: 0.0589 (0.0586)  loss_classifier: 0.0255 (0.0241)  loss_box_reg: 0.0203 (0.0201)  loss_objectness: 0.0102 (0.0119)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.4635  data: 0.0185  max mem: 11708
# Epoch: [6]  [140/279]  eta: 0:03:23  lr: 0.000050  loss: 0.0537 (0.0582)  loss_classifier: 0.0201 (0.0240)  loss_box_reg: 0.0182 (0.0200)  loss_objectness: 0.0065 (0.0118)  loss_rpn_box_reg: 0.0021 (0.0025)  time: 1.4622  data: 0.0183  max mem: 11708
# Epoch: [6]  [150/279]  eta: 0:03:09  lr: 0.000050  loss: 0.0513 (0.0582)  loss_classifier: 0.0201 (0.0240)  loss_box_reg: 0.0187 (0.0199)  loss_objectness: 0.0078 (0.0119)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 1.4620  data: 0.0190  max mem: 11708
# ...
# Epoch: [47]  [250/279]  eta: 0:00:42  lr: 0.000000  loss: 0.0505 (0.0584)  loss_classifier: 0.0218 (0.0240)  loss_box_reg: 0.0185 (0.0203)  loss_objectness: 0.0075 (0.0116)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.4643  data: 0.0191  max mem: 11708
# Epoch: [47]  [260/279]  eta: 0:00:27  lr: 0.000000  loss: 0.0516 (0.0583)  loss_classifier: 0.0218 (0.0240)  loss_box_reg: 0.0189 (0.0203)  loss_objectness: 0.0075 (0.0115)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 1.4624  data: 0.0181  max mem: 11708
# Epoch: [47]  [270/279]  eta: 0:00:13  lr: 0.000000  loss: 0.0528 (0.0583)  loss_classifier: 0.0212 (0.0239)  loss_box_reg: 0.0184 (0.0203)  loss_objectness: 0.0072 (0.0115)  loss_rpn_box_reg: 0.0022 (0.0025)  time: 1.4637  data: 0.0194  max mem: 11708
# Epoch: [47]  [278/279]  eta: 0:00:01  lr: 0.000000  loss: 0.0476 (0.0581)  loss_classifier: 0.0216 (0.0240)  loss_box_reg: 0.0180 (0.0203)  loss_objectness: 0.0068 (0.0115)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.4642  data: 0.0206  max mem: 11708
# Epoch: [47] Total time: 0:06:49 (1.4683 s / it)
# Epoch: [48]  [  0/279]  eta: 0:09:05  lr: 0.000000  loss: 0.0749 (0.0749)  loss_classifier: 0.0306 (0.0306)  loss_box_reg: 0.0185 (0.0185)  loss_objectness: 0.0233 (0.0233)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.9545  data: 0.4999  max mem: 11708
# Epoch: [48]  [ 10/279]  eta: 0:06:44  lr: 0.000000  loss: 0.0541 (0.0617)  loss_classifier: 0.0231 (0.0259)  loss_box_reg: 0.0211 (0.0212)  loss_objectness: 0.0120 (0.0123)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.5048  data: 0.0591  max mem: 11708
# Epoch: [48]  [ 20/279]  eta: 0:06:24  lr: 0.000000  loss: 0.0625 (0.0627)  loss_classifier: 0.0237 (0.0253)  loss_box_reg: 0.0211 (0.0211)  loss_objectness: 0.0120 (0.0138)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.4628  data: 0.0167  max mem: 11708
# Epoch: [48]  [ 30/279]  eta: 0:06:08  lr: 0.000000  loss: 0.0609 (0.0612)  loss_classifier: 0.0231 (0.0244)  loss_box_reg: 0.0204 (0.0209)  loss_objectness: 0.0108 (0.0135)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.4645  data: 0.0184  max mem: 11708
# Epoch: [48]  [ 40/279]  eta: 0:05:52  lr: 0.000000  loss: 0.0505 (0.0591)  loss_classifier: 0.0200 (0.0237)  loss_box_reg: 0.0193 (0.0205)  loss_objectness: 0.0073 (0.0125)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 1.4636  data: 0.0188  max mem: 11708
# Epoch: [48]  [ 50/279]  eta: 0:05:37  lr: 0.000000  loss: 0.0517 (0.0592)  loss_classifier: 0.0239 (0.0236)  loss_box_reg: 0.0193 (0.0205)  loss_objectness: 0.0096 (0.0128)  loss_rpn_box_reg: 0.0021 (0.0024)  time: 1.4638  data: 0.0185  max mem: 11708
# Epoch: [48]  [ 60/279]  eta: 0:05:22  lr: 0.000000  loss: 0.0553 (0.0589)  loss_classifier: 0.0227 (0.0238)  loss_box_reg: 0.0198 (0.0203)  loss_objectness: 0.0089 (0.0125)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.4638  data: 0.0188  max mem: 11708
# Epoch: [48]  [ 70/279]  eta: 0:05:07  lr: 0.000000  loss: 0.0553 (0.0598)  loss_classifier: 0.0229 (0.0242)  loss_box_reg: 0.0185 (0.0205)  loss_objectness: 0.0119 (0.0127)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 1.4642  data: 0.0195  max mem: 11708
# Epoch: [48]  [ 80/279]  eta: 0:04:52  lr: 0.000000  loss: 0.0585 (0.0597)  loss_classifier: 0.0239 (0.0242)  loss_box_reg: 0.0189 (0.0206)  loss_objectness: 0.0101 (0.0124)  loss_rpn_box_reg: 0.0025 (0.0024)  time: 1.4646  data: 0.0189  max mem: 11708
# Epoch: [48]  [ 90/279]  eta: 0:04:37  lr: 0.000000  loss: 0.0538 (0.0592)  loss_classifier: 0.0213 (0.0242)  loss_box_reg: 0.0189 (0.0204)  loss_objectness: 0.0098 (0.0122)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 1.4624  data: 0.0177  max mem: 11708
# Epoch: [48]  [100/279]  eta: 0:04:22  lr: 0.000000  loss: 0.0517 (0.0588)  loss_classifier: 0.0207 (0.0240)  loss_box_reg: 0.0197 (0.0202)  loss_objectness: 0.0098 (0.0123)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 1.4627  data: 0.0187  max mem: 11708
# Epoch: [48]  [110/279]  eta: 0:04:08  lr: 0.000000  loss: 0.0536 (0.0589)  loss_classifier: 0.0223 (0.0241)  loss_box_reg: 0.0201 (0.0201)  loss_objectness: 0.0084 (0.0122)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.4648  data: 0.0199  max mem: 11708
# Epoch: [48]  [120/279]  eta: 0:03:53  lr: 0.000000  loss: 0.0541 (0.0589)  loss_classifier: 0.0235 (0.0241)  loss_box_reg: 0.0198 (0.0201)  loss_objectness: 0.0082 (0.0122)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.4648  data: 0.0200  max mem: 11708
# Epoch: [48]  [130/279]  eta: 0:03:38  lr: 0.000000  loss: 0.0563 (0.0585)  loss_classifier: 0.0230 (0.0240)  loss_box_reg: 0.0179 (0.0200)  loss_objectness: 0.0074 (0.0121)  loss_rpn_box_reg: 0.0021 (0.0024)  time: 1.4653  data: 0.0207  max mem: 11708
# Epoch: [48]  [140/279]  eta: 0:03:23  lr: 0.000000  loss: 0.0566 (0.0586)  loss_classifier: 0.0230 (0.0240)  loss_box_reg: 0.0200 (0.0201)  loss_objectness: 0.0094 (0.0121)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 1.4635  data: 0.0192  max mem: 11708
# Epoch: [48]  [150/279]  eta: 0:03:09  lr: 0.000000  loss: 0.0633 (0.0586)  loss_classifier: 0.0240 (0.0240)  loss_box_reg: 0.0205 (0.0201)  loss_objectness: 0.0094 (0.0121)  loss_rpn_box_reg: 0.0027 (0.0024)  time: 1.4623  data: 0.0182  max mem: 11708
# Epoch: [48]  [160/279]  eta: 0:02:54  lr: 0.000000  loss: 0.0524 (0.0585)  loss_classifier: 0.0225 (0.0239)  loss_box_reg: 0.0196 (0.0201)  loss_objectness: 0.0068 (0.0121)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.4629  data: 0.0177  max mem: 11708
# Epoch: [48]  [170/279]  eta: 0:02:39  lr: 0.000000  loss: 0.0495 (0.0582)  loss_classifier: 0.0217 (0.0238)  loss_box_reg: 0.0200 (0.0201)  loss_objectness: 0.0071 (0.0118)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.4651  data: 0.0197  max mem: 11708
# Epoch: [48]  [180/279]  eta: 0:02:25  lr: 0.000000  loss: 0.0544 (0.0587)  loss_classifier: 0.0235 (0.0240)  loss_box_reg: 0.0211 (0.0201)  loss_objectness: 0.0085 (0.0121)  loss_rpn_box_reg: 0.0027 (0.0024)  time: 1.4667  data: 0.0213  max mem: 11708
# Epoch: [48]  [190/279]  eta: 0:02:10  lr: 0.000000  loss: 0.0627 (0.0590)  loss_classifier: 0.0248 (0.0240)  loss_box_reg: 0.0211 (0.0201)  loss_objectness: 0.0117 (0.0124)  loss_rpn_box_reg: 0.0026 (0.0024)  time: 1.4646  data: 0.0191  max mem: 11708
# Epoch: [48]  [200/279]  eta: 0:01:55  lr: 0.000000  loss: 0.0545 (0.0587)  loss_classifier: 0.0227 (0.0240)  loss_box_reg: 0.0190 (0.0201)  loss_objectness: 0.0086 (0.0122)  loss_rpn_box_reg: 0.0025 (0.0024)  time: 1.4641  data: 0.0182  max mem: 11708
# Epoch: [48]  [210/279]  eta: 0:01:41  lr: 0.000000  loss: 0.0517 (0.0587)  loss_classifier: 0.0220 (0.0239)  loss_box_reg: 0.0195 (0.0201)  loss_objectness: 0.0086 (0.0122)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.4668  data: 0.0206  max mem: 11708
# Epoch: [48]  [220/279]  eta: 0:01:26  lr: 0.000000  loss: 0.0513 (0.0587)  loss_classifier: 0.0202 (0.0239)  loss_box_reg: 0.0204 (0.0202)  loss_objectness: 0.0092 (0.0122)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.4668  data: 0.0219  max mem: 11708
# Epoch: [48]  [230/279]  eta: 0:01:11  lr: 0.000000  loss: 0.0538 (0.0586)  loss_classifier: 0.0231 (0.0239)  loss_box_reg: 0.0200 (0.0202)  loss_objectness: 0.0092 (0.0121)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.4645  data: 0.0202  max mem: 11708
# Epoch: [48]  [240/279]  eta: 0:00:57  lr: 0.000000  loss: 0.0563 (0.0588)  loss_classifier: 0.0231 (0.0240)  loss_box_reg: 0.0204 (0.0202)  loss_objectness: 0.0096 (0.0121)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.4645  data: 0.0196  max mem: 11708
# Epoch: [48]  [250/279]  eta: 0:00:42  lr: 0.000000  loss: 0.0583 (0.0589)  loss_classifier: 0.0253 (0.0241)  loss_box_reg: 0.0183 (0.0202)  loss_objectness: 0.0117 (0.0122)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.4646  data: 0.0195  max mem: 11708
# Epoch: [48]  [260/279]  eta: 0:00:27  lr: 0.000000  loss: 0.0583 (0.0589)  loss_classifier: 0.0251 (0.0241)  loss_box_reg: 0.0190 (0.0202)  loss_objectness: 0.0125 (0.0122)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 1.4632  data: 0.0188  max mem: 11708
# Epoch: [48]  [270/279]  eta: 0:00:13  lr: 0.000000  loss: 0.0611 (0.0591)  loss_classifier: 0.0253 (0.0242)  loss_box_reg: 0.0232 (0.0203)  loss_objectness: 0.0084 (0.0122)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.4630  data: 0.0190  max mem: 11708
# Epoch: [48]  [278/279]  eta: 0:00:01  lr: 0.000000  loss: 0.0606 (0.0590)  loss_classifier: 0.0240 (0.0242)  loss_box_reg: 0.0199 (0.0202)  loss_objectness: 0.0084 (0.0122)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 1.4638  data: 0.0197  max mem: 11708
# Epoch: [48] Total time: 0:06:49 (1.4662 s / it)
# Epoch: [49]  [  0/279]  eta: 0:08:56  lr: 0.000000  loss: 0.0377 (0.0377)  loss_classifier: 0.0144 (0.0144)  loss_box_reg: 0.0168 (0.0168)  loss_objectness: 0.0042 (0.0042)  loss_rpn_box_reg: 0.0023 (0.0023)  time: 1.9231  data: 0.4195  max mem: 11708
# Epoch: [49]  [ 10/279]  eta: 0:06:45  lr: 0.000000  loss: 0.0456 (0.0563)  loss_classifier: 0.0198 (0.0230)  loss_box_reg: 0.0175 (0.0190)  loss_objectness: 0.0075 (0.0119)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.5090  data: 0.0572  max mem: 11708
# Epoch: [49]  [ 20/279]  eta: 0:06:24  lr: 0.000000  loss: 0.0547 (0.0573)  loss_classifier: 0.0201 (0.0233)  loss_box_reg: 0.0175 (0.0192)  loss_objectness: 0.0075 (0.0123)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 1.4646  data: 0.0195  max mem: 11708
# Epoch: [49]  [ 30/279]  eta: 0:06:08  lr: 0.000000  loss: 0.0462 (0.0570)  loss_classifier: 0.0192 (0.0226)  loss_box_reg: 0.0170 (0.0185)  loss_objectness: 0.0062 (0.0135)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 1.4630  data: 0.0185  max mem: 11708
# Epoch: [49]  [ 40/279]  eta: 0:05:52  lr: 0.000000  loss: 0.0500 (0.0571)  loss_classifier: 0.0196 (0.0227)  loss_box_reg: 0.0171 (0.0191)  loss_objectness: 0.0078 (0.0129)  loss_rpn_box_reg: 0.0025 (0.0024)  time: 1.4637  data: 0.0193  max mem: 11708
# Epoch: [49]  [ 50/279]  eta: 0:05:37  lr: 0.000000  loss: 0.0581 (0.0571)  loss_classifier: 0.0222 (0.0227)  loss_box_reg: 0.0216 (0.0193)  loss_objectness: 0.0078 (0.0126)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 1.4641  data: 0.0197  max mem: 11708
# Epoch: [49]  [ 60/279]  eta: 0:05:22  lr: 0.000000  loss: 0.0552 (0.0569)  loss_classifier: 0.0213 (0.0227)  loss_box_reg: 0.0187 (0.0193)  loss_objectness: 0.0080 (0.0125)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.4655  data: 0.0190  max mem: 11708
# Epoch: [49]  [ 70/279]  eta: 0:05:07  lr: 0.000000  loss: 0.0514 (0.0566)  loss_classifier: 0.0211 (0.0228)  loss_box_reg: 0.0187 (0.0194)  loss_objectness: 0.0079 (0.0120)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 1.4640  data: 0.0180  max mem: 11708
# Epoch: [49]  [ 80/279]  eta: 0:04:52  lr: 0.000000  loss: 0.0510 (0.0570)  loss_classifier: 0.0235 (0.0230)  loss_box_reg: 0.0171 (0.0192)  loss_objectness: 0.0106 (0.0124)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 1.4631  data: 0.0188  max mem: 11708
# Epoch: [49]  [ 90/279]  eta: 0:04:37  lr: 0.000000  loss: 0.0524 (0.0578)  loss_classifier: 0.0227 (0.0235)  loss_box_reg: 0.0183 (0.0194)  loss_objectness: 0.0108 (0.0125)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 1.4641  data: 0.0193  max mem: 11708
# Epoch: [49]  [100/279]  eta: 0:04:22  lr: 0.000000  loss: 0.0573 (0.0588)  loss_classifier: 0.0227 (0.0239)  loss_box_reg: 0.0220 (0.0197)  loss_objectness: 0.0087 (0.0127)  loss_rpn_box_reg: 0.0028 (0.0025)  time: 1.4645  data: 0.0187  max mem: 11708
# Epoch: [49]  [110/279]  eta: 0:04:08  lr: 0.000000  loss: 0.0587 (0.0585)  loss_classifier: 0.0242 (0.0239)  loss_box_reg: 0.0220 (0.0199)  loss_objectness: 0.0078 (0.0122)  loss_rpn_box_reg: 0.0027 (0.0025)  time: 1.4655  data: 0.0196  max mem: 11708
# Epoch: [49]  [120/279]  eta: 0:03:53  lr: 0.000000  loss: 0.0587 (0.0586)  loss_classifier: 0.0243 (0.0241)  loss_box_reg: 0.0208 (0.0199)  loss_objectness: 0.0079 (0.0121)  loss_rpn_box_reg: 0.0026 (0.0025)  time: 1.4651  data: 0.0189  max mem: 11708
# Epoch: [49]  [130/279]  eta: 0:03:38  lr: 0.000000  loss: 0.0603 (0.0587)  loss_classifier: 0.0255 (0.0240)  loss_box_reg: 0.0212 (0.0199)  loss_objectness: 0.0101 (0.0123)  loss_rpn_box_reg: 0.0026 (0.0025)  time: 1.4648  data: 0.0180  max mem: 11708
# Epoch: [49]  [140/279]  eta: 0:03:24  lr: 0.000000  loss: 0.0591 (0.0588)  loss_classifier: 0.0237 (0.0241)  loss_box_reg: 0.0212 (0.0200)  loss_objectness: 0.0100 (0.0122)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.4653  data: 0.0187  max mem: 11708
# Epoch: [49]  [150/279]  eta: 0:03:09  lr: 0.000000  loss: 0.0591 (0.0588)  loss_classifier: 0.0242 (0.0241)  loss_box_reg: 0.0201 (0.0201)  loss_objectness: 0.0100 (0.0122)  loss_rpn_box_reg: 0.0022 (0.0025)  time: 1.4653  data: 0.0194  max mem: 11708
# Epoch: [49]  [160/279]  eta: 0:02:54  lr: 0.000000  loss: 0.0562 (0.0588)  loss_classifier: 0.0238 (0.0241)  loss_box_reg: 0.0203 (0.0201)  loss_objectness: 0.0096 (0.0121)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.4659  data: 0.0203  max mem: 11708
# Epoch: [49]  [170/279]  eta: 0:02:39  lr: 0.000000  loss: 0.0608 (0.0593)  loss_classifier: 0.0262 (0.0243)  loss_box_reg: 0.0211 (0.0202)  loss_objectness: 0.0099 (0.0123)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.4657  data: 0.0207  max mem: 11708
# Epoch: [49]  [180/279]  eta: 0:02:25  lr: 0.000000  loss: 0.0582 (0.0591)  loss_classifier: 0.0241 (0.0242)  loss_box_reg: 0.0202 (0.0203)  loss_objectness: 0.0089 (0.0121)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.4649  data: 0.0197  max mem: 11708
# Epoch: [49]  [190/279]  eta: 0:02:10  lr: 0.000000  loss: 0.0555 (0.0593)  loss_classifier: 0.0235 (0.0244)  loss_box_reg: 0.0201 (0.0204)  loss_objectness: 0.0083 (0.0120)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.4635  data: 0.0188  max mem: 11708
# Epoch: [49]  [200/279]  eta: 0:01:55  lr: 0.000000  loss: 0.0591 (0.0594)  loss_classifier: 0.0247 (0.0244)  loss_box_reg: 0.0214 (0.0204)  loss_objectness: 0.0096 (0.0121)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.4641  data: 0.0191  max mem: 11708
# Epoch: [49]  [210/279]  eta: 0:01:41  lr: 0.000000  loss: 0.0562 (0.0595)  loss_classifier: 0.0233 (0.0244)  loss_box_reg: 0.0192 (0.0205)  loss_objectness: 0.0132 (0.0122)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.4666  data: 0.0194  max mem: 11708
# Epoch: [49]  [220/279]  eta: 0:01:26  lr: 0.000000  loss: 0.0580 (0.0598)  loss_classifier: 0.0252 (0.0244)  loss_box_reg: 0.0214 (0.0205)  loss_objectness: 0.0096 (0.0123)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.4664  data: 0.0198  max mem: 11708
# Epoch: [49]  [230/279]  eta: 0:01:11  lr: 0.000000  loss: 0.0556 (0.0597)  loss_classifier: 0.0255 (0.0245)  loss_box_reg: 0.0202 (0.0205)  loss_objectness: 0.0082 (0.0122)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.4651  data: 0.0196  max mem: 11708
# Epoch: [49]  [240/279]  eta: 0:00:57  lr: 0.000000  loss: 0.0554 (0.0596)  loss_classifier: 0.0210 (0.0244)  loss_box_reg: 0.0186 (0.0204)  loss_objectness: 0.0100 (0.0122)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.4655  data: 0.0191  max mem: 11708
# Epoch: [49]  [250/279]  eta: 0:00:42  lr: 0.000000  loss: 0.0573 (0.0596)  loss_classifier: 0.0244 (0.0245)  loss_box_reg: 0.0209 (0.0204)  loss_objectness: 0.0104 (0.0123)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.4655  data: 0.0184  max mem: 11708
# Epoch: [49]  [260/279]  eta: 0:00:27  lr: 0.000000  loss: 0.0536 (0.0593)  loss_classifier: 0.0214 (0.0243)  loss_box_reg: 0.0203 (0.0204)  loss_objectness: 0.0081 (0.0121)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.4642  data: 0.0185  max mem: 11708
# Epoch: [49]  [270/279]  eta: 0:00:13  lr: 0.000000  loss: 0.0530 (0.0592)  loss_classifier: 0.0201 (0.0243)  loss_box_reg: 0.0204 (0.0204)  loss_objectness: 0.0079 (0.0120)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.4647  data: 0.0204  max mem: 11708
# Epoch: [49]  [278/279]  eta: 0:00:01  lr: 0.000000  loss: 0.0489 (0.0589)  loss_classifier: 0.0192 (0.0242)  loss_box_reg: 0.0205 (0.0204)  loss_objectness: 0.0078 (0.0119)  loss_rpn_box_reg: 0.0021 (0.0025)  time: 1.4664  data: 0.0210  max mem: 11708
# Epoch: [49] Total time: 0:06:49 (1.4668 s / it)

# %% [markdown]
# Saving Model

# %%
# %cd '/drive/MyDrive/CSE499 Project/modelSaves/Attention Mechanism/SENet/model3'

torch.save(model.state_dict(), 'model.pth')

torch.save({
'epoch':num_epochs,
'model_state_dict':model.state_dict(),
'optimizer_state_dict':optimizer.state_dict(),
},'ckpt.pth')
# Out:
# [Errno 2] No such file or directory: '/drive/MyDrive/CSE499 Project/modelSaves/Attention Mechanism/SENet/model3'
# /content/Tutorial-Book-Utils

# %% [markdown]
# Loading model

# %%
# %cd '/drive/MyDrive/CSE499 Project/modelSaves/Attention Mechanism/Channel/SENet/model3'
model.load_state_dict(torch.load('./model.pth'))
model = model.to(device)
# Out:
# /drive/.shortcut-targets-by-id/1M-kTVs7g43FucvCjcPvKwiR8r1e1qtHe/CSE499_Project/modelSaves/Attention Mechanism/Channel/SENet/model3

# %% [markdown]
# #Testing

# %%
test_dataset = MitosisImagesDatasetTest(test_dir, 481, 451,transforms=get_transform(train=False))

torch.manual_seed(1)
indices = torch.randperm(len(dataset_test)).tolist()

test_split = 0.2
tsize = int(len(test_dataset)*test_split)

test_dataset = torch.utils.data.Subset(test_dataset, indices[-tsize:])

test_data_loader = torch.utils.data.DataLoader(
  test_dataset,
  batch_size=10,
  shuffle=False,
  num_workers=4,
  collate_fn=utils.collate_fn,
)
test_dir
# Out:
# '/drive/MyDrive/CSE499 Project/Patch Datasets/Hamamatsu S360/'

# %%
def apply_nms(orig_prediction, iou_thresh=0.3):
  keep = torchvision.ops.nms(orig_prediction['boxes'], orig_prediction['scores'], iou_thresh)
  
  final_prediction = orig_prediction
  final_prediction['boxes'] = final_prediction['boxes'][keep]
  final_prediction['scores'] = final_prediction['scores'][keep]
  final_prediction['labels'] = final_prediction['labels'][keep]
  
  return final_prediction

# function to convert a torchtensor back to PIL image
def torch_to_pil(img):
  return torchtrans.ToPILImage()(img).convert('RGB')

# %%
test_dataset = MitosisImagesDatasetTest(test_dir, 481, 451, transforms = get_transform(train=False))
dataset      = MitosisImagesDatasetTest(test_dir, 481, 451)
test_dir
# Out:
# '/drive/MyDrive/CSE499 Project/Patch Datasets/Hamamatsu S360/'

# %% [markdown]
# Predicted labels

# %%
# pick one image from the test set
INDEX_PICK = 53
model=model.to('cpu')
img, target = test_dataset[INDEX_PICK]
# put the model in evaluation mode
model.eval()
with torch.no_grad():
  img = img.to('cpu')
  prediction = model([img])[0]

print('MODEL OUTPUT\n')
nms_prediction = apply_nms(prediction,iou_thresh=0.3)

plot_img_bbox(torch_to_pil(img), nms_prediction)
# Out:
# MODEL OUTPUT

# %% [markdown]
# Ground Truth labels

# %%
img, target = dataset[INDEX_PICK]
plot_img_bbox(img, target)

# %%
def make_prediction(model, img, threshold):
    model.eval()
    preds = model(img)
    for id in range(len(preds)) :
        idx_list = []

        for idx, score in enumerate(preds[id]['scores']) :
            if score > threshold : 
                idx_list.append(idx)

        preds[id]['boxes'] = preds[id]['boxes'][idx_list]
        preds[id]['labels'] = preds[id]['labels'][idx_list]
        preds[id]['scores'] = preds[id]['scores'][idx_list]

    return preds

# %%
model=model.to(device)

# %%
from tqdm import tqdm

labels = []
preds_adj_all = []
annot_all = []

for im, annot in tqdm(test_data_loader, position = 0, leave = True):
    im = list(img.to(device) for img in im)
    #annot = [{k: v.to(device) for k, v in t.items()} for t in annot]

    for t in annot:
        labels += t['labels']

    with torch.no_grad():
        preds_adj = make_prediction(model, im, 0.3)
        preds_adj = [{k: v.to(torch.device('cpu')) for k, v in t.items()} for t in preds_adj]
        preds_adj_all.append(preds_adj)
        annot_all.append(annot)
# Out:
# 100%|██████████| 38/38 [01:17<00:00,  2.03s/it]

# %%
# %cd /content/Tutorial-Book-Utils
import utils_ObjectDetection as utils2
# Out:
# /content/Tutorial-Book-Utils

# %% [markdown]
# Trained on Dataset X, Tested on Dataset Y

# %%
sample_metrics = []
for batch_i in range(len(preds_adj_all)):
    sample_metrics += utils2.get_batch_statistics(preds_adj_all[batch_i], annot_all[batch_i], iou_threshold=0.3) 

true_positives, pred_scores, pred_labels = [torch.cat(x, 0) for x in list(zip(*sample_metrics))]
precision, recall, AP, f1, ap_class = utils2.ap_per_class(true_positives, pred_scores, pred_labels, torch.tensor(labels))
mAP = torch.mean(AP)
print(f'mAP : {mAP}')
# print(f'AP : {AP}')
# Out:
# mAP : 0.5831964649914059

# %%
print('precision: ',precision)
print('recall: ',recall)
print('AP: ',AP)
print('f1: ',f1)
print('ap_class: ',ap_class)
# Out:
# precision:  tensor([0.1024])
# recall:  tensor([0.8482])
# AP:  tensor([0.5832], dtype=torch.float64)
# f1:  tensor([0.1828])
# ap_class:  tensor([1])

# %%
print(train_dir)
print(test_dir)
# Out:
# /drive/MyDrive/CSE499 Project/Patch Datasets/Aperio ScanScope CS2/
# /drive/MyDrive/CSE499 Project/Patch Datasets/Hamamatsu S360/
