# %% [markdown]
# #Installing libraries etc.

# %%
from IPython.display import clear_output
# %load_ext autoreload
# %autoreload 2
# Install dependencies and 
# !pip install albumentations==0.4.6
# !pip install pycocotools --quiet

# !git clone https://github.com/Pseudo-Lab/Tutorial-Book-Utils
# !python Tutorial-Book-Utils/PL_data_loader.py --data FaceMaskDetection

# Clone TorchVision repo and copy helper files
# !git clone https://github.com/pytorch/vision.git
# %cd vision
# !git checkout v0.3.0
# %cd ..
# !cp vision/references/detection/utils.py ./
# !cp vision/references/detection/transforms.py ./
# !cp vision/references/detection/coco_eval.py ./
# !cp vision/references/detection/engine.py ./
# !cp vision/references/detection/coco_utils.py ./


# basic python and ML Libraries
import os
import random
import numpy as np
import pandas as pd

# for ignoring warnings
import warnings
warnings.filterwarnings('ignore')

# We will be reading images using OpenCV
import cv2

# matplotlib for visualization
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# torchvision libraries
import torch
import torchvision
from torchvision import transforms as torchtrans  
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.backbone_utils import resnet_fpn_backbone

from torchvision.models.detection.rpn import AnchorGenerator

import torch.nn as nn
import torch.nn.functional as F

# helper libraries
from engine import train_one_epoch, evaluate
import utils
import transforms as T

# for image augmentations
import albumentations as A
from albumentations.pytorch.transforms import ToTensorV2

# !apt-get install python3-openslide
from openslide import open_slide

import plotly.express as px
clear_output()

# %%
from torchvision.models.detection import FasterRCNN
from torch.utils.data import DataLoader, Dataset
import sys
import os
from torchvision.ops import misc as misc_nn_ops

import torch.hub
from functools import partial
from typing import Type, Any, Callable, Union, List, Optional
import torch
import warnings
from typing import Callable, Dict, List, Optional, Union
from torch import nn, Tensor
from torchvision.ops import misc as misc_nn_ops
from torchvision.ops.feature_pyramid_network import ExtraFPNBlock, FeaturePyramidNetwork, LastLevelMaxPool
from collections import OrderedDict
from torchvision.models import resnet 
from torch.hub import load_state_dict_from_url
import enum
from typing import Sequence, TypeVar, Type
from dataclasses import dataclass,fields

T = TypeVar("T", bound=enum.Enum)


class StrEnumMeta(enum.EnumMeta):
    auto = enum.auto

    def from_str(self: Type[T], member: str) -> T:  # type: ignore[misc]
        try:
            return self[member]
        except KeyError:
            # TODO: use `add_suggestion` from torchvision.prototype.utils._internal to improve the error message as
            #  soon as it is migrated.
            raise ValueError(f"Unknown value '{member}' for {self.__name__}.") from None


class StrEnum(enum.Enum, metaclass=StrEnumMeta):
    pass

@dataclass
class Weights:
    """
    This class is used to group important attributes associated with the pre-trained weights.
    Args:
        url (str): The location where we find the weights.
        transforms (Callable): A callable that constructs the preprocessing method (or validation preset transforms)
            needed to use the model. The reason we attach a constructor method rather than an already constructed
            object is because the specific object might have memory and thus we want to delay initialization until
            needed.
        meta (Dict[str, Any]): Stores meta-data related to the weights of the model and its configuration. These can be
            informative attributes (for example the number of parameters/flops, recipe link/methods used in training
            etc), configuration parameters (for example the `num_classes`) needed to construct the model or important
            meta-data (for example the `classes` of a classification model) needed to use the model.
    """

    url: str
    transforms: Callable
    meta: Dict[str, Any]

class WeightsEnum(StrEnum):
    """
    This class is the parent class of all model weights. Each model building method receives an optional `weights`
    parameter with its associated pre-trained weights. It inherits from `Enum` and its values should be of type
    `Weights`.
    Args:
        value (Weights): The data class entry with the weight information.
    """

    def __init__(self, value: Weights):
        self._value_ = value

    @classmethod
    def verify(cls, obj: Any) -> Any:
        if obj is not None:
            if type(obj) is str:
                obj = cls.from_str(obj.replace(cls.__name__ + ".", ""))
            elif not isinstance(obj, cls):
                raise TypeError(
                    f"Invalid Weight class provided; expected {cls.__name__} but received {obj.__class__.__name__}."
                )
        return obj

    def get_state_dict(self, progress: bool) -> OrderedDict:
        return load_state_dict_from_url(self.url, progress=progress)

    def __repr__(self) -> str:
        return f"{self.__class__.__name__}.{self._name_}"

    def __getattr__(self, name):
        # Be able to fetch Weights attributes directly
        for f in fields(Weights):
            if f.name == name:
                return object.__getattribute__(self.value, name)
        return super().__getattr__(name)

class IntermediateLayerGetter(nn.ModuleDict):
    _version = 2
    __annotations__ = {
        "return_layers": Dict[str, str],
    }

    def __init__(self, model: nn.Module, return_layers: Dict[str, str]) -> None:
        if not set(return_layers).issubset([name for name, _ in model.named_children()]):
            raise ValueError("return_layers are not present in model")
        orig_return_layers = return_layers
        return_layers = {str(k): str(v) for k, v in return_layers.items()}
        layers = OrderedDict()
        for name, module in model.named_children():
            layers[name] = module
            if name in return_layers:
                del return_layers[name]
            if not return_layers:
                break

        super().__init__(layers)
        self.return_layers = orig_return_layers

    def forward(self, x):
        out = OrderedDict()
        for name, module in self.items():
            x = module(x)
            if name in self.return_layers:
                out_name = self.return_layers[name]
                out[out_name] = x
        return out

class BackboneWithFPN(nn.Module):
    def __init__(
        self,
        backbone: nn.Module,
        return_layers: Dict[str, str],
        in_channels_list: List[int],
        out_channels: int,
        extra_blocks: Optional[ExtraFPNBlock] = None,
    ) -> None:
        super().__init__()

        if extra_blocks is None:
            extra_blocks = LastLevelMaxPool()

        self.body = IntermediateLayerGetter(backbone, return_layers=return_layers)
        self.fpn = FeaturePyramidNetwork(
            in_channels_list=in_channels_list,
            out_channels=out_channels,
            extra_blocks=extra_blocks,
        )
        self.out_channels = out_channels

    def forward(self, x: Tensor) -> Dict[str, Tensor]:
        x = self.body(x)
        x = self.fpn(x)
        return x

def _resnet_fpn_extractor(
    backbone: resnet.ResNet,
    trainable_layers: int,
    returned_layers: Optional[List[int]] = None,
    extra_blocks: Optional[ExtraFPNBlock] = None,
) -> BackboneWithFPN:

    # select layers that wont be frozen
    if trainable_layers < 0 or trainable_layers > 5:
        raise ValueError(f"Trainable layers should be in the range [0,5], got {trainable_layers}")
    layers_to_train = ["layer4", "layer3", "layer2", "layer1", "conv1"][:trainable_layers]
    if trainable_layers == 5:
        layers_to_train.append("bn1")
    for name, parameter in backbone.named_parameters():
        if all([not name.startswith(layer) for layer in layers_to_train]):
            parameter.requires_grad_(False)

    if extra_blocks is None:
        extra_blocks = LastLevelMaxPool()

    if returned_layers is None:
        returned_layers = [1, 2, 3, 4]
    if min(returned_layers) <= 0 or max(returned_layers) >= 5:
        raise ValueError(f"Each returned layer should be in the range [1,4]. Got {returned_layers}")
    return_layers = {f"layer{k}": str(v) for v, k in enumerate(returned_layers)}

    in_channels_stage2 = backbone.inplanes // 8
    in_channels_list = [in_channels_stage2 * 2 ** (i - 1) for i in returned_layers]
    out_channels = 256
    return BackboneWithFPN(backbone, return_layers, in_channels_list, out_channels, extra_blocks=extra_blocks)

def resnet_fpn_backbone(
    *,
    backbone_name: str,
    weights: Optional[WeightsEnum],
    norm_layer: Callable[..., nn.Module] = misc_nn_ops.FrozenBatchNorm2d,
    trainable_layers: int = 3,
    returned_layers: Optional[List[int]] = None,
    extra_blocks: Optional[ExtraFPNBlock] = None,
) -> BackboneWithFPN:
    
    backbone = resnet.__dict__[backbone_name](weights=weights, norm_layer=norm_layer)
    return _resnet_fpn_extractor(backbone, trainable_layers, returned_layers, extra_blocks)

# %%
# from vision.torchvision.models.detection.backbone_utils import _resnet_fpn_extractor,_validate_trainable_layers

# %% [markdown]
# #Setting datapath

# %%
import json
from pathlib import Path

from google.colab import drive
drive.mount('/drive', force_remount=True)
# Out:
# Mounted at /drive

# %%
hamamatsu_xr ='Hamamatsu XR'
hamamatsu_s360='Hamamatsu S360'
aperio_cs2='Aperio ScanScope CS2'

train_dataset_folder =  aperio_cs2+'/'
test_dataset_folder  =   hamamatsu_xr+'/'

df_train = pd.read_pickle('/drive/MyDrive/CSE499 Project/Patch Datasets/'+train_dataset_folder+'DataFrame.pkl')
df_test  = pd.read_pickle('/drive/MyDrive/CSE499 Project/Patch Datasets/'+test_dataset_folder+'DataFrame.pkl')

# %% [markdown]
# #Train and Test Class

# %%
class MitosisImagesDatasetTrain(torch.utils.data.Dataset):
  def __init__(self, files_dir, width, height,transforms=None):
    self.transforms = transforms
    self.files_dir  = files_dir
    self.height     = height
    self.width      = width

    self.imgs = [image for image in sorted(os.listdir(files_dir)) if image[-5:]=='.tiff']
    
    self.classes = [_, 'mitotic figure']

  def __getitem__(self, idx):
    img_name   = self.imgs[idx]
    image_path = os.path.join(self.files_dir, img_name)

    img     = cv2.imread(image_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
    img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)

    img_res /= 255.0
    
    dataframe = df_train[df_train['file_name']==img_name].copy()
    
    boxes = []
    labels = []

    wt = img.shape[1]
    ht = img.shape[0]
    
    for index in dataframe.index:
      labels.append(1)
      
      List = dataframe['box'][index]
      
      scale_x = float(481)/float(self.width)
      scale_y = float(451)/float(self.height)

      xmin = List[0]#/float(scale_x)
      xmax = List[2]#/float(scale_x)
      ymin = List[1]#/float(scale_y)
      ymax = List[3]#/float(scale_y)
      
      # print(xmin,xmax,ymin,ymax)
      # sys.exit()

      xmin_corr = (xmin)
      xmax_corr = (xmax)
      ymin_corr = (ymin)
      ymax_corr = (ymax)
          
      boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])
    


    boxes = torch.as_tensor(boxes, dtype=torch.float32)
    labels = torch.as_tensor(labels, dtype=torch.int64)
    area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
    #area = torch.as_tensor(area, dtype=torch.float32)
    iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)
    
    target = {}
    target["boxes"] = boxes
    target["labels"] = labels
    target["image_id"] = torch.tensor([idx])
    target["area"] = area
    target["iscrowd"] = iscrowd
    
    if self.transforms:
      sample = self.transforms(image = img_res,
                                bboxes = target['boxes'],
                                labels = labels)
      img_res = sample['image']
      target['boxes'] = torch.Tensor(sample['bboxes'])

    return img_res, target
    
  def __len__(self):
    return len(self.imgs)

class MitosisImagesDatasetTest(torch.utils.data.Dataset):
  def __init__(self, files_dir, width, height,transforms=None):
    self.transforms = transforms
    self.files_dir  = files_dir
    self.height     = height
    self.width      = width

    self.imgs = [image for image in sorted(os.listdir(files_dir)) if image[-5:]=='.tiff']
    
    self.classes = [_, 'mitotic figure']

  def __getitem__(self, idx):
    img_name   = self.imgs[idx]
    image_path = os.path.join(self.files_dir, img_name)

    img     = cv2.imread(image_path)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB).astype(np.float32)
    img_res = cv2.resize(img_rgb, (self.width, self.height), cv2.INTER_AREA)

    img_res /= 255.0
    
    dataframe = df_test[df_test['file_name']==img_name].copy()
    
    boxes = []
    labels = []

    wt = img.shape[1]
    ht = img.shape[0]
    
    for index in dataframe.index:
      labels.append(1)
      
      List = dataframe['box'][index]
      
      scale_x = float(481)/float(self.width)
      scale_y = float(451)/float(self.height)

      xmin = List[0]#/float(scale_x)
      xmax = List[2]#/float(scale_x)
      ymin = List[1]#/float(scale_y)
      ymax = List[3]#/float(scale_y)

      

      xmin_corr = (xmin)
      xmax_corr = (xmax)
      ymin_corr = (ymin)
      ymax_corr = (ymax)
          
      boxes.append([xmin_corr, ymin_corr, xmax_corr, ymax_corr])
    


    boxes = torch.as_tensor(boxes, dtype=torch.float32)
    labels = torch.as_tensor(labels, dtype=torch.int64)
    area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
    #area = torch.as_tensor(area, dtype=torch.float32)
    iscrowd = torch.zeros((boxes.shape[0],), dtype=torch.int64)
    
    target = {}
    target["boxes"] = boxes
    target["labels"] = labels
    target["image_id"] = torch.tensor([idx])
    target["area"] = area
    target["iscrowd"] = iscrowd
    
    if self.transforms:
      sample = self.transforms(image = img_res,
                                bboxes = target['boxes'],
                                labels = labels)
      img_res = sample['image']
      target['boxes'] = torch.Tensor(sample['bboxes'])

    return img_res, target
    
  def __len__(self):
    return len(self.imgs)

# %% [markdown]
# #Plotting and setting training data

# %%
# Function to visualize bounding boxes in the image
def plot_img_bbox(img, target):
  # plot the image and bboxes
  # Bounding boxes are defined as follows: x-min y-min width height
  fig, a = plt.subplots(1,1)
  fig.set_size_inches(5,5)
  a.imshow(img)
  for box in (target['boxes']):
    x, y, width, height  = box[0], box[1], box[2]-box[0], box[3]-box[1]
    rect = patches.Rectangle(
      (x, y),
      width, height,
      linewidth = 2,
      edgecolor = 'r',
      facecolor = 'none'
    )
    # Draw the bounding box on top of the image
    a.add_patch(rect)
  plt.show()

  # Send train=True for training transforms and False for val/test transforms
def get_transform(train):
  if train:
    return A.Compose(
      [
        A.HorizontalFlip(0.5),
        # ToTensorV2 converts image to pytorch tensor without div by 255
        ToTensorV2(p=1.0) 
      ],
      bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']}
    )
  else:
    return A.Compose(
      [ToTensorV2(p=1.0)],
      bbox_params={'format': 'pascal_voc', 'label_fields': ['labels']}
    )

# %%
train_dir = '/drive/MyDrive/CSE499 Project/Patch Datasets/'+train_dataset_folder
test_dir = '/drive/MyDrive/CSE499 Project/Patch Datasets/'+test_dataset_folder

print(train_dir)
print(test_dir)

dataset =      MitosisImagesDatasetTrain(train_dir, 481, 451)
dataset_test = MitosisImagesDatasetTest(test_dir, 481,451)

# plotting the image with bboxes. Feel free to change the index
img, target = dataset[100]
print(img.shape)
plot_img_bbox(img, target)
# Out:
# /drive/MyDrive/CSE499 Project/Patch Datasets/Aperio ScanScope CS2/
# /drive/MyDrive/CSE499 Project/Patch Datasets/Hamamatsu XR/
# (451, 481, 3)

# %%
train_dataset =      MitosisImagesDatasetTrain(train_dir, 481, 451,transforms=get_transform(train=True))

def collate_fn(batch):
    return tuple(zip(*batch))

train_data_loader  = DataLoader(train_dataset,batch_size=10,shuffle=True,num_workers=4,collate_fn=utils.collate_fn)

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print(device)
# Out:
# cuda

# %% [markdown]
# #Training part

# %%
# !git clone https://github.com/Ixiondbz/Global-Second-order-Pooling-Convolutional-Networks.git gsop
# %cd Global-Second-order-Pooling-Convolutional-Networks/
from gsop.torchvision.models import resnet50 as _resnet50
# Out:
# fatal: destination path 'gsop' already exists and is not an empty directory.

# %%
resnet50_GSOP = _resnet50(pretrained=False)

# num_classes=2
# backbone = _resnet_fpn_extractor(resnet50_SE,trainable_layers=3)
# model = FasterRCNN(backbone,num_classes=num_classes)
# in_features = model.roi_heads.box_predictor.cls_score.in_features
# model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

# model = model.to(device)

# params = [p for p in model.parameters() if p.requires_grad]
# optimizer = torch.optim.SGD(params, lr=0.005, momentum=0.9, weight_decay=0.0005)
# lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)
# num_epochs = 50
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-03bfc7611d7a> in <module>()
# ----> 1 resnet50_GSOP = _resnet50(pretrained=False)
#       2
#       3 # num_classes=2
#       4 # backbone = _resnet_fpn_extractor(resnet50_SE,trainable_layers=3)
#       5 # model = FasterRCNN(backbone,num_classes=num_classes)
#
# /content/gsop/torchvision/models/resnet.py in resnet50(pretrained, att_position, att_dim, **kwargs)
#     333         pretrained (bool): If True, returns a model pre-trained on ImageNet
#     334     """
# --> 335     model = ResNet(Bottleneck, [3, 4, 6, 3], att_position, att_dim,1, **kwargs)
#     336     if pretrained:
#     337         model.load_state_dict(model_zoo.load_url(model_urls['resnet50']))
#
# /content/gsop/torchvision/models/resnet.py in __init__(self, block, layers, att_position, att_dim, GSoP_mode, num_classes)
#     259         self.relu = nn.ReLU(inplace=True)
#     260         self.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
# --> 261         self.layer1 = self._make_layer(block, 64, layers[0], att_position=att_position[0], att_dim=att_dim)
#     262         self.layer2 = self._make_layer(block, 128, layers[1], stride=2, att_position=att_position[1], att_dim=att_dim)
#     263         self.layer3 = self._make_layer(block, 256, layers[2], stride=2, att_position=att_position[2], att_dim=att_dim)
#
# /content/gsop/torchvision/models/resnet.py in _make_layer(self, block, planes, blocks, stride, att_position, att_dim)
#     293
#     294         layers = []
# --> 295         layers.append(block(self.inplanes, planes, stride, downsample, att_position[0], att_dim=att_dim))
#     296         self.inplanes = planes * block.expansion
#     297         for i in range(1, blocks):
#
# IndexError: list index out of range

# %%
modelOG=torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=False)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]

# %%
modelOG
# Out:
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64, eps=1e-05)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128, eps=1e-05)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256, eps=1e-05)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048, eps=1e-05)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512, eps=1e-05)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048, eps=1e-05)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (3): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=91, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=364, bias=True)
#     )
#   )
# )

# %%
model
# Out:
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): SEBottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=256, out_features=16, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=16, out_features=256, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): SEBottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=256, out_features=16, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=16, out_features=256, bias=False)
#               (3): Sigmoid()
#             )
#           )
#         )
#         (2): SEBottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=256, out_features=16, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=16, out_features=256, bias=False)
#               (3): Sigmoid()
#             )
#           )
#         )
#       )
#       (layer2): Sequential(
#         (0): SEBottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=512, out_features=32, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=32, out_features=512, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): SEBottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=512, out_features=32, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=32, out_features=512, bias=False)
#               (3): Sigmoid()
#             )
#           )
#         )
#         (2): SEBottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=512, out_features=32, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=32, out_features=512, bias=False)
#               (3): Sigmoid()
#             )
#           )
#         )
#         (3): SEBottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=512, out_features=32, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=32, out_features=512, bias=False)
#               (3): Sigmoid()
#             )
#           )
#         )
#       )
#       (layer3): Sequential(
#         (0): SEBottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=1024, out_features=64, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=64, out_features=1024, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): SEBottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=1024, out_features=64, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=64, out_features=1024, bias=False)
#               (3): Sigmoid()
#             )
#           )
#         )
#         (2): SEBottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=1024, out_features=64, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=64, out_features=1024, bias=False)
#               (3): Sigmoid()
#             )
#           )
#         )
#         (3): SEBottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=1024, out_features=64, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=64, out_features=1024, bias=False)
#               (3): Sigmoid()
#             )
#           )
#         )
#         (4): SEBottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=1024, out_features=64, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=64, out_features=1024, bias=False)
#               (3): Sigmoid()
#             )
#           )
#         )
#         (5): SEBottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=1024, out_features=64, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=64, out_features=1024, bias=False)
#               (3): Sigmoid()
#             )
#           )
#         )
#       )
#       (layer4): Sequential(
#         (0): SEBottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=2048, out_features=128, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=128, out_features=2048, bias=False)
#               (3): Sigmoid()
#             )
#           )
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#         )
#         (1): SEBottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=2048, out_features=128, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=128, out_features=2048, bias=False)
#               (3): Sigmoid()
#             )
#           )
#         )
#         (2): SEBottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu): ReLU(inplace=True)
#           (se): SELayer(
#             (avg_pool): AdaptiveAvgPool2d(output_size=1)
#             (fc): Sequential(
#               (0): Linear(in_features=2048, out_features=128, bias=False)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=128, out_features=2048, bias=False)
#               (3): Sigmoid()
#             )
#           )
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (3): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign(featmap_names=['0', '1', '2', '3'], output_size=(7, 7), sampling_ratio=2)
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=2, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=8, bias=True)
#     )
#   )
# )

# %%
print(train_dir)
print(test_dir)
# Out:
# /drive/MyDrive/CSE499 Project/Patch Datasets/Aperio ScanScope CS2/
# /drive/MyDrive/CSE499 Project/Patch Datasets/Hamamatsu XR/

# %%
# %cd '/drive/MyDrive/CSE499 Project/modelSaves/Attention Mechanism/SENet/model3'

for epoch in range(num_epochs):
    # training for one epoch
    train_one_epoch(model, optimizer, train_data_loader, device, epoch, print_freq=10)
    #save the model
    torch.save(model.state_dict(), 'model.pth')
    torch.save({
    'epoch':epoch+1,
    'model_state_dict':model.state_dict(),
    'optimizer_state_dict':optimizer.state_dict(),
    },'ckpt.pth')
    # update the learning rate
    lr_scheduler.step()
# Out:
# /drive/.shortcut-targets-by-id/1M-kTVs7g43FucvCjcPvKwiR8r1e1qtHe/CSE499_Project/modelSaves/Attention Mechanism/model3
# Epoch: [0]  [  0/224]  eta: 0:46:42  lr: 0.000027  loss: 1.3557 (1.3557)  loss_classifier: 0.6027 (0.6027)  loss_box_reg: 0.0138 (0.0138)  loss_objectness: 0.7095 (0.7095)  loss_rpn_box_reg: 0.0297 (0.0297)  time: 12.5104  data: 10.8016  max mem: 12822
# Epoch: [0]  [ 10/224]  eta: 0:23:15  lr: 0.000251  loss: 1.2222 (1.1714)  loss_classifier: 0.4644 (0.4223)  loss_box_reg: 0.0151 (0.0156)  loss_objectness: 0.7043 (0.7012)  loss_rpn_box_reg: 0.0316 (0.0323)  time: 6.5231  data: 5.2909  max mem: 12822
# Epoch: [0]  [ 20/224]  eta: 0:13:34  lr: 0.000475  loss: 0.8251 (0.9865)  loss_classifier: 0.1630 (0.2811)  loss_box_reg: 0.0179 (0.0177)  loss_objectness: 0.6741 (0.6622)  loss_rpn_box_reg: 0.0270 (0.0255)  time: 3.5677  data: 2.3808  max mem: 12822
# Epoch: [0]  [ 30/224]  eta: 0:10:01  lr: 0.000699  loss: 0.7405 (0.8631)  loss_classifier: 0.1290 (0.2342)  loss_box_reg: 0.0181 (0.0179)  loss_objectness: 0.5356 (0.5889)  loss_rpn_box_reg: 0.0147 (0.0222)  time: 1.2158  data: 0.0219  max mem: 12822
# Epoch: [0]  [ 40/224]  eta: 0:08:05  lr: 0.000923  loss: 0.4294 (0.7309)  loss_classifier: 0.0970 (0.1961)  loss_box_reg: 0.0141 (0.0158)  loss_objectness: 0.3056 (0.4996)  loss_rpn_box_reg: 0.0120 (0.0195)  time: 1.2208  data: 0.0215  max mem: 12822
# Epoch: [0]  [ 50/224]  eta: 0:06:51  lr: 0.001147  loss: 0.2513 (0.6349)  loss_classifier: 0.0780 (0.1751)  loss_box_reg: 0.0096 (0.0152)  loss_objectness: 0.1513 (0.4268)  loss_rpn_box_reg: 0.0105 (0.0178)  time: 1.2208  data: 0.0219  max mem: 12822
# Epoch: [0]  [ 60/224]  eta: 0:05:56  lr: 0.001371  loss: 0.2489 (0.5755)  loss_classifier: 0.1129 (0.1688)  loss_box_reg: 0.0203 (0.0182)  loss_objectness: 0.1063 (0.3722)  loss_rpn_box_reg: 0.0101 (0.0164)  time: 1.2196  data: 0.0213  max mem: 12822
# Epoch: [0]  [ 70/224]  eta: 0:05:14  lr: 0.001595  loss: 0.2428 (0.5255)  loss_classifier: 0.1129 (0.1583)  loss_box_reg: 0.0379 (0.0219)  loss_objectness: 0.0812 (0.3300)  loss_rpn_box_reg: 0.0086 (0.0153)  time: 1.2198  data: 0.0210  max mem: 12822
# Epoch: [0]  [ 80/224]  eta: 0:04:39  lr: 0.001819  loss: 0.2040 (0.4843)  loss_classifier: 0.0869 (0.1487)  loss_box_reg: 0.0404 (0.0242)  loss_objectness: 0.0684 (0.2971)  loss_rpn_box_reg: 0.0080 (0.0144)  time: 1.2216  data: 0.0227  max mem: 12822
# Epoch: [0]  [ 90/224]  eta: 0:04:09  lr: 0.002043  loss: 0.1810 (0.4507)  loss_classifier: 0.0784 (0.1406)  loss_box_reg: 0.0410 (0.0260)  loss_objectness: 0.0568 (0.2704)  loss_rpn_box_reg: 0.0078 (0.0137)  time: 1.2218  data: 0.0221  max mem: 12822
# Epoch: [0]  [100/224]  eta: 0:03:42  lr: 0.002267  loss: 0.1723 (0.4227)  loss_classifier: 0.0711 (0.1335)  loss_box_reg: 0.0428 (0.0279)  loss_objectness: 0.0481 (0.2482)  loss_rpn_box_reg: 0.0079 (0.0131)  time: 1.2207  data: 0.0214  max mem: 12822
# Epoch: [0]  [110/224]  eta: 0:03:18  lr: 0.002491  loss: 0.1525 (0.3978)  loss_classifier: 0.0618 (0.1266)  loss_box_reg: 0.0422 (0.0291)  loss_objectness: 0.0431 (0.2295)  loss_rpn_box_reg: 0.0078 (0.0126)  time: 1.2207  data: 0.0210  max mem: 12822
# Epoch: [0]  [120/224]  eta: 0:02:57  lr: 0.002715  loss: 0.1384 (0.3757)  loss_classifier: 0.0512 (0.1202)  loss_box_reg: 0.0402 (0.0297)  loss_objectness: 0.0372 (0.2137)  loss_rpn_box_reg: 0.0069 (0.0121)  time: 1.2219  data: 0.0211  max mem: 12822
# Epoch: [0]  [130/224]  eta: 0:02:36  lr: 0.002939  loss: 0.1233 (0.3561)  loss_classifier: 0.0473 (0.1144)  loss_box_reg: 0.0374 (0.0302)  loss_objectness: 0.0329 (0.1998)  loss_rpn_box_reg: 0.0067 (0.0117)  time: 1.2212  data: 0.0216  max mem: 12822
# Epoch: [0]  [140/224]  eta: 0:02:17  lr: 0.003163  loss: 0.1170 (0.3390)  loss_classifier: 0.0447 (0.1094)  loss_box_reg: 0.0321 (0.0303)  loss_objectness: 0.0303 (0.1881)  loss_rpn_box_reg: 0.0063 (0.0113)  time: 1.2229  data: 0.0227  max mem: 12822
# Epoch: [0]  [150/224]  eta: 0:01:58  lr: 0.003387  loss: 0.1095 (0.3240)  loss_classifier: 0.0402 (0.1047)  loss_box_reg: 0.0314 (0.0302)  loss_objectness: 0.0303 (0.1779)  loss_rpn_box_reg: 0.0070 (0.0111)  time: 1.2272  data: 0.0251  max mem: 12822
# Epoch: [0]  [160/224]  eta: 0:01:41  lr: 0.003611  loss: 0.1082 (0.3107)  loss_classifier: 0.0388 (0.1008)  loss_box_reg: 0.0313 (0.0303)  loss_objectness: 0.0291 (0.1687)  loss_rpn_box_reg: 0.0075 (0.0109)  time: 1.2265  data: 0.0248  max mem: 12822
# Epoch: [0]  [170/224]  eta: 0:01:24  lr: 0.003835  loss: 0.1020 (0.2985)  loss_classifier: 0.0388 (0.0970)  loss_box_reg: 0.0275 (0.0301)  loss_objectness: 0.0312 (0.1608)  loss_rpn_box_reg: 0.0066 (0.0106)  time: 1.2256  data: 0.0238  max mem: 12822
# Epoch: [0]  [180/224]  eta: 0:01:07  lr: 0.004059  loss: 0.1020 (0.2877)  loss_classifier: 0.0357 (0.0937)  loss_box_reg: 0.0249 (0.0300)  loss_objectness: 0.0337 (0.1536)  loss_rpn_box_reg: 0.0058 (0.0104)  time: 1.2275  data: 0.0238  max mem: 12822
# Epoch: [0]  [190/224]  eta: 0:00:51  lr: 0.004283  loss: 0.1046 (0.2785)  loss_classifier: 0.0358 (0.0909)  loss_box_reg: 0.0267 (0.0301)  loss_objectness: 0.0334 (0.1474)  loss_rpn_box_reg: 0.0057 (0.0102)  time: 1.2278  data: 0.0240  max mem: 12822
# Epoch: [0]  [200/224]  eta: 0:00:36  lr: 0.004507  loss: 0.1022 (0.2695)  loss_classifier: 0.0376 (0.0881)  loss_box_reg: 0.0277 (0.0299)  loss_objectness: 0.0331 (0.1416)  loss_rpn_box_reg: 0.0067 (0.0100)  time: 1.2253  data: 0.0234  max mem: 12822
# Epoch: [0]  [210/224]  eta: 0:00:20  lr: 0.004731  loss: 0.0930 (0.2610)  loss_classifier: 0.0348 (0.0855)  loss_box_reg: 0.0255 (0.0296)  loss_objectness: 0.0281 (0.1361)  loss_rpn_box_reg: 0.0050 (0.0098)  time: 1.2226  data: 0.0220  max mem: 12822
# Epoch: [0]  [220/224]  eta: 0:00:05  lr: 0.004955  loss: 0.0930 (0.2539)  loss_classifier: 0.0343 (0.0834)  loss_box_reg: 0.0267 (0.0296)  loss_objectness: 0.0275 (0.1314)  loss_rpn_box_reg: 0.0045 (0.0095)  time: 1.2226  data: 0.0212  max mem: 12822
# Epoch: [0]  [223/224]  eta: 0:00:01  lr: 0.005000  loss: 0.0930 (0.2516)  loss_classifier: 0.0334 (0.0826)  loss_box_reg: 0.0267 (0.0295)  loss_objectness: 0.0248 (0.1300)  loss_rpn_box_reg: 0.0045 (0.0095)  time: 1.1756  data: 0.0206  max mem: 12822
# Epoch: [0] Total time: 0:05:31 (1.4788 s / it)
# Epoch: [1]  [  0/224]  eta: 0:06:55  lr: 0.005000  loss: 0.0942 (0.0942)  loss_classifier: 0.0337 (0.0337)  loss_box_reg: 0.0267 (0.0267)  loss_objectness: 0.0282 (0.0282)  loss_rpn_box_reg: 0.0057 (0.0057)  time: 1.8537  data: 0.6149  max mem: 12822
# Epoch: [1]  [ 10/224]  eta: 0:04:34  lr: 0.005000  loss: 0.0895 (0.0922)  loss_classifier: 0.0337 (0.0323)  loss_box_reg: 0.0251 (0.0265)  loss_objectness: 0.0260 (0.0266)  loss_rpn_box_reg: 0.0064 (0.0068)  time: 1.2836  data: 0.0764  max mem: 12822
# Epoch: [1]  [ 20/224]  eta: 0:04:16  lr: 0.005000  loss: 0.0858 (0.0896)  loss_classifier: 0.0304 (0.0318)  loss_box_reg: 0.0247 (0.0262)  loss_objectness: 0.0212 (0.0251)  loss_rpn_box_reg: 0.0064 (0.0065)  time: 1.2273  data: 0.0231  max mem: 12822
# Epoch: [1]  [ 30/224]  eta: 0:04:01  lr: 0.005000  loss: 0.0877 (0.0916)  loss_classifier: 0.0338 (0.0334)  loss_box_reg: 0.0246 (0.0261)  loss_objectness: 0.0201 (0.0261)  loss_rpn_box_reg: 0.0052 (0.0060)  time: 1.2263  data: 0.0236  max mem: 12822
# Epoch: [1]  [ 40/224]  eta: 0:03:48  lr: 0.005000  loss: 0.0879 (0.0896)  loss_classifier: 0.0348 (0.0331)  loss_box_reg: 0.0231 (0.0249)  loss_objectness: 0.0189 (0.0260)  loss_rpn_box_reg: 0.0041 (0.0055)  time: 1.2253  data: 0.0230  max mem: 12822
# Epoch: [1]  [ 50/224]  eta: 0:03:35  lr: 0.005000  loss: 0.0896 (0.0916)  loss_classifier: 0.0331 (0.0338)  loss_box_reg: 0.0225 (0.0251)  loss_objectness: 0.0295 (0.0273)  loss_rpn_box_reg: 0.0042 (0.0054)  time: 1.2257  data: 0.0246  max mem: 12822
# Epoch: [1]  [ 60/224]  eta: 0:03:22  lr: 0.005000  loss: 0.0941 (0.0923)  loss_classifier: 0.0351 (0.0338)  loss_box_reg: 0.0265 (0.0257)  loss_objectness: 0.0299 (0.0273)  loss_rpn_box_reg: 0.0055 (0.0055)  time: 1.2231  data: 0.0243  max mem: 12822
# Epoch: [1]  [ 70/224]  eta: 0:03:10  lr: 0.005000  loss: 0.0944 (0.0927)  loss_classifier: 0.0352 (0.0342)  loss_box_reg: 0.0273 (0.0260)  loss_objectness: 0.0244 (0.0271)  loss_rpn_box_reg: 0.0055 (0.0054)  time: 1.2220  data: 0.0228  max mem: 12822
# Epoch: [1]  [ 80/224]  eta: 0:02:57  lr: 0.005000  loss: 0.0841 (0.0912)  loss_classifier: 0.0333 (0.0340)  loss_box_reg: 0.0258 (0.0259)  loss_objectness: 0.0207 (0.0262)  loss_rpn_box_reg: 0.0037 (0.0051)  time: 1.2234  data: 0.0223  max mem: 12822
# Epoch: [1]  [ 90/224]  eta: 0:02:44  lr: 0.005000  loss: 0.0815 (0.0911)  loss_classifier: 0.0333 (0.0342)  loss_box_reg: 0.0235 (0.0256)  loss_objectness: 0.0210 (0.0262)  loss_rpn_box_reg: 0.0036 (0.0050)  time: 1.2219  data: 0.0206  max mem: 12822
# Epoch: [1]  [100/224]  eta: 0:02:32  lr: 0.005000  loss: 0.0866 (0.0908)  loss_classifier: 0.0344 (0.0341)  loss_box_reg: 0.0235 (0.0254)  loss_objectness: 0.0250 (0.0264)  loss_rpn_box_reg: 0.0040 (0.0049)  time: 1.2204  data: 0.0208  max mem: 12822
# Epoch: [1]  [110/224]  eta: 0:02:20  lr: 0.005000  loss: 0.0862 (0.0899)  loss_classifier: 0.0327 (0.0338)  loss_box_reg: 0.0236 (0.0252)  loss_objectness: 0.0250 (0.0261)  loss_rpn_box_reg: 0.0038 (0.0048)  time: 1.2212  data: 0.0211  max mem: 12822
# Epoch: [1]  [120/224]  eta: 0:02:07  lr: 0.005000  loss: 0.0791 (0.0891)  loss_classifier: 0.0311 (0.0336)  loss_box_reg: 0.0234 (0.0252)  loss_objectness: 0.0181 (0.0256)  loss_rpn_box_reg: 0.0035 (0.0047)  time: 1.2230  data: 0.0217  max mem: 12822
# Epoch: [1]  [130/224]  eta: 0:01:55  lr: 0.005000  loss: 0.0760 (0.0880)  loss_classifier: 0.0279 (0.0331)  loss_box_reg: 0.0229 (0.0249)  loss_objectness: 0.0171 (0.0253)  loss_rpn_box_reg: 0.0035 (0.0046)  time: 1.2240  data: 0.0232  max mem: 12822
# Epoch: [1]  [140/224]  eta: 0:01:43  lr: 0.005000  loss: 0.0726 (0.0871)  loss_classifier: 0.0258 (0.0328)  loss_box_reg: 0.0211 (0.0246)  loss_objectness: 0.0204 (0.0252)  loss_rpn_box_reg: 0.0035 (0.0045)  time: 1.2247  data: 0.0242  max mem: 12822
# Epoch: [1]  [150/224]  eta: 0:01:30  lr: 0.005000  loss: 0.0715 (0.0865)  loss_classifier: 0.0266 (0.0324)  loss_box_reg: 0.0211 (0.0244)  loss_objectness: 0.0204 (0.0251)  loss_rpn_box_reg: 0.0037 (0.0045)  time: 1.2247  data: 0.0233  max mem: 12822
# Epoch: [1]  [160/224]  eta: 0:01:18  lr: 0.005000  loss: 0.0724 (0.0859)  loss_classifier: 0.0281 (0.0323)  loss_box_reg: 0.0219 (0.0243)  loss_objectness: 0.0185 (0.0249)  loss_rpn_box_reg: 0.0035 (0.0044)  time: 1.2232  data: 0.0223  max mem: 12822
# Epoch: [1]  [170/224]  eta: 0:01:06  lr: 0.005000  loss: 0.0792 (0.0855)  loss_classifier: 0.0282 (0.0321)  loss_box_reg: 0.0234 (0.0243)  loss_objectness: 0.0192 (0.0246)  loss_rpn_box_reg: 0.0037 (0.0044)  time: 1.2235  data: 0.0232  max mem: 12822
# Epoch: [1]  [180/224]  eta: 0:00:54  lr: 0.005000  loss: 0.0804 (0.0855)  loss_classifier: 0.0303 (0.0321)  loss_box_reg: 0.0232 (0.0243)  loss_objectness: 0.0202 (0.0247)  loss_rpn_box_reg: 0.0038 (0.0044)  time: 1.2239  data: 0.0223  max mem: 12822
# Epoch: [1]  [190/224]  eta: 0:00:41  lr: 0.005000  loss: 0.0767 (0.0853)  loss_classifier: 0.0303 (0.0321)  loss_box_reg: 0.0231 (0.0243)  loss_objectness: 0.0188 (0.0246)  loss_rpn_box_reg: 0.0036 (0.0043)  time: 1.2239  data: 0.0225  max mem: 12822
# Epoch: [1]  [200/224]  eta: 0:00:29  lr: 0.005000  loss: 0.0768 (0.0852)  loss_classifier: 0.0298 (0.0321)  loss_box_reg: 0.0240 (0.0244)  loss_objectness: 0.0186 (0.0245)  loss_rpn_box_reg: 0.0032 (0.0043)  time: 1.2227  data: 0.0231  max mem: 12822
# Epoch: [1]  [210/224]  eta: 0:00:17  lr: 0.005000  loss: 0.0788 (0.0851)  loss_classifier: 0.0303 (0.0320)  loss_box_reg: 0.0242 (0.0243)  loss_objectness: 0.0194 (0.0245)  loss_rpn_box_reg: 0.0035 (0.0043)  time: 1.2207  data: 0.0218  max mem: 12822
# Epoch: [1]  [220/224]  eta: 0:00:04  lr: 0.005000  loss: 0.0776 (0.0846)  loss_classifier: 0.0303 (0.0319)  loss_box_reg: 0.0216 (0.0242)  loss_objectness: 0.0166 (0.0242)  loss_rpn_box_reg: 0.0033 (0.0042)  time: 1.2197  data: 0.0218  max mem: 12822
# Epoch: [1]  [223/224]  eta: 0:00:01  lr: 0.005000  loss: 0.0776 (0.0846)  loss_classifier: 0.0291 (0.0319)  loss_box_reg: 0.0216 (0.0243)  loss_objectness: 0.0184 (0.0242)  loss_rpn_box_reg: 0.0035 (0.0042)  time: 1.1724  data: 0.0214  max mem: 12822
# Epoch: [1] Total time: 0:04:33 (1.2222 s / it)
# Epoch: [2]  [  0/224]  eta: 0:06:59  lr: 0.005000  loss: 0.0852 (0.0852)  loss_classifier: 0.0291 (0.0291)  loss_box_reg: 0.0203 (0.0203)  loss_objectness: 0.0314 (0.0314)  loss_rpn_box_reg: 0.0044 (0.0044)  time: 1.8738  data: 0.6268  max mem: 12822
# Epoch: [2]  [ 10/224]  eta: 0:04:33  lr: 0.005000  loss: 0.0693 (0.0746)  loss_classifier: 0.0291 (0.0296)  loss_box_reg: 0.0207 (0.0225)  loss_objectness: 0.0161 (0.0180)  loss_rpn_box_reg: 0.0043 (0.0046)  time: 1.2801  data: 0.0762  max mem: 12822
# Epoch: [2]  [ 20/224]  eta: 0:04:16  lr: 0.005000  loss: 0.0712 (0.0740)  loss_classifier: 0.0299 (0.0301)  loss_box_reg: 0.0222 (0.0228)  loss_objectness: 0.0144 (0.0168)  loss_rpn_box_reg: 0.0039 (0.0043)  time: 1.2250  data: 0.0228  max mem: 12822
# Epoch: [2]  [ 30/224]  eta: 0:04:01  lr: 0.005000  loss: 0.0808 (0.0771)  loss_classifier: 0.0333 (0.0314)  loss_box_reg: 0.0241 (0.0234)  loss_objectness: 0.0179 (0.0183)  loss_rpn_box_reg: 0.0037 (0.0040)  time: 1.2262  data: 0.0243  max mem: 12822
# Epoch: [2]  [ 40/224]  eta: 0:03:48  lr: 0.005000  loss: 0.0817 (0.0774)  loss_classifier: 0.0328 (0.0312)  loss_box_reg: 0.0224 (0.0231)  loss_objectness: 0.0202 (0.0194)  loss_rpn_box_reg: 0.0032 (0.0038)  time: 1.2220  data: 0.0234  max mem: 12822
# Epoch: [2]  [ 50/224]  eta: 0:03:35  lr: 0.005000  loss: 0.0688 (0.0752)  loss_classifier: 0.0259 (0.0304)  loss_box_reg: 0.0194 (0.0224)  loss_objectness: 0.0174 (0.0188)  loss_rpn_box_reg: 0.0030 (0.0036)  time: 1.2218  data: 0.0223  max mem: 12822
# Epoch: [2]  [ 60/224]  eta: 0:03:22  lr: 0.005000  loss: 0.0643 (0.0745)  loss_classifier: 0.0231 (0.0299)  loss_box_reg: 0.0194 (0.0224)  loss_objectness: 0.0168 (0.0188)  loss_rpn_box_reg: 0.0029 (0.0035)  time: 1.2212  data: 0.0217  max mem: 12822
# Epoch: [2]  [ 70/224]  eta: 0:03:09  lr: 0.005000  loss: 0.0717 (0.0745)  loss_classifier: 0.0271 (0.0298)  loss_box_reg: 0.0213 (0.0225)  loss_objectness: 0.0170 (0.0188)  loss_rpn_box_reg: 0.0029 (0.0035)  time: 1.2213  data: 0.0219  max mem: 12822
# Epoch: [2]  [ 80/224]  eta: 0:02:57  lr: 0.005000  loss: 0.0751 (0.0748)  loss_classifier: 0.0317 (0.0300)  loss_box_reg: 0.0218 (0.0225)  loss_objectness: 0.0180 (0.0189)  loss_rpn_box_reg: 0.0031 (0.0034)  time: 1.2225  data: 0.0223  max mem: 12822
# Epoch: [2]  [ 90/224]  eta: 0:02:44  lr: 0.005000  loss: 0.0752 (0.0747)  loss_classifier: 0.0297 (0.0298)  loss_box_reg: 0.0212 (0.0225)  loss_objectness: 0.0187 (0.0190)  loss_rpn_box_reg: 0.0029 (0.0034)  time: 1.2216  data: 0.0227  max mem: 12822
# Epoch: [2]  [100/224]  eta: 0:02:32  lr: 0.005000  loss: 0.0693 (0.0748)  loss_classifier: 0.0280 (0.0296)  loss_box_reg: 0.0203 (0.0223)  loss_objectness: 0.0184 (0.0195)  loss_rpn_box_reg: 0.0032 (0.0034)  time: 1.2209  data: 0.0235  max mem: 12822
# Epoch: [2]  [110/224]  eta: 0:02:19  lr: 0.005000  loss: 0.0722 (0.0746)  loss_classifier: 0.0283 (0.0297)  loss_box_reg: 0.0203 (0.0222)  loss_objectness: 0.0178 (0.0194)  loss_rpn_box_reg: 0.0032 (0.0034)  time: 1.2202  data: 0.0221  max mem: 12822
# Epoch: [2]  [120/224]  eta: 0:02:07  lr: 0.005000  loss: 0.0721 (0.0746)  loss_classifier: 0.0287 (0.0297)  loss_box_reg: 0.0216 (0.0221)  loss_objectness: 0.0163 (0.0194)  loss_rpn_box_reg: 0.0032 (0.0034)  time: 1.2202  data: 0.0210  max mem: 12822
# Epoch: [2]  [130/224]  eta: 0:01:55  lr: 0.005000  loss: 0.0656 (0.0742)  loss_classifier: 0.0252 (0.0294)  loss_box_reg: 0.0212 (0.0222)  loss_objectness: 0.0137 (0.0193)  loss_rpn_box_reg: 0.0030 (0.0034)  time: 1.2214  data: 0.0224  max mem: 12822
# Epoch: [2]  [140/224]  eta: 0:01:43  lr: 0.005000  loss: 0.0631 (0.0735)  loss_classifier: 0.0254 (0.0292)  loss_box_reg: 0.0209 (0.0221)  loss_objectness: 0.0122 (0.0189)  loss_rpn_box_reg: 0.0028 (0.0033)  time: 1.2221  data: 0.0233  max mem: 12822
# Epoch: [2]  [150/224]  eta: 0:01:30  lr: 0.005000  loss: 0.0590 (0.0729)  loss_classifier: 0.0253 (0.0290)  loss_box_reg: 0.0207 (0.0220)  loss_objectness: 0.0122 (0.0186)  loss_rpn_box_reg: 0.0025 (0.0033)  time: 1.2223  data: 0.0226  max mem: 12822
# Epoch: [2]  [160/224]  eta: 0:01:18  lr: 0.005000  loss: 0.0638 (0.0727)  loss_classifier: 0.0249 (0.0288)  loss_box_reg: 0.0213 (0.0220)  loss_objectness: 0.0184 (0.0187)  loss_rpn_box_reg: 0.0026 (0.0032)  time: 1.2230  data: 0.0230  max mem: 12822
# Epoch: [2]  [170/224]  eta: 0:01:06  lr: 0.005000  loss: 0.0702 (0.0725)  loss_classifier: 0.0274 (0.0288)  loss_box_reg: 0.0197 (0.0219)  loss_objectness: 0.0184 (0.0186)  loss_rpn_box_reg: 0.0028 (0.0032)  time: 1.2223  data: 0.0229  max mem: 12822
# Epoch: [2]  [180/224]  eta: 0:00:53  lr: 0.005000  loss: 0.0667 (0.0723)  loss_classifier: 0.0280 (0.0287)  loss_box_reg: 0.0190 (0.0218)  loss_objectness: 0.0155 (0.0186)  loss_rpn_box_reg: 0.0029 (0.0032)  time: 1.2204  data: 0.0222  max mem: 12822
# Epoch: [2]  [190/224]  eta: 0:00:41  lr: 0.005000  loss: 0.0638 (0.0719)  loss_classifier: 0.0254 (0.0285)  loss_box_reg: 0.0206 (0.0219)  loss_objectness: 0.0143 (0.0183)  loss_rpn_box_reg: 0.0029 (0.0032)  time: 1.2219  data: 0.0240  max mem: 12822
# Epoch: [2]  [200/224]  eta: 0:00:29  lr: 0.005000  loss: 0.0620 (0.0717)  loss_classifier: 0.0242 (0.0284)  loss_box_reg: 0.0231 (0.0219)  loss_objectness: 0.0126 (0.0182)  loss_rpn_box_reg: 0.0029 (0.0032)  time: 1.2227  data: 0.0234  max mem: 12822
# Epoch: [2]  [210/224]  eta: 0:00:17  lr: 0.005000  loss: 0.0704 (0.0721)  loss_classifier: 0.0291 (0.0287)  loss_box_reg: 0.0228 (0.0220)  loss_objectness: 0.0153 (0.0182)  loss_rpn_box_reg: 0.0029 (0.0032)  time: 1.2211  data: 0.0221  max mem: 12822
# Epoch: [2]  [220/224]  eta: 0:00:04  lr: 0.005000  loss: 0.0723 (0.0718)  loss_classifier: 0.0298 (0.0286)  loss_box_reg: 0.0204 (0.0219)  loss_objectness: 0.0149 (0.0180)  loss_rpn_box_reg: 0.0028 (0.0032)  time: 1.2211  data: 0.0225  max mem: 12822
# Epoch: [2]  [223/224]  eta: 0:00:01  lr: 0.005000  loss: 0.0715 (0.0717)  loss_classifier: 0.0297 (0.0286)  loss_box_reg: 0.0207 (0.0219)  loss_objectness: 0.0149 (0.0180)  loss_rpn_box_reg: 0.0027 (0.0031)  time: 1.1738  data: 0.0218  max mem: 12822
# Epoch: [2] Total time: 0:04:33 (1.2209 s / it)
# Epoch: [3]  [  0/224]  eta: 0:06:56  lr: 0.000500  loss: 0.0718 (0.0718)  loss_classifier: 0.0304 (0.0304)  loss_box_reg: 0.0241 (0.0241)  loss_objectness: 0.0137 (0.0137)  loss_rpn_box_reg: 0.0037 (0.0037)  time: 1.8576  data: 0.6454  max mem: 12822
# Epoch: [3]  [ 10/224]  eta: 0:04:33  lr: 0.000500  loss: 0.0622 (0.0709)  loss_classifier: 0.0274 (0.0287)  loss_box_reg: 0.0207 (0.0211)  loss_objectness: 0.0138 (0.0182)  loss_rpn_box_reg: 0.0029 (0.0029)  time: 1.2787  data: 0.0782  max mem: 12822
# Epoch: [3]  [ 20/224]  eta: 0:04:16  lr: 0.000500  loss: 0.0622 (0.0692)  loss_classifier: 0.0262 (0.0282)  loss_box_reg: 0.0207 (0.0210)  loss_objectness: 0.0148 (0.0173)  loss_rpn_box_reg: 0.0026 (0.0028)  time: 1.2260  data: 0.0227  max mem: 12822
# Epoch: [3]  [ 30/224]  eta: 0:04:01  lr: 0.000500  loss: 0.0616 (0.0680)  loss_classifier: 0.0261 (0.0281)  loss_box_reg: 0.0210 (0.0206)  loss_objectness: 0.0148 (0.0165)  loss_rpn_box_reg: 0.0025 (0.0027)  time: 1.2261  data: 0.0236  max mem: 12822
# Epoch: [3]  [ 40/224]  eta: 0:03:47  lr: 0.000500  loss: 0.0624 (0.0680)  loss_classifier: 0.0273 (0.0280)  loss_box_reg: 0.0197 (0.0205)  loss_objectness: 0.0140 (0.0168)  loss_rpn_box_reg: 0.0024 (0.0027)  time: 1.2205  data: 0.0228  max mem: 12822
# Epoch: [3]  [ 50/224]  eta: 0:03:35  lr: 0.000500  loss: 0.0654 (0.0681)  loss_classifier: 0.0273 (0.0282)  loss_box_reg: 0.0195 (0.0202)  loss_objectness: 0.0142 (0.0170)  loss_rpn_box_reg: 0.0024 (0.0027)  time: 1.2215  data: 0.0227  max mem: 12822
# Epoch: [3]  [ 60/224]  eta: 0:03:22  lr: 0.000500  loss: 0.0627 (0.0667)  loss_classifier: 0.0262 (0.0276)  loss_box_reg: 0.0188 (0.0202)  loss_objectness: 0.0125 (0.0163)  loss_rpn_box_reg: 0.0025 (0.0027)  time: 1.2231  data: 0.0237  max mem: 12822
# Epoch: [3]  [ 70/224]  eta: 0:03:09  lr: 0.000500  loss: 0.0626 (0.0665)  loss_classifier: 0.0255 (0.0274)  loss_box_reg: 0.0190 (0.0202)  loss_objectness: 0.0125 (0.0161)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 1.2216  data: 0.0232  max mem: 12822
# Epoch: [3]  [ 80/224]  eta: 0:02:57  lr: 0.000500  loss: 0.0610 (0.0668)  loss_classifier: 0.0265 (0.0277)  loss_box_reg: 0.0210 (0.0205)  loss_objectness: 0.0118 (0.0159)  loss_rpn_box_reg: 0.0026 (0.0027)  time: 1.2206  data: 0.0223  max mem: 12822
# Epoch: [3]  [ 90/224]  eta: 0:02:44  lr: 0.000500  loss: 0.0603 (0.0661)  loss_classifier: 0.0241 (0.0275)  loss_box_reg: 0.0193 (0.0203)  loss_objectness: 0.0103 (0.0158)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 1.2216  data: 0.0224  max mem: 12822
# Epoch: [3]  [100/224]  eta: 0:02:32  lr: 0.000500  loss: 0.0619 (0.0659)  loss_classifier: 0.0253 (0.0275)  loss_box_reg: 0.0181 (0.0202)  loss_objectness: 0.0143 (0.0156)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 1.2202  data: 0.0215  max mem: 12822
# Epoch: [3]  [110/224]  eta: 0:02:19  lr: 0.000500  loss: 0.0619 (0.0654)  loss_classifier: 0.0253 (0.0273)  loss_box_reg: 0.0189 (0.0202)  loss_objectness: 0.0112 (0.0153)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 1.2200  data: 0.0214  max mem: 12822
# Epoch: [3]  [120/224]  eta: 0:02:07  lr: 0.000500  loss: 0.0639 (0.0654)  loss_classifier: 0.0244 (0.0272)  loss_box_reg: 0.0199 (0.0202)  loss_objectness: 0.0126 (0.0154)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 1.2208  data: 0.0227  max mem: 12822
# Epoch: [3]  [130/224]  eta: 0:01:55  lr: 0.000500  loss: 0.0639 (0.0652)  loss_classifier: 0.0255 (0.0269)  loss_box_reg: 0.0198 (0.0202)  loss_objectness: 0.0142 (0.0154)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 1.2211  data: 0.0227  max mem: 12822
# Epoch: [3]  [140/224]  eta: 0:01:43  lr: 0.000500  loss: 0.0591 (0.0646)  loss_classifier: 0.0230 (0.0267)  loss_box_reg: 0.0179 (0.0201)  loss_objectness: 0.0122 (0.0152)  loss_rpn_box_reg: 0.0023 (0.0026)  time: 1.2220  data: 0.0231  max mem: 12822
# Epoch: [3]  [150/224]  eta: 0:01:30  lr: 0.000500  loss: 0.0568 (0.0642)  loss_classifier: 0.0246 (0.0266)  loss_box_reg: 0.0167 (0.0200)  loss_objectness: 0.0094 (0.0151)  loss_rpn_box_reg: 0.0022 (0.0026)  time: 1.2219  data: 0.0239  max mem: 12822
# Epoch: [3]  [160/224]  eta: 0:01:18  lr: 0.000500  loss: 0.0574 (0.0639)  loss_classifier: 0.0247 (0.0265)  loss_box_reg: 0.0194 (0.0200)  loss_objectness: 0.0107 (0.0148)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 1.2220  data: 0.0234  max mem: 12822
# Epoch: [3]  [170/224]  eta: 0:01:06  lr: 0.000500  loss: 0.0616 (0.0638)  loss_classifier: 0.0238 (0.0264)  loss_box_reg: 0.0201 (0.0201)  loss_objectness: 0.0099 (0.0147)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 1.2211  data: 0.0233  max mem: 12822
# Epoch: [3]  [180/224]  eta: 0:00:53  lr: 0.000500  loss: 0.0622 (0.0637)  loss_classifier: 0.0238 (0.0263)  loss_box_reg: 0.0187 (0.0200)  loss_objectness: 0.0113 (0.0149)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 1.2197  data: 0.0226  max mem: 12822
# Epoch: [3]  [190/224]  eta: 0:00:41  lr: 0.000500  loss: 0.0644 (0.0642)  loss_classifier: 0.0283 (0.0265)  loss_box_reg: 0.0183 (0.0200)  loss_objectness: 0.0145 (0.0151)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 1.2202  data: 0.0226  max mem: 12822
# Epoch: [3]  [200/224]  eta: 0:00:29  lr: 0.000500  loss: 0.0641 (0.0639)  loss_classifier: 0.0269 (0.0264)  loss_box_reg: 0.0179 (0.0199)  loss_objectness: 0.0121 (0.0150)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 1.2199  data: 0.0223  max mem: 12822
# Epoch: [3]  [210/224]  eta: 0:00:17  lr: 0.000500  loss: 0.0560 (0.0638)  loss_classifier: 0.0227 (0.0264)  loss_box_reg: 0.0176 (0.0200)  loss_objectness: 0.0107 (0.0149)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 1.2201  data: 0.0220  max mem: 12822
# Epoch: [3]  [220/224]  eta: 0:00:04  lr: 0.000500  loss: 0.0650 (0.0639)  loss_classifier: 0.0264 (0.0264)  loss_box_reg: 0.0212 (0.0201)  loss_objectness: 0.0110 (0.0148)  loss_rpn_box_reg: 0.0027 (0.0026)  time: 1.2204  data: 0.0230  max mem: 12822
# Epoch: [3]  [223/224]  eta: 0:00:01  lr: 0.000500  loss: 0.0686 (0.0640)  loss_classifier: 0.0272 (0.0265)  loss_box_reg: 0.0212 (0.0201)  loss_objectness: 0.0110 (0.0148)  loss_rpn_box_reg: 0.0027 (0.0026)  time: 1.1733  data: 0.0225  max mem: 12822
# Epoch: [3] Total time: 0:04:33 (1.2203 s / it)
# Epoch: [4]  [  0/224]  eta: 0:07:05  lr: 0.000500  loss: 0.0744 (0.0744)  loss_classifier: 0.0308 (0.0308)  loss_box_reg: 0.0245 (0.0245)  loss_objectness: 0.0164 (0.0164)  loss_rpn_box_reg: 0.0028 (0.0028)  time: 1.9003  data: 0.6973  max mem: 12822
# Epoch: [4]  [ 10/224]  eta: 0:04:33  lr: 0.000500  loss: 0.0616 (0.0624)  loss_classifier: 0.0276 (0.0262)  loss_box_reg: 0.0239 (0.0212)  loss_objectness: 0.0112 (0.0123)  loss_rpn_box_reg: 0.0028 (0.0027)  time: 1.2766  data: 0.0788  max mem: 12822
# Epoch: [4]  [ 20/224]  eta: 0:04:16  lr: 0.000500  loss: 0.0616 (0.0629)  loss_classifier: 0.0261 (0.0263)  loss_box_reg: 0.0216 (0.0206)  loss_objectness: 0.0110 (0.0133)  loss_rpn_box_reg: 0.0027 (0.0027)  time: 1.2238  data: 0.0206  max mem: 12822
# Epoch: [4]  [ 30/224]  eta: 0:04:01  lr: 0.000500  loss: 0.0637 (0.0624)  loss_classifier: 0.0261 (0.0265)  loss_box_reg: 0.0185 (0.0199)  loss_objectness: 0.0116 (0.0134)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 1.2273  data: 0.0235  max mem: 12822
# Epoch: [4]  [ 40/224]  eta: 0:03:47  lr: 0.000500  loss: 0.0567 (0.0609)  loss_classifier: 0.0252 (0.0261)  loss_box_reg: 0.0188 (0.0200)  loss_objectness: 0.0098 (0.0122)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 1.2213  data: 0.0220  max mem: 12822
# Epoch: [4]  [ 50/224]  eta: 0:03:34  lr: 0.000500  loss: 0.0575 (0.0622)  loss_classifier: 0.0253 (0.0264)  loss_box_reg: 0.0214 (0.0200)  loss_objectness: 0.0101 (0.0131)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 1.2195  data: 0.0210  max mem: 12822
# Epoch: [4]  [ 60/224]  eta: 0:03:22  lr: 0.000500  loss: 0.0683 (0.0634)  loss_classifier: 0.0262 (0.0266)  loss_box_reg: 0.0203 (0.0201)  loss_objectness: 0.0156 (0.0140)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 1.2192  data: 0.0217  max mem: 12822
# Epoch: [4]  [ 70/224]  eta: 0:03:09  lr: 0.000500  loss: 0.0640 (0.0633)  loss_classifier: 0.0244 (0.0264)  loss_box_reg: 0.0203 (0.0201)  loss_objectness: 0.0139 (0.0143)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 1.2210  data: 0.0238  max mem: 12822
# Epoch: [4]  [ 80/224]  eta: 0:02:57  lr: 0.000500  loss: 0.0598 (0.0632)  loss_classifier: 0.0242 (0.0264)  loss_box_reg: 0.0200 (0.0200)  loss_objectness: 0.0096 (0.0142)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 1.2211  data: 0.0233  max mem: 12822
# Epoch: [4]  [ 90/224]  eta: 0:02:44  lr: 0.000500  loss: 0.0590 (0.0631)  loss_classifier: 0.0248 (0.0262)  loss_box_reg: 0.0191 (0.0199)  loss_objectness: 0.0108 (0.0144)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 1.2211  data: 0.0214  max mem: 12822
# Epoch: [4]  [100/224]  eta: 0:02:32  lr: 0.000500  loss: 0.0514 (0.0631)  loss_classifier: 0.0219 (0.0263)  loss_box_reg: 0.0191 (0.0198)  loss_objectness: 0.0108 (0.0144)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 1.2211  data: 0.0214  max mem: 12822
# Epoch: [4]  [110/224]  eta: 0:02:19  lr: 0.000500  loss: 0.0538 (0.0633)  loss_classifier: 0.0244 (0.0265)  loss_box_reg: 0.0198 (0.0199)  loss_objectness: 0.0107 (0.0144)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 1.2204  data: 0.0218  max mem: 12822
# Epoch: [4]  [120/224]  eta: 0:02:07  lr: 0.000500  loss: 0.0693 (0.0635)  loss_classifier: 0.0276 (0.0265)  loss_box_reg: 0.0197 (0.0199)  loss_objectness: 0.0152 (0.0145)  loss_rpn_box_reg: 0.0028 (0.0026)  time: 1.2197  data: 0.0219  max mem: 12822
# Epoch: [4]  [130/224]  eta: 0:01:55  lr: 0.000500  loss: 0.0643 (0.0636)  loss_classifier: 0.0262 (0.0267)  loss_box_reg: 0.0203 (0.0200)  loss_objectness: 0.0132 (0.0144)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 1.2219  data: 0.0236  max mem: 12822
# Epoch: [4]  [140/224]  eta: 0:01:42  lr: 0.000500  loss: 0.0539 (0.0630)  loss_classifier: 0.0223 (0.0264)  loss_box_reg: 0.0180 (0.0198)  loss_objectness: 0.0098 (0.0143)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 1.2230  data: 0.0233  max mem: 12822
# Epoch: [4]  [150/224]  eta: 0:01:30  lr: 0.000500  loss: 0.0548 (0.0627)  loss_classifier: 0.0209 (0.0263)  loss_box_reg: 0.0174 (0.0197)  loss_objectness: 0.0095 (0.0141)  loss_rpn_box_reg: 0.0022 (0.0026)  time: 1.2219  data: 0.0220  max mem: 12822
# Epoch: [4]  [160/224]  eta: 0:01:18  lr: 0.000500  loss: 0.0604 (0.0630)  loss_classifier: 0.0241 (0.0262)  loss_box_reg: 0.0205 (0.0199)  loss_objectness: 0.0109 (0.0143)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 1.2220  data: 0.0226  max mem: 12822
# Epoch: [4]  [170/224]  eta: 0:01:06  lr: 0.000500  loss: 0.0577 (0.0626)  loss_classifier: 0.0237 (0.0261)  loss_box_reg: 0.0197 (0.0198)  loss_objectness: 0.0113 (0.0142)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 1.2210  data: 0.0224  max mem: 12822
# Epoch: [4]  [180/224]  eta: 0:00:53  lr: 0.000500  loss: 0.0568 (0.0628)  loss_classifier: 0.0240 (0.0261)  loss_box_reg: 0.0189 (0.0198)  loss_objectness: 0.0113 (0.0143)  loss_rpn_box_reg: 0.0027 (0.0026)  time: 1.2205  data: 0.0216  max mem: 12822
# Epoch: [4]  [190/224]  eta: 0:00:41  lr: 0.000500  loss: 0.0629 (0.0627)  loss_classifier: 0.0256 (0.0260)  loss_box_reg: 0.0200 (0.0198)  loss_objectness: 0.0136 (0.0142)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 1.2208  data: 0.0216  max mem: 12822
# Epoch: [4]  [200/224]  eta: 0:00:29  lr: 0.000500  loss: 0.0593 (0.0625)  loss_classifier: 0.0244 (0.0260)  loss_box_reg: 0.0186 (0.0198)  loss_objectness: 0.0114 (0.0142)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 1.2207  data: 0.0227  max mem: 12822
# Epoch: [4]  [210/224]  eta: 0:00:17  lr: 0.000500  loss: 0.0556 (0.0623)  loss_classifier: 0.0241 (0.0260)  loss_box_reg: 0.0192 (0.0198)  loss_objectness: 0.0082 (0.0140)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 1.2206  data: 0.0223  max mem: 12822
# Epoch: [4]  [220/224]  eta: 0:00:04  lr: 0.000500  loss: 0.0590 (0.0625)  loss_classifier: 0.0265 (0.0260)  loss_box_reg: 0.0197 (0.0197)  loss_objectness: 0.0104 (0.0142)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.2204  data: 0.0217  max mem: 12822
# Epoch: [4]  [223/224]  eta: 0:00:01  lr: 0.000500  loss: 0.0589 (0.0623)  loss_classifier: 0.0241 (0.0260)  loss_box_reg: 0.0194 (0.0197)  loss_objectness: 0.0109 (0.0141)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.1727  data: 0.0210  max mem: 12822
# Epoch: [4] Total time: 0:04:33 (1.2203 s / it)
# Epoch: [5]  [  0/224]  eta: 0:06:34  lr: 0.000500  loss: 0.0671 (0.0671)  loss_classifier: 0.0323 (0.0323)  loss_box_reg: 0.0197 (0.0197)  loss_objectness: 0.0127 (0.0127)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.7612  data: 0.5535  max mem: 12822
# Epoch: [5]  [ 10/224]  eta: 0:04:32  lr: 0.000500  loss: 0.0639 (0.0625)  loss_classifier: 0.0262 (0.0263)  loss_box_reg: 0.0220 (0.0215)  loss_objectness: 0.0088 (0.0120)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 1.2728  data: 0.0708  max mem: 12822
# Epoch: [5]  [ 20/224]  eta: 0:04:15  lr: 0.000500  loss: 0.0644 (0.0677)  loss_classifier: 0.0274 (0.0284)  loss_box_reg: 0.0220 (0.0218)  loss_objectness: 0.0145 (0.0148)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 1.2249  data: 0.0242  max mem: 12822
# Epoch: [5]  [ 30/224]  eta: 0:04:00  lr: 0.000500  loss: 0.0660 (0.0645)  loss_classifier: 0.0248 (0.0265)  loss_box_reg: 0.0210 (0.0215)  loss_objectness: 0.0118 (0.0138)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 1.2220  data: 0.0237  max mem: 12822
# Epoch: [5]  [ 40/224]  eta: 0:03:47  lr: 0.000500  loss: 0.0533 (0.0626)  loss_classifier: 0.0219 (0.0254)  loss_box_reg: 0.0195 (0.0211)  loss_objectness: 0.0086 (0.0134)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 1.2199  data: 0.0218  max mem: 12822
# Epoch: [5]  [ 50/224]  eta: 0:03:34  lr: 0.000500  loss: 0.0563 (0.0627)  loss_classifier: 0.0229 (0.0256)  loss_box_reg: 0.0199 (0.0210)  loss_objectness: 0.0095 (0.0134)  loss_rpn_box_reg: 0.0026 (0.0027)  time: 1.2233  data: 0.0235  max mem: 12822
# Epoch: [5]  [ 60/224]  eta: 0:03:21  lr: 0.000500  loss: 0.0563 (0.0615)  loss_classifier: 0.0219 (0.0251)  loss_box_reg: 0.0199 (0.0208)  loss_objectness: 0.0109 (0.0129)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 1.2231  data: 0.0236  max mem: 12822
# Epoch: [5]  [ 70/224]  eta: 0:03:09  lr: 0.000500  loss: 0.0505 (0.0616)  loss_classifier: 0.0210 (0.0253)  loss_box_reg: 0.0178 (0.0204)  loss_objectness: 0.0099 (0.0133)  loss_rpn_box_reg: 0.0023 (0.0026)  time: 1.2226  data: 0.0223  max mem: 12822
# Epoch: [5]  [ 80/224]  eta: 0:02:57  lr: 0.000500  loss: 0.0479 (0.0606)  loss_classifier: 0.0209 (0.0249)  loss_box_reg: 0.0193 (0.0204)  loss_objectness: 0.0081 (0.0128)  loss_rpn_box_reg: 0.0023 (0.0026)  time: 1.2238  data: 0.0232  max mem: 12822
# Epoch: [5]  [ 90/224]  eta: 0:02:44  lr: 0.000500  loss: 0.0597 (0.0614)  loss_classifier: 0.0236 (0.0252)  loss_box_reg: 0.0194 (0.0205)  loss_objectness: 0.0098 (0.0131)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 1.2242  data: 0.0243  max mem: 12822
# Epoch: [5]  [100/224]  eta: 0:02:32  lr: 0.000500  loss: 0.0637 (0.0613)  loss_classifier: 0.0247 (0.0252)  loss_box_reg: 0.0190 (0.0203)  loss_objectness: 0.0165 (0.0132)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 1.2224  data: 0.0239  max mem: 12822
# Epoch: [5]  [110/224]  eta: 0:02:19  lr: 0.000500  loss: 0.0568 (0.0613)  loss_classifier: 0.0247 (0.0254)  loss_box_reg: 0.0190 (0.0202)  loss_objectness: 0.0119 (0.0132)  loss_rpn_box_reg: 0.0027 (0.0026)  time: 1.2211  data: 0.0233  max mem: 12822
# Epoch: [5]  [120/224]  eta: 0:02:07  lr: 0.000500  loss: 0.0584 (0.0619)  loss_classifier: 0.0248 (0.0256)  loss_box_reg: 0.0196 (0.0202)  loss_objectness: 0.0119 (0.0135)  loss_rpn_box_reg: 0.0027 (0.0026)  time: 1.2245  data: 0.0248  max mem: 12822
# Epoch: [5]  [130/224]  eta: 0:01:55  lr: 0.000500  loss: 0.0619 (0.0624)  loss_classifier: 0.0265 (0.0259)  loss_box_reg: 0.0178 (0.0201)  loss_objectness: 0.0131 (0.0138)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 1.2258  data: 0.0260  max mem: 12822
# Epoch: [5]  [140/224]  eta: 0:01:43  lr: 0.000500  loss: 0.0607 (0.0626)  loss_classifier: 0.0255 (0.0260)  loss_box_reg: 0.0185 (0.0202)  loss_objectness: 0.0116 (0.0138)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 1.2246  data: 0.0256  max mem: 12822
# Epoch: [5]  [150/224]  eta: 0:01:30  lr: 0.000500  loss: 0.0628 (0.0627)  loss_classifier: 0.0276 (0.0261)  loss_box_reg: 0.0198 (0.0201)  loss_objectness: 0.0115 (0.0138)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 1.2240  data: 0.0246  max mem: 12822
# Epoch: [5]  [160/224]  eta: 0:01:18  lr: 0.000500  loss: 0.0609 (0.0622)  loss_classifier: 0.0269 (0.0260)  loss_box_reg: 0.0173 (0.0200)  loss_objectness: 0.0113 (0.0137)  loss_rpn_box_reg: 0.0023 (0.0026)  time: 1.2229  data: 0.0242  max mem: 12822
# Epoch: [5]  [170/224]  eta: 0:01:06  lr: 0.000500  loss: 0.0546 (0.0625)  loss_classifier: 0.0235 (0.0260)  loss_box_reg: 0.0170 (0.0199)  loss_objectness: 0.0096 (0.0140)  loss_rpn_box_reg: 0.0023 (0.0026)  time: 1.2215  data: 0.0236  max mem: 12822
# Epoch: [5]  [180/224]  eta: 0:00:53  lr: 0.000500  loss: 0.0537 (0.0622)  loss_classifier: 0.0241 (0.0259)  loss_box_reg: 0.0185 (0.0198)  loss_objectness: 0.0102 (0.0140)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 1.2220  data: 0.0238  max mem: 12822
# Epoch: [5]  [190/224]  eta: 0:00:41  lr: 0.000500  loss: 0.0554 (0.0622)  loss_classifier: 0.0245 (0.0259)  loss_box_reg: 0.0187 (0.0198)  loss_objectness: 0.0094 (0.0140)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 1.2237  data: 0.0242  max mem: 12822
# Epoch: [5]  [200/224]  eta: 0:00:29  lr: 0.000500  loss: 0.0554 (0.0621)  loss_classifier: 0.0230 (0.0258)  loss_box_reg: 0.0191 (0.0198)  loss_objectness: 0.0094 (0.0139)  loss_rpn_box_reg: 0.0025 (0.0026)  time: 1.2223  data: 0.0224  max mem: 12822
# Epoch: [5]  [210/224]  eta: 0:00:17  lr: 0.000500  loss: 0.0554 (0.0619)  loss_classifier: 0.0230 (0.0257)  loss_box_reg: 0.0191 (0.0198)  loss_objectness: 0.0100 (0.0139)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 1.2205  data: 0.0213  max mem: 12822
# Epoch: [5]  [220/224]  eta: 0:00:04  lr: 0.000500  loss: 0.0578 (0.0617)  loss_classifier: 0.0253 (0.0256)  loss_box_reg: 0.0168 (0.0197)  loss_objectness: 0.0097 (0.0138)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 1.2209  data: 0.0223  max mem: 12822
# Epoch: [5]  [223/224]  eta: 0:00:01  lr: 0.000500  loss: 0.0587 (0.0619)  loss_classifier: 0.0253 (0.0257)  loss_box_reg: 0.0186 (0.0198)  loss_objectness: 0.0100 (0.0138)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 1.1730  data: 0.0213  max mem: 12822
# Epoch: [5] Total time: 0:04:33 (1.2213 s / it)
# Epoch: [6]  [  0/224]  eta: 0:07:08  lr: 0.000050  loss: 0.0495 (0.0495)  loss_classifier: 0.0214 (0.0214)  loss_box_reg: 0.0193 (0.0193)  loss_objectness: 0.0065 (0.0065)  loss_rpn_box_reg: 0.0023 (0.0023)  time: 1.9137  data: 0.7027  max mem: 12822
# Epoch: [6]  [ 10/224]  eta: 0:04:35  lr: 0.000050  loss: 0.0676 (0.0645)  loss_classifier: 0.0267 (0.0260)  loss_box_reg: 0.0193 (0.0194)  loss_objectness: 0.0173 (0.0165)  loss_rpn_box_reg: 0.0024 (0.0026)  time: 1.2857  data: 0.0836  max mem: 12822
# Epoch: [6]  [ 20/224]  eta: 0:04:16  lr: 0.000050  loss: 0.0622 (0.0617)  loss_classifier: 0.0265 (0.0253)  loss_box_reg: 0.0195 (0.0194)  loss_objectness: 0.0117 (0.0145)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.2244  data: 0.0236  max mem: 12822
# Epoch: [6]  [ 30/224]  eta: 0:04:01  lr: 0.000050  loss: 0.0560 (0.0599)  loss_classifier: 0.0226 (0.0247)  loss_box_reg: 0.0195 (0.0195)  loss_objectness: 0.0083 (0.0132)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.2261  data: 0.0262  max mem: 12822
# Epoch: [6]  [ 40/224]  eta: 0:03:48  lr: 0.000050  loss: 0.0560 (0.0604)  loss_classifier: 0.0217 (0.0247)  loss_box_reg: 0.0177 (0.0193)  loss_objectness: 0.0124 (0.0139)  loss_rpn_box_reg: 0.0025 (0.0024)  time: 1.2237  data: 0.0245  max mem: 12822
# Epoch: [6]  [ 50/224]  eta: 0:03:35  lr: 0.000050  loss: 0.0581 (0.0603)  loss_classifier: 0.0241 (0.0247)  loss_box_reg: 0.0182 (0.0194)  loss_objectness: 0.0124 (0.0137)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.2223  data: 0.0223  max mem: 12822
# Epoch: [6]  [ 60/224]  eta: 0:03:22  lr: 0.000050  loss: 0.0607 (0.0606)  loss_classifier: 0.0258 (0.0252)  loss_box_reg: 0.0190 (0.0196)  loss_objectness: 0.0104 (0.0134)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.2223  data: 0.0221  max mem: 12822
# Epoch: [6]  [ 70/224]  eta: 0:03:09  lr: 0.000050  loss: 0.0587 (0.0597)  loss_classifier: 0.0259 (0.0250)  loss_box_reg: 0.0188 (0.0194)  loss_objectness: 0.0104 (0.0129)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 1.2208  data: 0.0220  max mem: 12822
# Epoch: [6]  [ 80/224]  eta: 0:02:57  lr: 0.000050  loss: 0.0507 (0.0588)  loss_classifier: 0.0216 (0.0246)  loss_box_reg: 0.0172 (0.0192)  loss_objectness: 0.0094 (0.0125)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 1.2222  data: 0.0232  max mem: 12822
# Epoch: [6]  [ 90/224]  eta: 0:02:44  lr: 0.000050  loss: 0.0517 (0.0596)  loss_classifier: 0.0213 (0.0249)  loss_box_reg: 0.0168 (0.0192)  loss_objectness: 0.0105 (0.0132)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.2223  data: 0.0229  max mem: 12822
# Epoch: [6]  [100/224]  eta: 0:02:32  lr: 0.000050  loss: 0.0587 (0.0598)  loss_classifier: 0.0247 (0.0250)  loss_box_reg: 0.0170 (0.0192)  loss_objectness: 0.0134 (0.0132)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 1.2205  data: 0.0212  max mem: 12822
# Epoch: [6]  [110/224]  eta: 0:02:20  lr: 0.000050  loss: 0.0543 (0.0594)  loss_classifier: 0.0242 (0.0248)  loss_box_reg: 0.0174 (0.0192)  loss_objectness: 0.0122 (0.0130)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.2218  data: 0.0220  max mem: 12822
# Epoch: [6]  [120/224]  eta: 0:02:07  lr: 0.000050  loss: 0.0524 (0.0594)  loss_classifier: 0.0239 (0.0248)  loss_box_reg: 0.0191 (0.0193)  loss_objectness: 0.0095 (0.0128)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 1.2232  data: 0.0229  max mem: 12822
# Epoch: [6]  [130/224]  eta: 0:01:55  lr: 0.000050  loss: 0.0604 (0.0595)  loss_classifier: 0.0236 (0.0247)  loss_box_reg: 0.0194 (0.0194)  loss_objectness: 0.0106 (0.0130)  loss_rpn_box_reg: 0.0025 (0.0024)  time: 1.2242  data: 0.0232  max mem: 12822
# Epoch: [6]  [140/224]  eta: 0:01:43  lr: 0.000050  loss: 0.0553 (0.0596)  loss_classifier: 0.0236 (0.0248)  loss_box_reg: 0.0181 (0.0194)  loss_objectness: 0.0100 (0.0129)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.2235  data: 0.0230  max mem: 12822
# Epoch: [6]  [150/224]  eta: 0:01:30  lr: 0.000050  loss: 0.0595 (0.0600)  loss_classifier: 0.0272 (0.0251)  loss_box_reg: 0.0208 (0.0196)  loss_objectness: 0.0096 (0.0129)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.2215  data: 0.0217  max mem: 12822
# Epoch: [6]  [160/224]  eta: 0:01:18  lr: 0.000050  loss: 0.0576 (0.0596)  loss_classifier: 0.0248 (0.0249)  loss_box_reg: 0.0208 (0.0195)  loss_objectness: 0.0096 (0.0128)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 1.2224  data: 0.0223  max mem: 12822
# Epoch: [6]  [170/224]  eta: 0:01:06  lr: 0.000050  loss: 0.0534 (0.0594)  loss_classifier: 0.0234 (0.0248)  loss_box_reg: 0.0174 (0.0194)  loss_objectness: 0.0072 (0.0127)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 1.2226  data: 0.0230  max mem: 12822
# Epoch: [6]  [180/224]  eta: 0:00:53  lr: 0.000050  loss: 0.0620 (0.0598)  loss_classifier: 0.0247 (0.0250)  loss_box_reg: 0.0199 (0.0195)  loss_objectness: 0.0156 (0.0129)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.2217  data: 0.0222  max mem: 12822
# Epoch: [6]  [190/224]  eta: 0:00:41  lr: 0.000050  loss: 0.0603 (0.0600)  loss_classifier: 0.0256 (0.0250)  loss_box_reg: 0.0214 (0.0195)  loss_objectness: 0.0152 (0.0130)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.2229  data: 0.0230  max mem: 12822
# Epoch: [6]  [200/224]  eta: 0:00:29  lr: 0.000050  loss: 0.0583 (0.0597)  loss_classifier: 0.0235 (0.0249)  loss_box_reg: 0.0182 (0.0194)  loss_objectness: 0.0110 (0.0130)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.2246  data: 0.0245  max mem: 12822
# Epoch: [6]  [210/224]  eta: 0:00:17  lr: 0.000050  loss: 0.0570 (0.0598)  loss_classifier: 0.0220 (0.0249)  loss_box_reg: 0.0172 (0.0194)  loss_objectness: 0.0110 (0.0130)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.2241  data: 0.0240  max mem: 12822
# Epoch: [6]  [220/224]  eta: 0:00:04  lr: 0.000050  loss: 0.0626 (0.0601)  loss_classifier: 0.0274 (0.0251)  loss_box_reg: 0.0193 (0.0195)  loss_objectness: 0.0125 (0.0131)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.2217  data: 0.0231  max mem: 12822
# Epoch: [6]  [223/224]  eta: 0:00:01  lr: 0.000050  loss: 0.0626 (0.0602)  loss_classifier: 0.0277 (0.0251)  loss_box_reg: 0.0206 (0.0195)  loss_objectness: 0.0120 (0.0131)  loss_rpn_box_reg: 0.0027 (0.0025)  time: 1.1736  data: 0.0220  max mem: 12822
# Epoch: [6] Total time: 0:04:33 (1.2219 s / it)
# Epoch: [7]  [  0/224]  eta: 0:11:45  lr: 0.000050  loss: 0.0528 (0.0528)  loss_classifier: 0.0218 (0.0218)  loss_box_reg: 0.0201 (0.0201)  loss_objectness: 0.0086 (0.0086)  loss_rpn_box_reg: 0.0023 (0.0023)  time: 3.1482  data: 1.9272  max mem: 12822
# Epoch: [7]  [ 10/224]  eta: 0:04:58  lr: 0.000050  loss: 0.0617 (0.0671)  loss_classifier: 0.0319 (0.0304)  loss_box_reg: 0.0210 (0.0207)  loss_objectness: 0.0110 (0.0137)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.3954  data: 0.1943  max mem: 12822
# Epoch: [7]  [ 20/224]  eta: 0:04:28  lr: 0.000050  loss: 0.0589 (0.0624)  loss_classifier: 0.0268 (0.0274)  loss_box_reg: 0.0206 (0.0205)  loss_objectness: 0.0102 (0.0120)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.2259  data: 0.0238  max mem: 12822
# Epoch: [7]  [ 30/224]  eta: 0:04:09  lr: 0.000050  loss: 0.0558 (0.0609)  loss_classifier: 0.0242 (0.0266)  loss_box_reg: 0.0201 (0.0202)  loss_objectness: 0.0096 (0.0116)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.2292  data: 0.0262  max mem: 12822
# Epoch: [7]  [ 40/224]  eta: 0:03:54  lr: 0.000050  loss: 0.0541 (0.0589)  loss_classifier: 0.0226 (0.0252)  loss_box_reg: 0.0183 (0.0197)  loss_objectness: 0.0086 (0.0116)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 1.2243  data: 0.0243  max mem: 12822
# Epoch: [7]  [ 50/224]  eta: 0:03:39  lr: 0.000050  loss: 0.0541 (0.0599)  loss_classifier: 0.0221 (0.0253)  loss_box_reg: 0.0183 (0.0197)  loss_objectness: 0.0087 (0.0124)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 1.2211  data: 0.0219  max mem: 12822
# Epoch: [7]  [ 60/224]  eta: 0:03:25  lr: 0.000050  loss: 0.0618 (0.0608)  loss_classifier: 0.0246 (0.0254)  loss_box_reg: 0.0201 (0.0199)  loss_objectness: 0.0119 (0.0130)  loss_rpn_box_reg: 0.0026 (0.0025)  time: 1.2210  data: 0.0216  max mem: 12822
# Epoch: [7]  [ 70/224]  eta: 0:03:12  lr: 0.000050  loss: 0.0588 (0.0602)  loss_classifier: 0.0246 (0.0254)  loss_box_reg: 0.0190 (0.0197)  loss_objectness: 0.0096 (0.0126)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.2221  data: 0.0229  max mem: 12822
# Epoch: [7]  [ 80/224]  eta: 0:02:59  lr: 0.000050  loss: 0.0584 (0.0607)  loss_classifier: 0.0250 (0.0256)  loss_box_reg: 0.0188 (0.0197)  loss_objectness: 0.0102 (0.0129)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.2225  data: 0.0235  max mem: 12822
# Epoch: [7]  [ 90/224]  eta: 0:02:46  lr: 0.000050  loss: 0.0592 (0.0605)  loss_classifier: 0.0257 (0.0255)  loss_box_reg: 0.0180 (0.0195)  loss_objectness: 0.0136 (0.0130)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.2230  data: 0.0237  max mem: 12822
# Epoch: [7]  [100/224]  eta: 0:02:34  lr: 0.000050  loss: 0.0534 (0.0600)  loss_classifier: 0.0244 (0.0255)  loss_box_reg: 0.0179 (0.0193)  loss_objectness: 0.0084 (0.0128)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 1.2226  data: 0.0235  max mem: 12822
# Epoch: [7]  [110/224]  eta: 0:02:21  lr: 0.000050  loss: 0.0514 (0.0599)  loss_classifier: 0.0224 (0.0254)  loss_box_reg: 0.0194 (0.0194)  loss_objectness: 0.0080 (0.0126)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 1.2216  data: 0.0227  max mem: 12822
# Epoch: [7]  [120/224]  eta: 0:02:08  lr: 0.000050  loss: 0.0568 (0.0601)  loss_classifier: 0.0253 (0.0256)  loss_box_reg: 0.0201 (0.0195)  loss_objectness: 0.0088 (0.0126)  loss_rpn_box_reg: 0.0025 (0.0024)  time: 1.2211  data: 0.0222  max mem: 12822
# Epoch: [7]  [130/224]  eta: 0:01:56  lr: 0.000050  loss: 0.0568 (0.0603)  loss_classifier: 0.0264 (0.0258)  loss_box_reg: 0.0193 (0.0194)  loss_objectness: 0.0098 (0.0126)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 1.2216  data: 0.0223  max mem: 12822
# Epoch: [7]  [140/224]  eta: 0:01:43  lr: 0.000050  loss: 0.0600 (0.0604)  loss_classifier: 0.0257 (0.0258)  loss_box_reg: 0.0191 (0.0195)  loss_objectness: 0.0114 (0.0127)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 1.2214  data: 0.0222  max mem: 12822
# Epoch: [7]  [150/224]  eta: 0:01:31  lr: 0.000050  loss: 0.0559 (0.0600)  loss_classifier: 0.0237 (0.0255)  loss_box_reg: 0.0187 (0.0194)  loss_objectness: 0.0114 (0.0127)  loss_rpn_box_reg: 0.0025 (0.0024)  time: 1.2202  data: 0.0224  max mem: 12822
# Epoch: [7]  [160/224]  eta: 0:01:19  lr: 0.000050  loss: 0.0576 (0.0599)  loss_classifier: 0.0218 (0.0254)  loss_box_reg: 0.0177 (0.0193)  loss_objectness: 0.0129 (0.0128)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 1.2229  data: 0.0248  max mem: 12822
# Epoch: [7]  [170/224]  eta: 0:01:06  lr: 0.000050  loss: 0.0625 (0.0604)  loss_classifier: 0.0253 (0.0255)  loss_box_reg: 0.0184 (0.0194)  loss_objectness: 0.0130 (0.0131)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 1.2215  data: 0.0234  max mem: 12822
# Epoch: [7]  [180/224]  eta: 0:00:54  lr: 0.000050  loss: 0.0513 (0.0602)  loss_classifier: 0.0223 (0.0254)  loss_box_reg: 0.0170 (0.0192)  loss_objectness: 0.0125 (0.0131)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.2200  data: 0.0219  max mem: 12822
# Epoch: [7]  [190/224]  eta: 0:00:41  lr: 0.000050  loss: 0.0518 (0.0598)  loss_classifier: 0.0215 (0.0252)  loss_box_reg: 0.0170 (0.0193)  loss_objectness: 0.0083 (0.0129)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 1.2214  data: 0.0223  max mem: 12822
# Epoch: [7]  [200/224]  eta: 0:00:29  lr: 0.000050  loss: 0.0563 (0.0600)  loss_classifier: 0.0226 (0.0253)  loss_box_reg: 0.0190 (0.0193)  loss_objectness: 0.0099 (0.0130)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.2210  data: 0.0210  max mem: 12822
# ...
# Epoch: [47]  [100/224]  eta: 0:02:32  lr: 0.000000  loss: 0.0592 (0.0617)  loss_classifier: 0.0251 (0.0256)  loss_box_reg: 0.0187 (0.0196)  loss_objectness: 0.0098 (0.0141)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.2215  data: 0.0235  max mem: 12822
# Epoch: [47]  [110/224]  eta: 0:02:20  lr: 0.000000  loss: 0.0548 (0.0611)  loss_classifier: 0.0228 (0.0254)  loss_box_reg: 0.0181 (0.0194)  loss_objectness: 0.0087 (0.0138)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.2219  data: 0.0236  max mem: 12822
# Epoch: [47]  [120/224]  eta: 0:02:07  lr: 0.000000  loss: 0.0536 (0.0607)  loss_classifier: 0.0242 (0.0253)  loss_box_reg: 0.0175 (0.0193)  loss_objectness: 0.0089 (0.0137)  loss_rpn_box_reg: 0.0022 (0.0025)  time: 1.2226  data: 0.0237  max mem: 12822
# Epoch: [47]  [130/224]  eta: 0:01:55  lr: 0.000000  loss: 0.0564 (0.0609)  loss_classifier: 0.0244 (0.0253)  loss_box_reg: 0.0182 (0.0193)  loss_objectness: 0.0089 (0.0138)  loss_rpn_box_reg: 0.0022 (0.0025)  time: 1.2220  data: 0.0227  max mem: 12822
# Epoch: [47]  [140/224]  eta: 0:01:43  lr: 0.000000  loss: 0.0564 (0.0607)  loss_classifier: 0.0242 (0.0253)  loss_box_reg: 0.0190 (0.0192)  loss_objectness: 0.0087 (0.0137)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.2226  data: 0.0230  max mem: 12822
# Epoch: [47]  [150/224]  eta: 0:01:30  lr: 0.000000  loss: 0.0568 (0.0609)  loss_classifier: 0.0242 (0.0254)  loss_box_reg: 0.0195 (0.0195)  loss_objectness: 0.0103 (0.0135)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.2229  data: 0.0231  max mem: 12822
# Epoch: [47]  [160/224]  eta: 0:01:18  lr: 0.000000  loss: 0.0580 (0.0607)  loss_classifier: 0.0242 (0.0253)  loss_box_reg: 0.0208 (0.0195)  loss_objectness: 0.0096 (0.0133)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.2239  data: 0.0232  max mem: 12822
# Epoch: [47]  [170/224]  eta: 0:01:06  lr: 0.000000  loss: 0.0580 (0.0605)  loss_classifier: 0.0241 (0.0253)  loss_box_reg: 0.0181 (0.0195)  loss_objectness: 0.0096 (0.0132)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.2233  data: 0.0234  max mem: 12822
# Epoch: [47]  [180/224]  eta: 0:00:53  lr: 0.000000  loss: 0.0559 (0.0604)  loss_classifier: 0.0258 (0.0254)  loss_box_reg: 0.0181 (0.0194)  loss_objectness: 0.0096 (0.0132)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.2230  data: 0.0235  max mem: 12822
# Epoch: [47]  [190/224]  eta: 0:00:41  lr: 0.000000  loss: 0.0559 (0.0604)  loss_classifier: 0.0261 (0.0253)  loss_box_reg: 0.0184 (0.0194)  loss_objectness: 0.0103 (0.0131)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.2237  data: 0.0238  max mem: 12822
# Epoch: [47]  [200/224]  eta: 0:00:29  lr: 0.000000  loss: 0.0568 (0.0603)  loss_classifier: 0.0254 (0.0254)  loss_box_reg: 0.0184 (0.0194)  loss_objectness: 0.0104 (0.0131)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.2219  data: 0.0240  max mem: 12822
# Epoch: [47]  [210/224]  eta: 0:00:17  lr: 0.000000  loss: 0.0575 (0.0603)  loss_classifier: 0.0246 (0.0254)  loss_box_reg: 0.0188 (0.0194)  loss_objectness: 0.0098 (0.0131)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.2209  data: 0.0238  max mem: 12822
# Epoch: [47]  [220/224]  eta: 0:00:04  lr: 0.000000  loss: 0.0579 (0.0602)  loss_classifier: 0.0231 (0.0253)  loss_box_reg: 0.0186 (0.0193)  loss_objectness: 0.0105 (0.0131)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.2218  data: 0.0238  max mem: 12822
# Epoch: [47]  [223/224]  eta: 0:00:01  lr: 0.000000  loss: 0.0551 (0.0601)  loss_classifier: 0.0206 (0.0252)  loss_box_reg: 0.0176 (0.0194)  loss_objectness: 0.0098 (0.0130)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.1746  data: 0.0225  max mem: 12822
# Epoch: [47] Total time: 0:04:33 (1.2218 s / it)
# Epoch: [48]  [  0/224]  eta: 0:07:14  lr: 0.000000  loss: 0.0721 (0.0721)  loss_classifier: 0.0292 (0.0292)  loss_box_reg: 0.0290 (0.0290)  loss_objectness: 0.0105 (0.0105)  loss_rpn_box_reg: 0.0034 (0.0034)  time: 1.9376  data: 0.6898  max mem: 12822
# Epoch: [48]  [ 10/224]  eta: 0:04:35  lr: 0.000000  loss: 0.0573 (0.0559)  loss_classifier: 0.0232 (0.0239)  loss_box_reg: 0.0172 (0.0183)  loss_objectness: 0.0105 (0.0114)  loss_rpn_box_reg: 0.0022 (0.0023)  time: 1.2888  data: 0.0785  max mem: 12822
# Epoch: [48]  [ 20/224]  eta: 0:04:16  lr: 0.000000  loss: 0.0526 (0.0549)  loss_classifier: 0.0215 (0.0232)  loss_box_reg: 0.0172 (0.0182)  loss_objectness: 0.0100 (0.0113)  loss_rpn_box_reg: 0.0022 (0.0023)  time: 1.2241  data: 0.0213  max mem: 12822
# Epoch: [48]  [ 30/224]  eta: 0:04:01  lr: 0.000000  loss: 0.0606 (0.0582)  loss_classifier: 0.0231 (0.0245)  loss_box_reg: 0.0186 (0.0192)  loss_objectness: 0.0106 (0.0121)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.2233  data: 0.0244  max mem: 12822
# Epoch: [48]  [ 40/224]  eta: 0:03:48  lr: 0.000000  loss: 0.0632 (0.0595)  loss_classifier: 0.0244 (0.0249)  loss_box_reg: 0.0184 (0.0193)  loss_objectness: 0.0139 (0.0127)  loss_rpn_box_reg: 0.0026 (0.0025)  time: 1.2221  data: 0.0230  max mem: 12822
# Epoch: [48]  [ 50/224]  eta: 0:03:35  lr: 0.000000  loss: 0.0556 (0.0580)  loss_classifier: 0.0223 (0.0242)  loss_box_reg: 0.0180 (0.0191)  loss_objectness: 0.0111 (0.0123)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.2237  data: 0.0232  max mem: 12822
# Epoch: [48]  [ 60/224]  eta: 0:03:22  lr: 0.000000  loss: 0.0550 (0.0586)  loss_classifier: 0.0223 (0.0243)  loss_box_reg: 0.0175 (0.0190)  loss_objectness: 0.0086 (0.0128)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.2246  data: 0.0241  max mem: 12822
# Epoch: [48]  [ 70/224]  eta: 0:03:09  lr: 0.000000  loss: 0.0589 (0.0586)  loss_classifier: 0.0229 (0.0244)  loss_box_reg: 0.0201 (0.0190)  loss_objectness: 0.0124 (0.0127)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 1.2237  data: 0.0238  max mem: 12822
# Epoch: [48]  [ 80/224]  eta: 0:02:57  lr: 0.000000  loss: 0.0589 (0.0592)  loss_classifier: 0.0245 (0.0248)  loss_box_reg: 0.0190 (0.0190)  loss_objectness: 0.0124 (0.0131)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.2224  data: 0.0225  max mem: 12822
# Epoch: [48]  [ 90/224]  eta: 0:02:44  lr: 0.000000  loss: 0.0539 (0.0586)  loss_classifier: 0.0221 (0.0243)  loss_box_reg: 0.0165 (0.0187)  loss_objectness: 0.0136 (0.0132)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 1.2212  data: 0.0218  max mem: 12822
# Epoch: [48]  [100/224]  eta: 0:02:32  lr: 0.000000  loss: 0.0539 (0.0587)  loss_classifier: 0.0243 (0.0246)  loss_box_reg: 0.0161 (0.0187)  loss_objectness: 0.0120 (0.0130)  loss_rpn_box_reg: 0.0023 (0.0024)  time: 1.2223  data: 0.0231  max mem: 12822
# Epoch: [48]  [110/224]  eta: 0:02:20  lr: 0.000000  loss: 0.0575 (0.0590)  loss_classifier: 0.0244 (0.0246)  loss_box_reg: 0.0192 (0.0188)  loss_objectness: 0.0120 (0.0131)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 1.2231  data: 0.0233  max mem: 12822
# Epoch: [48]  [120/224]  eta: 0:02:07  lr: 0.000000  loss: 0.0587 (0.0591)  loss_classifier: 0.0240 (0.0247)  loss_box_reg: 0.0196 (0.0189)  loss_objectness: 0.0115 (0.0130)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 1.2225  data: 0.0219  max mem: 12822
# Epoch: [48]  [130/224]  eta: 0:01:55  lr: 0.000000  loss: 0.0591 (0.0595)  loss_classifier: 0.0272 (0.0249)  loss_box_reg: 0.0209 (0.0192)  loss_objectness: 0.0089 (0.0130)  loss_rpn_box_reg: 0.0024 (0.0024)  time: 1.2239  data: 0.0225  max mem: 12822
# Epoch: [48]  [140/224]  eta: 0:01:43  lr: 0.000000  loss: 0.0657 (0.0600)  loss_classifier: 0.0263 (0.0251)  loss_box_reg: 0.0216 (0.0193)  loss_objectness: 0.0132 (0.0132)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.2240  data: 0.0236  max mem: 12822
# Epoch: [48]  [150/224]  eta: 0:01:30  lr: 0.000000  loss: 0.0618 (0.0601)  loss_classifier: 0.0252 (0.0251)  loss_box_reg: 0.0212 (0.0194)  loss_objectness: 0.0132 (0.0132)  loss_rpn_box_reg: 0.0026 (0.0025)  time: 1.2227  data: 0.0234  max mem: 12822
# Epoch: [48]  [160/224]  eta: 0:01:18  lr: 0.000000  loss: 0.0592 (0.0597)  loss_classifier: 0.0233 (0.0249)  loss_box_reg: 0.0194 (0.0194)  loss_objectness: 0.0109 (0.0130)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.2236  data: 0.0238  max mem: 12822
# Epoch: [48]  [170/224]  eta: 0:01:06  lr: 0.000000  loss: 0.0656 (0.0603)  loss_classifier: 0.0267 (0.0252)  loss_box_reg: 0.0189 (0.0195)  loss_objectness: 0.0099 (0.0131)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.2233  data: 0.0236  max mem: 12822
# Epoch: [48]  [180/224]  eta: 0:00:53  lr: 0.000000  loss: 0.0665 (0.0604)  loss_classifier: 0.0283 (0.0252)  loss_box_reg: 0.0205 (0.0196)  loss_objectness: 0.0135 (0.0131)  loss_rpn_box_reg: 0.0027 (0.0025)  time: 1.2230  data: 0.0227  max mem: 12822
# Epoch: [48]  [190/224]  eta: 0:00:41  lr: 0.000000  loss: 0.0526 (0.0603)  loss_classifier: 0.0238 (0.0253)  loss_box_reg: 0.0194 (0.0195)  loss_objectness: 0.0083 (0.0131)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.2243  data: 0.0228  max mem: 12822
# Epoch: [48]  [200/224]  eta: 0:00:29  lr: 0.000000  loss: 0.0541 (0.0604)  loss_classifier: 0.0239 (0.0253)  loss_box_reg: 0.0182 (0.0196)  loss_objectness: 0.0095 (0.0131)  loss_rpn_box_reg: 0.0022 (0.0025)  time: 1.2251  data: 0.0235  max mem: 12822
# Epoch: [48]  [210/224]  eta: 0:00:17  lr: 0.000000  loss: 0.0561 (0.0605)  loss_classifier: 0.0252 (0.0253)  loss_box_reg: 0.0189 (0.0195)  loss_objectness: 0.0100 (0.0131)  loss_rpn_box_reg: 0.0022 (0.0025)  time: 1.2239  data: 0.0236  max mem: 12822
# Epoch: [48]  [220/224]  eta: 0:00:04  lr: 0.000000  loss: 0.0570 (0.0605)  loss_classifier: 0.0252 (0.0253)  loss_box_reg: 0.0196 (0.0196)  loss_objectness: 0.0110 (0.0132)  loss_rpn_box_reg: 0.0026 (0.0025)  time: 1.2219  data: 0.0225  max mem: 12822
# Epoch: [48]  [223/224]  eta: 0:00:01  lr: 0.000000  loss: 0.0606 (0.0604)  loss_classifier: 0.0252 (0.0253)  loss_box_reg: 0.0188 (0.0195)  loss_objectness: 0.0113 (0.0132)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.1743  data: 0.0214  max mem: 12822
# Epoch: [48] Total time: 0:04:33 (1.2226 s / it)
# Epoch: [49]  [  0/224]  eta: 0:06:45  lr: 0.000000  loss: 0.0702 (0.0702)  loss_classifier: 0.0267 (0.0267)  loss_box_reg: 0.0312 (0.0312)  loss_objectness: 0.0092 (0.0092)  loss_rpn_box_reg: 0.0032 (0.0032)  time: 1.8094  data: 0.5660  max mem: 12822
# Epoch: [49]  [ 10/224]  eta: 0:04:33  lr: 0.000000  loss: 0.0633 (0.0610)  loss_classifier: 0.0254 (0.0252)  loss_box_reg: 0.0210 (0.0215)  loss_objectness: 0.0101 (0.0116)  loss_rpn_box_reg: 0.0030 (0.0027)  time: 1.2767  data: 0.0707  max mem: 12822
# Epoch: [49]  [ 20/224]  eta: 0:04:16  lr: 0.000000  loss: 0.0586 (0.0595)  loss_classifier: 0.0242 (0.0245)  loss_box_reg: 0.0180 (0.0196)  loss_objectness: 0.0105 (0.0128)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.2282  data: 0.0232  max mem: 12822
# Epoch: [49]  [ 30/224]  eta: 0:04:01  lr: 0.000000  loss: 0.0534 (0.0593)  loss_classifier: 0.0221 (0.0244)  loss_box_reg: 0.0180 (0.0194)  loss_objectness: 0.0098 (0.0131)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.2285  data: 0.0247  max mem: 12822
# Epoch: [49]  [ 40/224]  eta: 0:03:48  lr: 0.000000  loss: 0.0624 (0.0614)  loss_classifier: 0.0223 (0.0254)  loss_box_reg: 0.0192 (0.0199)  loss_objectness: 0.0119 (0.0135)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.2254  data: 0.0248  max mem: 12822
# Epoch: [49]  [ 50/224]  eta: 0:03:35  lr: 0.000000  loss: 0.0672 (0.0628)  loss_classifier: 0.0267 (0.0259)  loss_box_reg: 0.0222 (0.0205)  loss_objectness: 0.0144 (0.0137)  loss_rpn_box_reg: 0.0027 (0.0026)  time: 1.2244  data: 0.0242  max mem: 12822
# Epoch: [49]  [ 60/224]  eta: 0:03:22  lr: 0.000000  loss: 0.0572 (0.0613)  loss_classifier: 0.0239 (0.0254)  loss_box_reg: 0.0202 (0.0201)  loss_objectness: 0.0100 (0.0132)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.2235  data: 0.0233  max mem: 12822
# Epoch: [49]  [ 70/224]  eta: 0:03:09  lr: 0.000000  loss: 0.0502 (0.0602)  loss_classifier: 0.0222 (0.0251)  loss_box_reg: 0.0182 (0.0199)  loss_objectness: 0.0090 (0.0127)  loss_rpn_box_reg: 0.0021 (0.0025)  time: 1.2240  data: 0.0225  max mem: 12822
# Epoch: [49]  [ 80/224]  eta: 0:02:57  lr: 0.000000  loss: 0.0536 (0.0604)  loss_classifier: 0.0242 (0.0252)  loss_box_reg: 0.0187 (0.0202)  loss_objectness: 0.0082 (0.0125)  loss_rpn_box_reg: 0.0022 (0.0025)  time: 1.2253  data: 0.0238  max mem: 12822
# Epoch: [49]  [ 90/224]  eta: 0:02:45  lr: 0.000000  loss: 0.0575 (0.0607)  loss_classifier: 0.0255 (0.0253)  loss_box_reg: 0.0198 (0.0201)  loss_objectness: 0.0083 (0.0127)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.2265  data: 0.0256  max mem: 12822
# Epoch: [49]  [100/224]  eta: 0:02:32  lr: 0.000000  loss: 0.0595 (0.0605)  loss_classifier: 0.0261 (0.0251)  loss_box_reg: 0.0182 (0.0199)  loss_objectness: 0.0115 (0.0130)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.2254  data: 0.0247  max mem: 12822
# Epoch: [49]  [110/224]  eta: 0:02:20  lr: 0.000000  loss: 0.0593 (0.0604)  loss_classifier: 0.0256 (0.0252)  loss_box_reg: 0.0176 (0.0199)  loss_objectness: 0.0116 (0.0129)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.2255  data: 0.0232  max mem: 12822
# Epoch: [49]  [120/224]  eta: 0:02:07  lr: 0.000000  loss: 0.0535 (0.0604)  loss_classifier: 0.0235 (0.0253)  loss_box_reg: 0.0177 (0.0199)  loss_objectness: 0.0092 (0.0128)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.2250  data: 0.0227  max mem: 12822
# Epoch: [49]  [130/224]  eta: 0:01:55  lr: 0.000000  loss: 0.0545 (0.0605)  loss_classifier: 0.0226 (0.0253)  loss_box_reg: 0.0188 (0.0199)  loss_objectness: 0.0089 (0.0129)  loss_rpn_box_reg: 0.0026 (0.0025)  time: 1.2244  data: 0.0230  max mem: 12822
# Epoch: [49]  [140/224]  eta: 0:01:43  lr: 0.000000  loss: 0.0549 (0.0603)  loss_classifier: 0.0229 (0.0253)  loss_box_reg: 0.0184 (0.0197)  loss_objectness: 0.0089 (0.0128)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.2235  data: 0.0222  max mem: 12822
# Epoch: [49]  [150/224]  eta: 0:01:30  lr: 0.000000  loss: 0.0565 (0.0602)  loss_classifier: 0.0244 (0.0253)  loss_box_reg: 0.0190 (0.0198)  loss_objectness: 0.0093 (0.0127)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.2236  data: 0.0225  max mem: 12822
# Epoch: [49]  [160/224]  eta: 0:01:18  lr: 0.000000  loss: 0.0549 (0.0600)  loss_classifier: 0.0239 (0.0252)  loss_box_reg: 0.0189 (0.0196)  loss_objectness: 0.0084 (0.0127)  loss_rpn_box_reg: 0.0022 (0.0024)  time: 1.2247  data: 0.0239  max mem: 12822
# Epoch: [49]  [170/224]  eta: 0:01:06  lr: 0.000000  loss: 0.0583 (0.0604)  loss_classifier: 0.0248 (0.0253)  loss_box_reg: 0.0171 (0.0196)  loss_objectness: 0.0118 (0.0130)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.2249  data: 0.0241  max mem: 12822
# Epoch: [49]  [180/224]  eta: 0:00:54  lr: 0.000000  loss: 0.0612 (0.0606)  loss_classifier: 0.0252 (0.0253)  loss_box_reg: 0.0190 (0.0196)  loss_objectness: 0.0140 (0.0132)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.2250  data: 0.0244  max mem: 12822
# Epoch: [49]  [190/224]  eta: 0:00:41  lr: 0.000000  loss: 0.0570 (0.0608)  loss_classifier: 0.0235 (0.0254)  loss_box_reg: 0.0196 (0.0197)  loss_objectness: 0.0117 (0.0132)  loss_rpn_box_reg: 0.0023 (0.0025)  time: 1.2259  data: 0.0250  max mem: 12822
# Epoch: [49]  [200/224]  eta: 0:00:29  lr: 0.000000  loss: 0.0551 (0.0606)  loss_classifier: 0.0227 (0.0253)  loss_box_reg: 0.0185 (0.0196)  loss_objectness: 0.0108 (0.0132)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.2265  data: 0.0246  max mem: 12822
# Epoch: [49]  [210/224]  eta: 0:00:17  lr: 0.000000  loss: 0.0587 (0.0608)  loss_classifier: 0.0238 (0.0253)  loss_box_reg: 0.0181 (0.0196)  loss_objectness: 0.0110 (0.0133)  loss_rpn_box_reg: 0.0026 (0.0025)  time: 1.2265  data: 0.0241  max mem: 12822
# Epoch: [49]  [220/224]  eta: 0:00:04  lr: 0.000000  loss: 0.0589 (0.0607)  loss_classifier: 0.0269 (0.0253)  loss_box_reg: 0.0181 (0.0195)  loss_objectness: 0.0127 (0.0133)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.2260  data: 0.0241  max mem: 12822
# Epoch: [49]  [223/224]  eta: 0:00:01  lr: 0.000000  loss: 0.0587 (0.0606)  loss_classifier: 0.0269 (0.0252)  loss_box_reg: 0.0175 (0.0195)  loss_objectness: 0.0128 (0.0133)  loss_rpn_box_reg: 0.0024 (0.0025)  time: 1.1778  data: 0.0233  max mem: 12822
# Epoch: [49] Total time: 0:04:34 (1.2240 s / it)

# %% [markdown]
# Saving Model

# %%
# %cd '/drive/MyDrive/CSE499 Project/modelSaves/Attention Mechanism/SENet/model3'

torch.save(model.state_dict(), 'model.pth')

torch.save({
'epoch':num_epochs,
'model_state_dict':model.state_dict(),
'optimizer_state_dict':optimizer.state_dict(),
},'ckpt.pth')
# Out:
# [Errno 2] No such file or directory: '/drive/MyDrive/CSE499 Project/modelSaves/Attention Mechanism/SENet/model3'
# /content/Tutorial-Book-Utils

# %% [markdown]
# Loading model

# %%
# %cd '/drive/MyDrive/CSE499 Project/modelSaves/Attention Mechanism/Channel/SENet/model3'
model.load_state_dict(torch.load('./model.pth'))
model = model.to(device)
# Out:
# /drive/.shortcut-targets-by-id/1M-kTVs7g43FucvCjcPvKwiR8r1e1qtHe/CSE499_Project/modelSaves/Attention Mechanism/Channel/SENet/model3

# %% [markdown]
# #Testing

# %%
test_dataset = MitosisImagesDatasetTest(test_dir, 481, 451,transforms=get_transform(train=False))

torch.manual_seed(1)
indices = torch.randperm(len(dataset_test)).tolist()

test_split = 0.2
tsize = int(len(test_dataset)*test_split)

test_dataset = torch.utils.data.Subset(test_dataset, indices[-tsize:])

test_data_loader = torch.utils.data.DataLoader(
  test_dataset,
  batch_size=10,
  shuffle=False,
  num_workers=4,
  collate_fn=utils.collate_fn,
)
test_dir
# Out:
# '/drive/MyDrive/CSE499 Project/Patch Datasets/Hamamatsu XR/'

# %%
def apply_nms(orig_prediction, iou_thresh=0.3):
  keep = torchvision.ops.nms(orig_prediction['boxes'], orig_prediction['scores'], iou_thresh)
  
  final_prediction = orig_prediction
  final_prediction['boxes'] = final_prediction['boxes'][keep]
  final_prediction['scores'] = final_prediction['scores'][keep]
  final_prediction['labels'] = final_prediction['labels'][keep]
  
  return final_prediction

# function to convert a torchtensor back to PIL image
def torch_to_pil(img):
  return torchtrans.ToPILImage()(img).convert('RGB')

# %%
test_dataset = MitosisImagesDatasetTest(test_dir, 481, 451, transforms = get_transform(train=False))
dataset      = MitosisImagesDatasetTest(test_dir, 481, 451)
test_dir
# Out:
# '/drive/MyDrive/CSE499 Project/Patch Datasets/Hamamatsu XR/'

# %% [markdown]
# Predicted labels

# %%
# pick one image from the test set
INDEX_PICK = 53
model=model.to('cpu')
img, target = test_dataset[INDEX_PICK]
# put the model in evaluation mode
model.eval()
with torch.no_grad():
  img = img.to('cpu')
  prediction = model([img])[0]

print('MODEL OUTPUT\n')
nms_prediction = apply_nms(prediction,iou_thresh=0.3)

plot_img_bbox(torch_to_pil(img), nms_prediction)
# Out:
# MODEL OUTPUT

# %% [markdown]
# Ground Truth labels

# %%
img, target = dataset[INDEX_PICK]
plot_img_bbox(img, target)

# %%
def make_prediction(model, img, threshold):
    model.eval()
    preds = model(img)
    for id in range(len(preds)) :
        idx_list = []

        for idx, score in enumerate(preds[id]['scores']) :
            if score > threshold : 
                idx_list.append(idx)

        preds[id]['boxes'] = preds[id]['boxes'][idx_list]
        preds[id]['labels'] = preds[id]['labels'][idx_list]
        preds[id]['scores'] = preds[id]['scores'][idx_list]

    return preds

# %%
model=model.to(device)

# %%
from tqdm import tqdm

labels = []
preds_adj_all = []
annot_all = []

for im, annot in tqdm(test_data_loader, position = 0, leave = True):
    im = list(img.to(device) for img in im)
    #annot = [{k: v.to(device) for k, v in t.items()} for t in annot]

    for t in annot:
        labels += t['labels']

    with torch.no_grad():
        preds_adj = make_prediction(model, im, 0.3)
        preds_adj = [{k: v.to(torch.device('cpu')) for k, v in t.items()} for t in preds_adj]
        preds_adj_all.append(preds_adj)
        annot_all.append(annot)
# Out:
# 100%|██████████| 30/30 [00:36<00:00,  1.22s/it]

# %%
# %cd /content/Tutorial-Book-Utils
import utils_ObjectDetection as utils2
# Out:
# /content/Tutorial-Book-Utils

# %% [markdown]
# Trained on Dataset X, Tested on Dataset Y

# %%
sample_metrics = []
for batch_i in range(len(preds_adj_all)):
    sample_metrics += utils2.get_batch_statistics(preds_adj_all[batch_i], annot_all[batch_i], iou_threshold=0.3) 

true_positives, pred_scores, pred_labels = [torch.cat(x, 0) for x in list(zip(*sample_metrics))]
precision, recall, AP, f1, ap_class = utils2.ap_per_class(true_positives, pred_scores, pred_labels, torch.tensor(labels))
mAP = torch.mean(AP)
print(f'mAP : {mAP}')
# print(f'AP : {AP}')
# Out:
# mAP : 0.5681384641408695

# %%
print('precision: ',precision)
print('recall: ',recall)
print('AP: ',AP)
print('f1: ',f1)
print('ap_class: ',ap_class)
# Out:
# precision:  tensor([0.3568])
# recall:  tensor([0.8062])
# AP:  tensor([0.5681], dtype=torch.float64)
# f1:  tensor([0.4947])
# ap_class:  tensor([1])

# %%
print(train_dir)
print(test_dir)
