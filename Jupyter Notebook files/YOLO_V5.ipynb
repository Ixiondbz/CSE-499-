# %% [markdown]
# #IMPORTING

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
# Out:
# Mounted at /content/drive

# %%
# !cp '/content/drive/Othercomputers/My Laptop/YOLO_V5' -r /content/
# YOLO_V5

# %%
cd /content/YOLO_V5/yolov5
# Out:
# /content/YOLO_V5/yolov5

# %%
# !pip install -r requirements.txt

# %%
import torch
from IPython.display import Image  # for displaying images
import os 
import random
import shutil
from sklearn.model_selection import train_test_split
import xml.etree.ElementTree as ET
from xml.dom import minidom
from tqdm import tqdm
from PIL import Image, ImageDraw
import numpy as np
import matplotlib.pyplot as plt

random.seed(108)

# %%
cat '/content/YOLO_V5/yolov5/data/Mitotic.yaml'
# Out:
# train: /content/YOLO_V5/yolov5/Mitotic/images/train/
# val:  /content/YOLO_V5/yolov5/Mitotic/images/val/
# test: /content/YOLO_V5/yolov5/Mitotic/images/test/
#
# # number of classes
# nc: 1
#
# # class names
# names: ["mitotic"]

# %%
# TAKES 4 MINUTES TO COPY !!!
# !cp '/content/drive/MyDrive/CSE499 Project/YOLO/Dataset_2_train_Dataset_3_val' -r /content/

# %%
os.rename('/content/Dataset_2_train_Dataset_3_val', '/content/Mitotic')

# %%
#rename the folder to Mitotic
# !cp '/content/Mitotic' -r '/content/YOLO_V5/yolov5'

# %%
print("""YOLO FORMAT FOR ANNOTATIONS in a .txt file:

class x_center y_center width height
""")
# Out:
# YOLO FORMAT FOR ANNOTATIONS in a .txt file:
#
# class x_center y_center width height

# %% [markdown]
# #TRAINING

# %%
# !python train.py --img 481 --cfg yolov5s.yaml --hyp hyp.scratch.yaml --batch 32 --epochs 100 --data Mitotic.yaml --weights yolov5s.pt --workers 24 --name yolo_road_det
# Out:
# train: weights=yolov5s.pt, cfg=yolov5s.yaml, data=Mitotic.yaml, hyp=hyp.scratch.yaml, epochs=100, batch_size=32, imgsz=481, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=24, project=runs/train, name=yolo_road_det, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 101, done.
# remote: Counting objects: 100% (94/94), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 101 (delta 58), reused 71 (delta 45), pack-reused 7
# Receiving objects: 100% (101/101), 78.16 KiB | 19.54 MiB/s, done.
# Resolving deltas: 100% (58/58), completed with 7 local objects.
# From https://github.com/ultralytics/yolov5
# ...
